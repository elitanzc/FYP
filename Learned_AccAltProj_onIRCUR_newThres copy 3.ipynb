# %% [markdown]
# # Accelerated Alternating Projection
#
# Paper: https://arxiv.org/pdf/1711.05519.pdf
#
# Matlab Script: https://github.com/caesarcai/AccAltProj_for_RPCA/blob/master/AccAltProj.m
#
# Full Repository: https://github.com/caesarcai/AccAltProj_for_RPCA

# %%
import numpy as np
from numpy import linalg as LA
import random
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
import torch
from torch import nn
from torch.optim import Adam
from torch.optim import SGD
import math
import scipy.stats as stats

from helper import *

torch.set_printoptions(precision=3, sci_mode=True)

# %%
def thres(inputs, t, hard=True, old=True):
    if not hard:
        out = torch.sign(inputs) * torch.max(torch.abs(inputs)- t, torch.zeros(inputs.shape))
    else:
        if old:
            out = inputs * (torch.abs(inputs) > t)
        else:
            # out = torch.sign(inputs) * torch.max(\
            #                                     torch.abs(inputs) - torch.nan_to_num(torch.div(torch.pow(t, 6), torch.pow(torch.abs(inputs), 5))) \
            #                                     , torch.zeros(inputs.shape))
            # out = torch.sign(inputs) * torch.max(torch.abs(inputs) \
            #                                     - torch.div(t, torch.exp(3 * torch.div(torch.abs(inputs) - t, t))) \
            #                                     , torch.zeros(inputs.shape))
            # out = inputs * torch.max(1 - torch.div(torch.pow(t, 2), torch.pow(inputs, 2)), torch.zeros(inputs.shape))
            # out = torch.div(1,  1 + torch.exp(-100 * (torch.sign(inputs) * torch.max(torch.abs(inputs)- t, torch.zeros(inputs.shape))))) \
            #         + torch.sign(inputs) * torch.max(torch.abs(inputs)- t, torch.zeros(inputs.shape)) \
            #         - t
            # mu = 1.0005 * t
            # out = inputs * (torch.abs(inputs) >= mu) \
            #         + torch.sign(inputs) * (mu/(mu-t))*(torch.abs(inputs) - t) * (mu > torch.abs(inputs)) * (torch.abs(inputs) >= t)
            gamma, beta = 0.95, 1
            out = inputs * (torch.abs(inputs) > torch.sqrt(gamma * beta * t**2)) * (beta <= gamma) \
                    + torch.sign(inputs) * torch.min(beta/(beta - gamma) * torch.max(torch.abs(inputs) - (t * gamma), torch.zeros(inputs.shape)), torch.abs(inputs)) * (beta > gamma)
    return out

# %%
def AccAltProj(M0, r, tol, gamma, max_iter):
    m, n = M0.shape
    norm_of_M0 = torch.linalg.norm(M0)
    ## Keep track of loss
    loss = []
    ## Initialization
    beta = 1/(2 * np.power(m * n, 1/4))
    beta_init = 4 * beta
    zeta = beta_init * torch.linalg.norm(M0, 2)
    S = thres(M0, zeta)#, False)
    U, Sigma, V = torch.linalg.svd(M0 - S, full_matrices=False)
    ## NOTE: torch.linalg.svd(M) returns U, S, V such that M=USV not USV.T
    U, Sigma, V = U[:,:r], Sigma[:r], V.t()[:, :r]
    L = U @ torch.diag(Sigma) @ V.t()
    zeta = beta * Sigma[0]
    S = thres(M0 - L, zeta)#, False)
    ## Initial loss
    err = torch.linalg.norm(M0 - L - S)/ norm_of_M0
    loss.append(err)
    for t in range(max_iter):
        ## Update L
        Z = M0 - S
        Q1, R1 = torch.linalg.qr(Z.t() @ U - V @ ((Z @ V).t() @ U)) ## reduced QR
        Q2, R2 = torch.linalg.qr(Z @ V - U @ (U.t() @ Z @ V)) ## reduced QR
        A = torch.cat((torch.cat((U.t() @ Z @ V, R1.t()), 1), 
                        torch.cat((R2, torch.zeros(R2.shape)), 1)), 0) ## A is 2r x 2r matrix
        Um, Sigma, Vm = torch.linalg.svd(A, full_matrices=False)
        U = torch.cat((U, Q2), 1) @ Um[:,:r]
        V = torch.cat((V, Q1), 1) @ Vm.t()[:,:r]
        L = U @ torch.diag(Sigma[:r]) @ V.t()
        ## Update S
        zeta = beta * (Sigma[r] + torch.pow(gamma, t + 1) * Sigma[0])
        S = thres(M0 - L, zeta)#, False)
        ## Compute error
        err = torch.linalg.norm(M0 - L - S)/ norm_of_M0
        loss.append(err)
        if err < tol:
            return loss, L, S
    return loss, L, S



## returns: loss, L, S
def IRCUR(M0, r, tol, gamma, con, max_iter):
    m, n = M0.shape
    norm_of_M0 = torch.linalg.norm(M0)
    ## Keep track of loss
    loss = []
    ## Initialization
    siz_row, siz_col = np.ceil(con * r * np.log(m)).astype(np.int64), np.ceil(con * r * np.log(n)).astype(np.int64)
    zeta = torch.max(torch.abs(M0))
    C, pinv_U, R = torch.zeros(M0.shape), torch.zeros([M0.shape[1], M0.shape[0]]), torch.zeros(M0.shape)
    for t in range(max_iter):
        ## resample rows and columns
        rows, cols = resample(m, n, siz_row, siz_col)
        M0_rows = M0[rows, :]
        M0_cols = M0[:, cols]
        norm_of_M0 = torch.linalg.norm(M0_rows) + torch.linalg.norm(M0_cols)
        ## compute submatrices of L from previous iteration
        L_rows = C[rows, :] @ pinv_U @ R
        L_cols = C @ pinv_U @ R[:, cols]
        ## update S using submatrices of L
        S_rows = thres(M0_rows - L_rows, zeta)
        S_cols = thres(M0_cols - L_cols, zeta)
        ## update L
        C = M0_cols - S_cols
        R = M0_rows - S_rows
        MU = C[rows, :]
        U,Sigma,Vh = torch.linalg.svd(MU, full_matrices=False)
        ## calculate Moore-Penrose inverse of Sigma
        pinv_U = Vh.t()[:,:r] @ torch.diag(1./Sigma[:r]) @ U[:, :r].t()
        ## update zeta
        zeta = gamma * zeta
        ## update loss
        err = (torch.linalg.norm(M0_rows - L_rows - S_rows) + torch.linalg.norm(M0_cols - L_cols - S_cols))/ norm_of_M0
        loss.append(err)
        if err < tol:
            L = C @ pinv_U @ R
            S = thres(M0 - L, zeta)
            return loss, L, S
    L = C @ pinv_U @ R
    S = thres(M0 - L, zeta)
    return loss, L, S

# %% [markdown]
# ## Unrolled version

# %%
## ======================== Learned AccAltProj model ========================
## recover low-rank matrix L from M = L + S

class InitStage(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, M0, r):
        m, n = M0.shape
        norm_of_M0 = torch.linalg.norm(M0)
        beta = 1/(2 * np.power(m * n, 1/4))
        beta_init = 4 * beta
        zeta = beta_init * torch.linalg.norm(M0, 2)
        S = thres(M0, zeta, hard=True, old=False)
        U, Sigma, V = torch.linalg.svd(M0 - S, full_matrices=False)
        U, Sigma, V = U[:,:r], Sigma[:r], V.t()[:, :r]
        L = U @ torch.diag(Sigma) @ V.t()
        zeta = beta * Sigma[0]
        S = M0 - L
        S = thres(S, zeta, hard=True, old=False)
        return S, L, U, V, beta, norm_of_M0

class ProjStage(nn.Module):
    def __init__(self, gamma, lay):
        super().__init__()
        self.gamma = gamma
        self.lay = lay
    def forward(self, M0, S, U, V, r, beta):
        ## Update L
        Z = M0 - S
        Q1, R1 = torch.linalg.qr(Z.t() @ U - V @ ((Z @ V).t() @ U)) ## reduced QR
        Q2, R2 = torch.linalg.qr(Z @ V - U @ (U.t() @ Z @ V)) ## reduced QR
        A = torch.cat((torch.cat((U.t() @ Z @ V, R1.t()), 1), 
                        torch.cat((R2, torch.zeros(R2.shape)), 1)), 0) ## A is 2r x 2r matrix
        Um, Sm, Vm = torch.linalg.svd(A, full_matrices=False)
        U = torch.cat((U, Q2), 1) @ Um[:,:r]
        V = torch.cat((V, Q1), 1) @ Vm.t()[:,:r]
        L = U @ torch.diag(Sm[:r]) @ V.t()
        ## Update S
        zeta = beta * (Sm[r] + torch.pow(self.gamma, self.lay) * Sm[0])
        S = M0 - L
        S = thres(S, zeta, hard=True, old=False)
        return S, L, U, V

class LearnedAAP(nn.Module):
    def __init__(self, max_iter, d1, d2):
        super().__init__()
        self.max_iter = max_iter
        self.gamma = nn.Parameter(torch.tensor(0.7))
        #self.gamma = torch.tensor(0.7)
        self.beta = nn.Parameter(torch.tensor(1/(2 * np.power(d1 * d2, 1/4))))

        ## Stack layers
        self.layer = [InitStage()]
        for t in range(max_iter):
            #self.layer.append(ProjStage(gamma = nn.Parameter(torch.pow(self.gamma.clone().detach(), t + 1).requires_grad_(True))))
            #self.layer.append(ProjStage(gamma = nn.Parameter(self.gamma.clone().detach().requires_grad_(True))))
            self.layer.append(ProjStage(self.gamma, t+1))
        self.layers = nn.Sequential(*self.layer)
        ## Track loss
        self.err = np.zeros(max_iter + 1)

    def forward(self, M0, r):
        lay_init = self.layers[0]
        S, L, U, V, beta, norm_of_M0 = lay_init(M0, r)
        for t in range(1, self.max_iter + 1):
            lay = self.layers[t]
            S, L, U, V = lay(M0, S, U, V, r, self.beta)
            self.err[t] = torch.linalg.norm(M0 - L - S)/ norm_of_M0
        return L, S

# %% [markdown]
# ## The Pipeline

# %% [markdown]
# ### Scenario 1:
# **alpha = 0.1** (low sparsity), **c = 1**, r = 2, dimension = 250x250
#
# gamma=7.579e-01; beta=7.070e-02
#
# ***results: only relative err increased (from 0 to <5e-07 which is also very good) whereas the other errors got reduced***

# %%
## ======================== 0. set constants ========================
d1 = 250                   # num. of rows
d2 = 250                   # num. of columns
max_iter = 20              # num. of layers trained
alpha_true = 0.1
c_true = 1
r = 2
dataset_size = 300

## ======================== 1. generate data ========================
train, test =  generate_train_test(dataset_size, r, d1, d2, alpha_true, c_true)
# Out:
# train dataset size: 180
# test dataset size: 120

# %% [markdown]
# #### Training

# %%
## ======================== 2. estimations by classical ========================
## ======================== USING IRCUR AS EST ========================
train_est = []
for i, (L_true, S_true, M_true) in enumerate(train):
    loss, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    train_est.append((L0, S0, M_true))

# %%
## ======================== 3. train unrolled network with estimated data ========================
net, params_bftrain, params_aftrain, l0_norm_of_S_Shat = train_nn(LearnedAAP(max_iter, d1, d2), r \
                                                                    , lr=7e-03, weight_decay=0 \
                                                                    , nepochs=8, dataset=train_est)
# Out:
# [Parameter containing:
# tensor(7.069e-01, requires_grad=True), Parameter containing:
# tensor(3.853e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.809e-07) tensor(-7.777e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.712620128519916e-10
# [Parameter containing:
# tensor(7.018e-01, requires_grad=True), Parameter containing:
# tensor(3.352e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.118e-05) tensor(1.944e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.608498554465768e-07
# [Parameter containing:
# tensor(6.959e-01, requires_grad=True), Parameter containing:
# tensor(2.766e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.862e-05) tensor(2.998e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.2028718288092932e-07
# [Parameter containing:
# tensor(6.955e-01, requires_grad=True), Parameter containing:
# tensor(2.798e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.713e-05) tensor(-4.671e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.9189106126304978e-07
# [Parameter containing:
# tensor(6.978e-01, requires_grad=True), Parameter containing:
# tensor(3.087e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.762e-05) tensor(-5.922e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.580628605779566e-07
# [Parameter containing:
# tensor(7.005e-01, requires_grad=True), Parameter containing:
# tensor(3.396e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.283e-05) tensor(-1.451e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.7214985820478432e-08
# [Parameter containing:
# tensor(7.000e-01, requires_grad=True), Parameter containing:
# tensor(3.407e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.911e-05) tensor(6.097e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.7884281078295317e-07
# [Parameter containing:
# tensor(6.995e-01, requires_grad=True), Parameter containing:
# tensor(3.414e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.062e-06) tensor(1.095e-06, dtype=torch.float64)
# Epoch 1/8 at cost=2.224610362588919e-08
# [Parameter containing:
# tensor(6.984e-01, requires_grad=True), Parameter containing:
# tensor(3.358e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.858e-05) tensor(1.904e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.3421166278913006e-08
# [Parameter containing:
# tensor(6.983e-01, requires_grad=True), Parameter containing:
# tensor(3.380e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.173e-05) tensor(-2.260e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.0945086614810862e-08
# [Parameter containing:
# tensor(6.993e-01, requires_grad=True), Parameter containing:
# tensor(3.508e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.593e-05) tensor(-3.713e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.7451869283036103e-08
# [Parameter containing:
# tensor(6.986e-01, requires_grad=True), Parameter containing:
# tensor(3.478e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.035e-05) tensor(5.021e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.791113639157629e-08
# [Parameter containing:
# tensor(6.980e-01, requires_grad=True), Parameter containing:
# tensor(3.450e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.930e-07) tensor(5.227e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.735366738144563e-10
# [Parameter containing:
# tensor(6.971e-01, requires_grad=True), Parameter containing:
# tensor(3.389e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.299e-05) tensor(1.314e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.565362393156192e-09
# [Parameter containing:
# tensor(6.971e-01, requires_grad=True), Parameter containing:
# tensor(3.409e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.727e-05) tensor(-2.806e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.357058003279235e-08
# [Parameter containing:
# tensor(6.971e-01, requires_grad=True), Parameter containing:
# tensor(3.429e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.160e-07) tensor(-5.536e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.419556304784521e-10
# [Parameter containing:
# tensor(6.977e-01, requires_grad=True), Parameter containing:
# tensor(3.507e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.233e-05) tensor(-2.270e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.8620363917420946e-08
# [Parameter containing:
# tensor(6.983e-01, requires_grad=True), Parameter containing:
# tensor(3.578e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.430e-08) tensor(9.884e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.981477730314765e-11
# [Parameter containing:
# tensor(6.982e-01, requires_grad=True), Parameter containing:
# tensor(3.593e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.828e-05) tensor(1.786e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.9976326127753055e-09
# [Parameter containing:
# tensor(6.975e-01, requires_grad=True), Parameter containing:
# tensor(3.546e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.364e-05) tensor(2.298e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.594037760265792e-09
# [Parameter containing:
# tensor(6.964e-01, requires_grad=True), Parameter containing:
# tensor(3.458e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.734e-05) tensor(1.707e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.1195103510885929e-08
# [Parameter containing:
# tensor(6.957e-01, requires_grad=True), Parameter containing:
# tensor(3.404e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.382e-06) tensor(-9.458e-06, dtype=torch.float64)
# Epoch 1/8 at cost=2.3493711864830402e-08
# [Parameter containing:
# tensor(6.953e-01, requires_grad=True), Parameter containing:
# tensor(3.387e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.151e-05) tensor(-1.179e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.238311556217013e-08
# [Parameter containing:
# tensor(6.950e-01, requires_grad=True), Parameter containing:
# tensor(3.371e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.019e-07) tensor(-1.103e-07, dtype=torch.float64)
# Epoch 1/8 at cost=6.119939399695795e-08
# [Parameter containing:
# tensor(6.961e-01, requires_grad=True), Parameter containing:
# tensor(3.484e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.682e-05) tensor(-4.827e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.328361562031205e-08
# [Parameter containing:
# tensor(6.977e-01, requires_grad=True), Parameter containing:
# tensor(3.652e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.564e-05) tensor(-2.564e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.341526090214984e-08
# [Parameter containing:
# tensor(6.983e-01, requires_grad=True), Parameter containing:
# tensor(3.724e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.181e-05) tensor(3.043e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.013242195175735e-08
# [Parameter containing:
# tensor(6.989e-01, requires_grad=True), Parameter containing:
# tensor(3.788e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.227e-08) tensor(7.198e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.5577031926313794e-08
# [Parameter containing:
# tensor(6.988e-01, requires_grad=True), Parameter containing:
# tensor(3.799e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.977e-05) tensor(1.824e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.4584878726964234e-07
# [Parameter containing:
# tensor(6.987e-01, requires_grad=True), Parameter containing:
# tensor(3.809e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.095e-07) tensor(1.083e-07, dtype=torch.float64)
# Epoch 1/8 at cost=9.330913286476061e-08
# [Parameter containing:
# tensor(6.974e-01, requires_grad=True), Parameter containing:
# tensor(3.709e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.531e-05) tensor(4.160e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.033930132621208e-07
# [Parameter containing:
# tensor(6.935e-01, requires_grad=True), Parameter containing:
# tensor(3.345e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.851e-04) tensor(1.741e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.5979965439782973e-07
# [Parameter containing:
# tensor(6.900e-01, requires_grad=True), Parameter containing:
# tensor(3.014e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.586e-07) tensor(-1.729e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.4015462568295334e-07
# [Parameter containing:
# tensor(6.868e-01, requires_grad=True), Parameter containing:
# tensor(2.717e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.702e-06) tensor(-3.115e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.238580153994917e-07
# [Parameter containing:
# tensor(6.842e-01, requires_grad=True), Parameter containing:
# tensor(2.489e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.745e-05) tensor(-2.211e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.8092954690018814e-07
# [Parameter containing:
# tensor(6.818e-01, requires_grad=True), Parameter containing:
# tensor(2.280e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.548e-09) tensor(-1.340e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.820631550548569e-07
# [Parameter containing:
# tensor(6.798e-01, requires_grad=True), Parameter containing:
# tensor(2.100e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.511e-06) tensor(-5.265e-06, dtype=torch.float64)
# Epoch 1/8 at cost=2.0303691883327701e-07
# [Parameter containing:
# tensor(6.779e-01, requires_grad=True), Parameter containing:
# tensor(1.937e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.804e-08) tensor(-6.589e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.326346984522388e-07
# [Parameter containing:
# tensor(6.761e-01, requires_grad=True), Parameter containing:
# tensor(1.788e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.267e-07) tensor(-2.400e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.403968378279387e-07
# [Parameter containing:
# tensor(6.746e-01, requires_grad=True), Parameter containing:
# tensor(1.654e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.344e-07) tensor(-4.704e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.7896524557036173e-07
# [Parameter containing:
# tensor(6.732e-01, requires_grad=True), Parameter containing:
# tensor(1.533e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.445e-07) tensor(-7.114e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.4024888034546166e-07
# [Parameter containing:
# tensor(6.719e-01, requires_grad=True), Parameter containing:
# tensor(1.423e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.107e-08) tensor(-9.587e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.313470813282038e-07
# [Parameter containing:
# tensor(6.707e-01, requires_grad=True), Parameter containing:
# tensor(1.328e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.453e-07) tensor(-2.233e-06, dtype=torch.float64)
# Epoch 1/8 at cost=3.1912227882457955e-07
# [Parameter containing:
# tensor(6.697e-01, requires_grad=True), Parameter containing:
# tensor(1.241e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.340e-08) tensor(-3.806e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.879999042055715e-07
# [Parameter containing:
# tensor(6.687e-01, requires_grad=True), Parameter containing:
# tensor(1.163e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.469e-08) tensor(-2.762e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.787930324961053e-07
# [Parameter containing:
# tensor(6.679e-01, requires_grad=True), Parameter containing:
# tensor(1.092e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.822e-08) tensor(-5.590e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.6040598299914564e-07
# [Parameter containing:
# tensor(6.671e-01, requires_grad=True), Parameter containing:
# tensor(1.027e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.264e-08) tensor(-4.097e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.883318472868268e-07
# [Parameter containing:
# tensor(6.664e-01, requires_grad=True), Parameter containing:
# tensor(9.683e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.185e-08) tensor(-4.297e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.3447766750450683e-07
# [Parameter containing:
# tensor(6.657e-01, requires_grad=True), Parameter containing:
# tensor(9.150e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-8.049e-10) tensor(-3.439e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.536647230044764e-07
# [Parameter containing:
# tensor(6.651e-01, requires_grad=True), Parameter containing:
# tensor(8.675e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.162e-07) tensor(-4.241e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.4188975089600717e-07
# [Parameter containing:
# tensor(6.646e-01, requires_grad=True), Parameter containing:
# tensor(8.243e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.437e-09) tensor(-6.517e-09, dtype=torch.float64)
# Epoch 1/8 at cost=4.1422495655751845e-07
# [Parameter containing:
# tensor(6.641e-01, requires_grad=True), Parameter containing:
# tensor(7.850e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.681e-10) tensor(-1.463e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.077750534430379e-07
# [Parameter containing:
# tensor(6.637e-01, requires_grad=True), Parameter containing:
# tensor(7.494e-03, dtype=torch.float64, requires_grad=True)]
# tensor(3.092e-11) tensor(1.219e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.919497260085336e-07
# [Parameter containing:
# tensor(6.633e-01, requires_grad=True), Parameter containing:
# tensor(7.170e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.334e-10) tensor(-1.957e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.1727333293929405e-07
# [Parameter containing:
# tensor(6.629e-01, requires_grad=True), Parameter containing:
# tensor(6.876e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-8.199e-11) tensor(-5.218e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.8747879216316505e-07
# [Parameter containing:
# tensor(6.626e-01, requires_grad=True), Parameter containing:
# tensor(6.610e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.525e-09) tensor(-1.342e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.8958117209422198e-07
# [Parameter containing:
# tensor(6.623e-01, requires_grad=True), Parameter containing:
# tensor(6.368e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.102e-09) tensor(-6.791e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.246051960559271e-07
# [Parameter containing:
# tensor(6.620e-01, requires_grad=True), Parameter containing:
# tensor(6.148e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-4.085e-12) tensor(-3.685e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.6107449002665817e-07
# [Parameter containing:
# tensor(6.617e-01, requires_grad=True), Parameter containing:
# tensor(5.949e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.507e-09) tensor(-1.028e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.5605962150621053e-07
# [Parameter containing:
# tensor(6.615e-01, requires_grad=True), Parameter containing:
# tensor(5.768e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.039e-09) tensor(-7.577e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.4660747044435993e-07
# [Parameter containing:
# tensor(6.613e-01, requires_grad=True), Parameter containing:
# tensor(5.605e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.170e-09) tensor(-1.481e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.125622581341304e-07
# [Parameter containing:
# tensor(6.611e-01, requires_grad=True), Parameter containing:
# tensor(5.456e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.482e-10) tensor(-1.027e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.1525059423765924e-07
# [Parameter containing:
# tensor(6.610e-01, requires_grad=True), Parameter containing:
# tensor(5.322e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.030e-09) tensor(-7.583e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.929465949819132e-07
# [Parameter containing:
# tensor(6.608e-01, requires_grad=True), Parameter containing:
# tensor(5.200e-03, dtype=torch.float64, requires_grad=True)]
# tensor(7.772e-10) tensor(5.475e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.0009400120434293e-07
# [Parameter containing:
# tensor(6.607e-01, requires_grad=True), Parameter containing:
# tensor(5.089e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-5.253e-10) tensor(-4.054e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.218214660842932e-07
# [Parameter containing:
# tensor(6.605e-01, requires_grad=True), Parameter containing:
# tensor(4.989e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.587e-09) tensor(-1.780e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.95283030027349e-07
# [Parameter containing:
# tensor(6.604e-01, requires_grad=True), Parameter containing:
# tensor(4.899e-03, dtype=torch.float64, requires_grad=True)]
# tensor(4.686e-10) tensor(3.566e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.609041871437512e-07
# [Parameter containing:
# tensor(6.603e-01, requires_grad=True), Parameter containing:
# tensor(4.818e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.707e-09) tensor(-6.031e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.7367073585082835e-07
# [Parameter containing:
# tensor(6.602e-01, requires_grad=True), Parameter containing:
# tensor(4.744e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.781e-12) tensor(-1.533e-11, dtype=torch.float64)
# Epoch 1/8 at cost=4.116776892715279e-07
# [Parameter containing:
# tensor(6.601e-01, requires_grad=True), Parameter containing:
# tensor(4.678e-03, dtype=torch.float64, requires_grad=True)]
# tensor(7.142e-10) tensor(5.437e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.742554272572306e-07
# [Parameter containing:
# tensor(6.601e-01, requires_grad=True), Parameter containing:
# tensor(4.618e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.096e-10) tensor(-9.221e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.9821666203133645e-07
# [Parameter containing:
# tensor(6.600e-01, requires_grad=True), Parameter containing:
# tensor(4.563e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-8.767e-11) tensor(-9.987e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.3498965617818612e-07
# [Parameter containing:
# tensor(6.599e-01, requires_grad=True), Parameter containing:
# tensor(4.513e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.323e-10) tensor(-1.301e-09, dtype=torch.float64)
# Epoch 1/8 at cost=4.3673048821801785e-07
# [Parameter containing:
# tensor(6.599e-01, requires_grad=True), Parameter containing:
# tensor(4.469e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.589e-12) tensor(-2.163e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.38439974711946e-07
# [Parameter containing:
# tensor(6.598e-01, requires_grad=True), Parameter containing:
# tensor(4.428e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-4.823e-11) tensor(-5.765e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.8231851817727147e-07
# [Parameter containing:
# tensor(6.598e-01, requires_grad=True), Parameter containing:
# tensor(4.391e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.156e-10) tensor(-1.899e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.3678826721607038e-07
# [Parameter containing:
# tensor(6.597e-01, requires_grad=True), Parameter containing:
# tensor(4.358e-03, dtype=torch.float64, requires_grad=True)]
# tensor(5.736e-14) tensor(-3.117e-12, dtype=torch.float64)
# Epoch 1/8 at cost=3.114153344085935e-07
# [Parameter containing:
# tensor(6.597e-01, requires_grad=True), Parameter containing:
# tensor(4.328e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.833e-10) tensor(-2.623e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.2862715809424117e-07
# [Parameter containing:
# tensor(6.597e-01, requires_grad=True), Parameter containing:
# tensor(4.300e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.618e-11) tensor(-6.748e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.0496181580019766e-07
# [Parameter containing:
# tensor(6.596e-01, requires_grad=True), Parameter containing:
# tensor(4.276e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.322e-10) tensor(-1.256e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.890519112952461e-07
# [Parameter containing:
# tensor(6.596e-01, requires_grad=True), Parameter containing:
# tensor(4.253e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.546e-11) tensor(-1.745e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.167405395743117e-07
# [Parameter containing:
# tensor(6.596e-01, requires_grad=True), Parameter containing:
# tensor(4.233e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.871e-12) tensor(-6.931e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.430496692795714e-07
# [Parameter containing:
# tensor(6.596e-01, requires_grad=True), Parameter containing:
# tensor(4.215e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.528e-10) tensor(-1.712e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.0673530204694543e-07
# [Parameter containing:
# tensor(6.595e-01, requires_grad=True), Parameter containing:
# tensor(4.198e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.636e-10) tensor(-1.799e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.0195906219887547e-07
# [Parameter containing:
# tensor(6.595e-01, requires_grad=True), Parameter containing:
# tensor(4.183e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.247e-12) tensor(-6.213e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.4351805905098445e-07
# [Parameter containing:
# tensor(6.595e-01, requires_grad=True), Parameter containing:
# tensor(4.170e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.606e-11) tensor(-2.847e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.346849777903117e-07
# [Parameter containing:
# tensor(6.595e-01, requires_grad=True), Parameter containing:
# tensor(4.158e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-9.363e-10) tensor(-8.225e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.725493229467247e-07
# [Parameter containing:
# tensor(6.595e-01, requires_grad=True), Parameter containing:
# tensor(4.147e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.822e-11) tensor(-1.844e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.800670699798502e-07
# [Parameter containing:
# tensor(6.595e-01, requires_grad=True), Parameter containing:
# tensor(4.137e-03, dtype=torch.float64, requires_grad=True)]
# tensor(6.738e-10) tensor(5.922e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.5241803314202116e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.128e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.387e-09) tensor(-1.374e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.385486309070984e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.120e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.882e-11) tensor(-3.164e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.3067831256848876e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.114e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-5.399e-10) tensor(-5.359e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.2253522047321894e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.107e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.062e-14) tensor(-5.611e-13, dtype=torch.float64)
# Epoch 1/8 at cost=1.879728728226837e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.102e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.367e-11) tensor(-2.484e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.9436537235815194e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.096e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-9.014e-11) tensor(-8.719e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.2534038041376334e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.092e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.779e-11) tensor(-9.836e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.1749470963404747e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.088e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-5.154e-11) tensor(-5.612e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.613282331116352e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.085e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.433e-09) tensor(-2.284e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.3963889955448394e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.082e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.745e-11) tensor(-2.616e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.8020394893246703e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.080e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.083e-10) tensor(-7.070e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.97866051823803e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.078e-03, dtype=torch.float64, requires_grad=True)]
# tensor(6.015e-12) tensor(-7.349e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.3457556608263985e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.077e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.829e-09) tensor(-3.657e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.2331737170588895e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.078e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-5.779e-09) tensor(-7.341e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.5655630742658104e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.080e-03, dtype=torch.float64, requires_grad=True)]
# tensor(6.360e-11) tensor(2.713e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.926421072719677e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.082e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.749e-09) tensor(-1.779e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.779220835691376e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.084e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.217e-09) tensor(-1.104e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.155006365635927e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.094e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.312e-08) tensor(-2.678e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.4248387830994034e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.103e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.209e-11) tensor(-7.176e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.1265270195035555e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.113e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-4.975e-09) tensor(-4.000e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.6165770944098767e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.122e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.223e-09) tensor(-1.044e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.951214691573114e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.130e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-4.402e-11) tensor(-5.346e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.037897045032878e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.137e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.265e-10) tensor(-1.385e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.94507316311865e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.144e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.055e-10) tensor(-1.132e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.9523098987738194e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.150e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.869e-11) tensor(-1.000e-09, dtype=torch.float64)
# Epoch 1/8 at cost=4.5380409119388787e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.156e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.422e-09) tensor(-1.355e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.144327251902723e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.163e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.434e-09) tensor(-3.455e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.95622186285982e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.169e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.070e-10) tensor(-5.479e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.7533470731432317e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.174e-03, dtype=torch.float64, requires_grad=True)]
# tensor(2.227e-09) tensor(1.845e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.0204270135291154e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.178e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.271e-09) tensor(-1.067e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.6774475259117025e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.184e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.577e-09) tensor(-2.842e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.2096019708660606e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.191e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.017e-09) tensor(-6.482e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.472254377356876e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.197e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-5.267e-11) tensor(-6.528e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.903285860611504e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.203e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.417e-09) tensor(-1.899e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.476769734334084e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.209e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.515e-11) tensor(-2.471e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.5090187705245626e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.214e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.761e-10) tensor(-1.844e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.15889764124222e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.219e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.431e-10) tensor(-2.199e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.8787277983610693e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.223e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-4.036e-10) tensor(-3.818e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.0985953003437317e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.227e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.265e-12) tensor(-4.237e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.2209249550542154e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.234e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.021e-08) tensor(-9.391e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.619785846036393e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.243e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-9.340e-09) tensor(-7.412e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.923040085534012e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.251e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.558e-11) tensor(-7.499e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.7936630431213416e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.258e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.097e-11) tensor(-1.270e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.1301652825277415e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.266e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.140e-09) tensor(-3.204e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.2948977118630864e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.273e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.361e-11) tensor(-1.432e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.12285578729643e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.279e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.473e-12) tensor(-4.243e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.6725248858383566e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.285e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.287e-10) tensor(-5.427e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.975370989588555e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.290e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.259e-11) tensor(-2.477e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.434483630826435e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.295e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.147e-11) tensor(-5.268e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.114370201728889e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.299e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.156e-10) tensor(-2.787e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.710671023782197e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.303e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.106e-11) tensor(-1.113e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.6306094014216796e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.306e-03, dtype=torch.float64, requires_grad=True)]
# tensor(2.697e-09) tensor(2.411e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.091535975523584e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.309e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-8.553e-12) tensor(-8.949e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.675463631225284e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.311e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.458e-10) tensor(-2.588e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.2445913689116423e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.312e-03, dtype=torch.float64, requires_grad=True)]
# tensor(4.362e-09) tensor(3.369e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.38652938580708e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.313e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.312e-12) tensor(-1.625e-11, dtype=torch.float64)
# Epoch 1/8 at cost=4.2167596348008374e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.314e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-4.701e-10) tensor(-4.919e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.355174189005993e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.315e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.911e-10) tensor(-6.772e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.605446525194566e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.316e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.382e-09) tensor(-2.127e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.459097174778435e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.318e-03, dtype=torch.float64, requires_grad=True)]
# tensor(6.565e-10) tensor(4.575e-09, dtype=torch.float64)
# Epoch 1/8 at cost=4.4227573425814626e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.319e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.491e-11) tensor(-2.827e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.2267743083357345e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.320e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-5.536e-10) tensor(-4.744e-09, dtype=torch.float64)
# Epoch 1/8 at cost=4.0838421000444214e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.324e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.644e-09) tensor(-5.155e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.969758720108075e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.326e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.410e-11) tensor(-2.615e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.4357291295018513e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.329e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-6.949e-12) tensor(-8.187e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.859753749362426e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.332e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.012e-10) tensor(-5.962e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.801086509407469e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.336e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-5.692e-09) tensor(-5.108e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.4463916992754093e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.340e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.537e-11) tensor(-2.525e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.216509583126026e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.345e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.599e-09) tensor(-5.783e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.580310649591411e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.351e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-9.538e-11) tensor(-9.280e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.5400231606909074e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.355e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.156e-10) tensor(-1.111e-09, dtype=torch.float64)
# Epoch 1/8 at cost=4.248233835824067e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.360e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.263e-09) tensor(-1.921e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.145971388425096e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.365e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.371e-12) tensor(-1.904e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.608588462431726e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.369e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.906e-12) tensor(-1.529e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.454807426805928e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.370e-03, dtype=torch.float64, requires_grad=True)]
# tensor(6.823e-09) tensor(6.025e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.3358338669131626e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.372e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.190e-09) tensor(-1.013e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.8184529437803576e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.374e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.290e-09) tensor(-1.339e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.550407766146236e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.376e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.034e-10) tensor(-2.888e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.8667596179966495e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.378e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-4.774e-10) tensor(-4.937e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.711540443873673e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.379e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.662e-12) tensor(-7.301e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.581842011295521e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.381e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.095e-10) tensor(-1.304e-09, dtype=torch.float64)
# Epoch 1/8 at cost=4.014071919300477e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.383e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.955e-10) tensor(-3.891e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.9975833487915224e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.384e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.155e-10) tensor(-1.139e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.3378921671101125e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.386e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.815e-10) tensor(-3.393e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.820043446012278e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.387e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.917e-10) tensor(-3.480e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.3664580339755048e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.392e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-8.424e-09) tensor(-7.922e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.27586008097569e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.396e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-5.403e-11) tensor(-5.666e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.3989982739512925e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.400e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.135e-11) tensor(-7.656e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.987111429320066e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.403e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.221e-11) tensor(-8.332e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.8603826390517497e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.415e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.985e-08) tensor(-2.261e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.592084567571874e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.427e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-8.939e-10) tensor(-9.065e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.8593703405022097e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.438e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-4.554e-13) tensor(-1.019e-12, dtype=torch.float64)
# Epoch 2/8 at cost=2.2589655657156982e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.458e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.456e-08) tensor(-2.743e-07, dtype=torch.float64)
# Epoch 2/8 at cost=2.7867250196322857e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.475e-03, dtype=torch.float64, requires_grad=True)]
# tensor(8.003e-09) tensor(6.202e-08, dtype=torch.float64)
# Epoch 2/8 at cost=4.1989733290392905e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.491e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.602e-09) tensor(-3.172e-08, dtype=torch.float64)
# Epoch 2/8 at cost=3.0489002256217645e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.505e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-7.137e-11) tensor(-7.385e-10, dtype=torch.float64)
# Epoch 2/8 at cost=3.809271049703966e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.518e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.920e-11) tensor(-3.119e-10, dtype=torch.float64)
# Epoch 2/8 at cost=1.68980875514535e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.530e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.025e-09) tensor(-9.281e-09, dtype=torch.float64)
# Epoch 2/8 at cost=3.094074827458826e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.541e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.209e-10) tensor(-2.116e-09, dtype=torch.float64)
# Epoch 2/8 at cost=4.1966239905377734e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.552e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.410e-09) tensor(-2.158e-08, dtype=torch.float64)
# Epoch 2/8 at cost=3.0113213256299787e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.563e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-4.455e-09) tensor(-3.424e-08, dtype=torch.float64)
# Epoch 2/8 at cost=3.63837415306989e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.574e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.718e-12) tensor(-1.652e-11, dtype=torch.float64)
# Epoch 2/8 at cost=3.174592961840972e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.583e-03, dtype=torch.float64, requires_grad=True)]
# tensor(7.398e-11) tensor(7.364e-10, dtype=torch.float64)
# Epoch 2/8 at cost=3.143260300930706e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.591e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-1.617e-10) tensor(-1.487e-09, dtype=torch.float64)
# Epoch 2/8 at cost=2.5218412247340893e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.608e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.000e-08) tensor(-2.155e-07, dtype=torch.float64)
# Epoch 2/8 at cost=2.6060260438498517e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.623e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-3.252e-10) tensor(-2.926e-09, dtype=torch.float64)
# Epoch 2/8 at cost=3.169635647282121e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.645e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-2.574e-08) tensor(-1.873e-07, dtype=torch.float64)
# Epoch 2/8 at cost=3.5595954273048847e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(4.668e-03, dtype=torch.float64, requires_grad=True)]
# tensor(-8.300e-09) tensor(-7.091e-08, dtype=torch.float64)
# Epoch 2/8 at cost=2.5923796442839375e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# ...
# tensor(1.134e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.418e-06) tensor(-9.847e-07, dtype=torch.float64)
# Epoch 8/8 at cost=7.717549932451107e-10
# [Parameter containing:
# tensor(6.572e-01, requires_grad=True), Parameter containing:
# tensor(1.140e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.316e-05) tensor(-6.689e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.2560628981361788e-08
# [Parameter containing:
# tensor(6.581e-01, requires_grad=True), Parameter containing:
# tensor(1.146e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.930e-06) tensor(-1.132e-06, dtype=torch.float64)
# Epoch 8/8 at cost=4.224840033373312e-09
# [Parameter containing:
# tensor(6.562e-01, requires_grad=True), Parameter containing:
# tensor(1.133e-01, dtype=torch.float64, requires_grad=True)]
# tensor(9.200e-05) tensor(2.641e-05, dtype=torch.float64)
# Epoch 8/8 at cost=4.1607250977904187e-08
# [Parameter containing:
# tensor(6.544e-01, requires_grad=True), Parameter containing:
# tensor(1.121e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-7.964e-07) tensor(-2.303e-07, dtype=torch.float64)
# Epoch 8/8 at cost=7.321380307567793e-11
# [Parameter containing:
# tensor(6.535e-01, requires_grad=True), Parameter containing:
# tensor(1.114e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.965e-05) tensor(-5.741e-06, dtype=torch.float64)
# Epoch 8/8 at cost=5.666950997351705e-08
# [Parameter containing:
# tensor(6.528e-01, requires_grad=True), Parameter containing:
# tensor(1.110e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-8.216e-06) tensor(-2.414e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.1808484146058618e-07
# [Parameter containing:
# tensor(6.529e-01, requires_grad=True), Parameter containing:
# tensor(1.110e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.017e-05) tensor(-5.933e-06, dtype=torch.float64)
# Epoch 8/8 at cost=7.5981404279446e-08
# [Parameter containing:
# tensor(6.531e-01, requires_grad=True), Parameter containing:
# tensor(1.112e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-8.719e-06) tensor(-2.566e-06, dtype=torch.float64)
# Epoch 8/8 at cost=4.1726618604798205e-08
# [Parameter containing:
# tensor(6.537e-01, requires_grad=True), Parameter containing:
# tensor(1.117e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.267e-05) tensor(-3.721e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.0402534772756553e-08
# [Parameter containing:
# tensor(6.546e-01, requires_grad=True), Parameter containing:
# tensor(1.124e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.039e-05) tensor(-3.041e-06, dtype=torch.float64)
# Epoch 8/8 at cost=4.594599900542562e-08
# [Parameter containing:
# tensor(6.568e-01, requires_grad=True), Parameter containing:
# tensor(1.140e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-4.765e-05) tensor(-1.388e-05, dtype=torch.float64)
# Epoch 8/8 at cost=6.679393038666603e-08
# [Parameter containing:
# tensor(6.589e-01, requires_grad=True), Parameter containing:
# tensor(1.156e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-7.308e-06) tensor(-2.102e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.4822416627424673e-09
# [Parameter containing:
# tensor(6.593e-01, requires_grad=True), Parameter containing:
# tensor(1.159e-01, dtype=torch.float64, requires_grad=True)]
# tensor(5.485e-05) tensor(1.564e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.324684172412162e-08
# [Parameter containing:
# tensor(6.585e-01, requires_grad=True), Parameter containing:
# tensor(1.154e-01, dtype=torch.float64, requires_grad=True)]
# tensor(3.574e-05) tensor(1.017e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.7836597976383928e-08
# [Parameter containing:
# tensor(6.568e-01, requires_grad=True), Parameter containing:
# tensor(1.142e-01, dtype=torch.float64, requires_grad=True)]
# tensor(3.631e-05) tensor(1.037e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.2248226372312274e-08
# [Parameter containing:
# tensor(6.568e-01, requires_grad=True), Parameter containing:
# tensor(1.142e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-5.092e-05) tensor(-1.464e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.2144001238521014e-08
# [Parameter containing:
# tensor(6.575e-01, requires_grad=True), Parameter containing:
# tensor(1.148e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.731e-05) tensor(-7.849e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.6490663057311394e-08
# [Parameter containing:
# tensor(6.577e-01, requires_grad=True), Parameter containing:
# tensor(1.150e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.434e-05) tensor(4.118e-06, dtype=torch.float64)
# Epoch 8/8 at cost=7.691869363668502e-09
# [Parameter containing:
# tensor(6.577e-01, requires_grad=True), Parameter containing:
# tensor(1.150e-01, dtype=torch.float64, requires_grad=True)]
# tensor(8.551e-06) tensor(2.447e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.7975297916805744e-09
# [Parameter containing:
# tensor(6.574e-01, requires_grad=True), Parameter containing:
# tensor(1.148e-01, dtype=torch.float64, requires_grad=True)]
# tensor(9.283e-06) tensor(2.656e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.9915963040139104e-09
# [Parameter containing:
# tensor(6.562e-01, requires_grad=True), Parameter containing:
# tensor(1.140e-01, dtype=torch.float64, requires_grad=True)]
# tensor(3.129e-05) tensor(8.962e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.5638507377957467e-08
# [Parameter containing:
# tensor(6.555e-01, requires_grad=True), Parameter containing:
# tensor(1.135e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.068e-05) tensor(-3.073e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.1933051758414877e-09
# [Parameter containing:
# tensor(6.548e-01, requires_grad=True), Parameter containing:
# tensor(1.130e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.989e-09) tensor(6.448e-10, dtype=torch.float64)
# Epoch 8/8 at cost=5.899857669078301e-08
# [Parameter containing:
# tensor(6.550e-01, requires_grad=True), Parameter containing:
# tensor(1.131e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.560e-05) tensor(-7.418e-06, dtype=torch.float64)
# Epoch 8/8 at cost=9.275419898813198e-08
# [Parameter containing:
# tensor(6.551e-01, requires_grad=True), Parameter containing:
# tensor(1.133e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-4.167e-07) tensor(-1.207e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.0815738466239964e-08
# [Parameter containing:
# tensor(6.557e-01, requires_grad=True), Parameter containing:
# tensor(1.138e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.800e-05) tensor(-5.206e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.5066993813993577e-08
# [Parameter containing:
# tensor(6.571e-01, requires_grad=True), Parameter containing:
# tensor(1.148e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.609e-05) tensor(-7.515e-06, dtype=torch.float64)
# Epoch 8/8 at cost=5.420109872034118e-08
# [Parameter containing:
# tensor(6.581e-01, requires_grad=True), Parameter containing:
# tensor(1.155e-01, dtype=torch.float64, requires_grad=True)]
# tensor(6.657e-06) tensor(1.911e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.533245473974489e-09
# [Parameter containing:
# tensor(6.576e-01, requires_grad=True), Parameter containing:
# tensor(1.152e-01, dtype=torch.float64, requires_grad=True)]
# tensor(4.973e-05) tensor(1.417e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.7639911692745045e-08
# [Parameter containing:
# tensor(6.554e-01, requires_grad=True), Parameter containing:
# tensor(1.136e-01, dtype=torch.float64, requires_grad=True)]
# tensor(5.714e-05) tensor(1.632e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.4230428269665936e-08
# [Parameter containing:
# tensor(6.539e-01, requires_grad=True), Parameter containing:
# tensor(1.126e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.502e-05) tensor(-4.333e-06, dtype=torch.float64)
# Epoch 8/8 at cost=8.116316507766896e-09
# [Parameter containing:
# tensor(6.528e-01, requires_grad=True), Parameter containing:
# tensor(1.118e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-7.631e-06) tensor(-2.217e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.71867976411977e-08
# [Parameter containing:
# tensor(6.525e-01, requires_grad=True), Parameter containing:
# tensor(1.116e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.304e-05) tensor(-6.728e-06, dtype=torch.float64)
# Epoch 8/8 at cost=4.7697021443582344e-08
# [Parameter containing:
# tensor(6.531e-01, requires_grad=True), Parameter containing:
# tensor(1.121e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.054e-05) tensor(-8.927e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.2835074275917577e-07
# [Parameter containing:
# tensor(6.541e-01, requires_grad=True), Parameter containing:
# tensor(1.128e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.708e-05) tensor(-4.980e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.687329671540283e-07
# [Parameter containing:
# tensor(6.556e-01, requires_grad=True), Parameter containing:
# tensor(1.139e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.861e-05) tensor(-5.398e-06, dtype=torch.float64)
# Epoch 8/8 at cost=8.022259834206125e-08
# [Parameter containing:
# tensor(6.577e-01, requires_grad=True), Parameter containing:
# tensor(1.156e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.992e-05) tensor(-8.604e-06, dtype=torch.float64)
# Epoch 8/8 at cost=4.524051533394413e-08
# [Parameter containing:
# tensor(6.595e-01, requires_grad=True), Parameter containing:
# tensor(1.169e-01, dtype=torch.float64, requires_grad=True)]
# tensor(8.015e-06) tensor(2.282e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.415956990020618e-09
# [Parameter containing:
# tensor(6.605e-01, requires_grad=True), Parameter containing:
# tensor(1.177e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.834e-05) tensor(5.178e-06, dtype=torch.float64)
# Epoch 8/8 at cost=5.316049112025212e-08
# [Parameter containing:
# tensor(6.593e-01, requires_grad=True), Parameter containing:
# tensor(1.169e-01, dtype=torch.float64, requires_grad=True)]
# tensor(7.185e-05) tensor(2.017e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.0593741706088622e-07
# [Parameter containing:
# tensor(6.562e-01, requires_grad=True), Parameter containing:
# tensor(1.147e-01, dtype=torch.float64, requires_grad=True)]
# tensor(7.309e-05) tensor(2.062e-05, dtype=torch.float64)
# Epoch 8/8 at cost=9.237287912355896e-08
# [Parameter containing:
# tensor(6.534e-01, requires_grad=True), Parameter containing:
# tensor(1.127e-01, dtype=torch.float64, requires_grad=True)]
# tensor(2.901e-07) tensor(8.817e-08, dtype=torch.float64)
# Epoch 8/8 at cost=1.7982959565898682e-10
# [Parameter containing:
# tensor(6.513e-01, requires_grad=True), Parameter containing:
# tensor(1.113e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.772e-05) tensor(-5.131e-06, dtype=torch.float64)
# Epoch 8/8 at cost=4.6936982300849195e-08
# [Parameter containing:
# tensor(6.502e-01, requires_grad=True), Parameter containing:
# tensor(1.105e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.409e-05) tensor(-7.054e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.0667866945368587e-07
# [Parameter containing:
# tensor(6.492e-01, requires_grad=True), Parameter containing:
# tensor(1.098e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.593e-06) tensor(-4.698e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.3121391734548524e-07
# [Parameter containing:
# tensor(6.489e-01, requires_grad=True), Parameter containing:
# tensor(1.097e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.984e-05) tensor(-5.864e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.8496370418906736e-07
# [Parameter containing:
# tensor(6.486e-01, requires_grad=True), Parameter containing:
# tensor(1.096e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-7.493e-08) tensor(-2.327e-08, dtype=torch.float64)
# Epoch 8/8 at cost=7.462298867721984e-08
# [Parameter containing:
# tensor(6.484e-01, requires_grad=True), Parameter containing:
# tensor(1.095e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.474e-06) tensor(-4.382e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.085732688783537e-07
# [Parameter containing:
# tensor(6.482e-01, requires_grad=True), Parameter containing:
# tensor(1.094e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-5.225e-08) tensor(-1.651e-08, dtype=torch.float64)
# Epoch 8/8 at cost=1.992096372305241e-07
# [Parameter containing:
# tensor(6.483e-01, requires_grad=True), Parameter containing:
# tensor(1.095e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.045e-05) tensor(-3.101e-06, dtype=torch.float64)
# Epoch 8/8 at cost=7.090946496646211e-08
# [Parameter containing:
# tensor(6.491e-01, requires_grad=True), Parameter containing:
# tensor(1.102e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.318e-05) tensor(-6.860e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.927631896909588e-07
# [Parameter containing:
# tensor(6.501e-01, requires_grad=True), Parameter containing:
# tensor(1.110e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-9.364e-06) tensor(-2.760e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.0268416872349917e-07
# [Parameter containing:
# tensor(6.518e-01, requires_grad=True), Parameter containing:
# tensor(1.123e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.898e-05) tensor(-8.488e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.354548911398524e-07
# [Parameter containing:
# tensor(6.534e-01, requires_grad=True), Parameter containing:
# tensor(1.135e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.016e-07) tensor(-3.098e-08, dtype=torch.float64)
# Epoch 8/8 at cost=9.585188109895171e-08
# [Parameter containing:
# tensor(6.558e-01, requires_grad=True), Parameter containing:
# tensor(1.154e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.712e-05) tensor(-1.068e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.2861714537848457e-07
# [Parameter containing:
# tensor(6.596e-01, requires_grad=True), Parameter containing:
# tensor(1.182e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-5.454e-05) tensor(-1.550e-05, dtype=torch.float64)
# Epoch 8/8 at cost=4.873212589018294e-08
# [Parameter containing:
# tensor(6.627e-01, requires_grad=True), Parameter containing:
# tensor(1.205e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.113e-05) tensor(3.113e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.0561703334133199e-07
# [Parameter containing:
# tensor(6.643e-01, requires_grad=True), Parameter containing:
# tensor(1.217e-01, dtype=torch.float64, requires_grad=True)]
# tensor(4.238e-05) tensor(1.166e-05, dtype=torch.float64)
# Epoch 8/8 at cost=4.363905361515208e-07
# [Parameter containing:
# tensor(6.657e-01, requires_grad=True), Parameter containing:
# tensor(1.228e-01, dtype=torch.float64, requires_grad=True)]
# tensor(4.589e-07) tensor(1.321e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.363830589047211e-07
# [Parameter containing:
# tensor(6.664e-01, requires_grad=True), Parameter containing:
# tensor(1.235e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.691e-05) tensor(4.585e-06, dtype=torch.float64)
# Epoch 8/8 at cost=4.819767127628438e-07
# [Parameter containing:
# tensor(6.632e-01, requires_grad=True), Parameter containing:
# tensor(1.213e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.379e-04) tensor(3.721e-05, dtype=torch.float64)
# Epoch 8/8 at cost=6.631439077864343e-07
# [Parameter containing:
# tensor(6.595e-01, requires_grad=True), Parameter containing:
# tensor(1.188e-01, dtype=torch.float64, requires_grad=True)]
# tensor(2.985e-05) tensor(8.168e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.757445543011272e-07
# [Parameter containing:
# tensor(6.542e-01, requires_grad=True), Parameter containing:
# tensor(1.151e-01, dtype=torch.float64, requires_grad=True)]
# tensor(6.746e-05) tensor(1.874e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.3216383365488582e-07
# [Parameter containing:
# tensor(6.498e-01, requires_grad=True), Parameter containing:
# tensor(1.121e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.244e-05) tensor(-3.534e-06, dtype=torch.float64)
# Epoch 8/8 at cost=8.027180342651263e-08
# [Parameter containing:
# tensor(6.459e-01, requires_grad=True), Parameter containing:
# tensor(1.094e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-7.478e-07) tensor(-2.285e-07, dtype=torch.float64)
# Epoch 8/8 at cost=1.9986048016562563e-07
# Finished Training

# %% [markdown]
# #### Evaluating unrolled network on train dataset

# %%
out_bftrain, out_hat = get_net_outputs(net, LearnedAAP(max_iter, d1, d2), r, train)
out_accaltproj = []
for i, (L_true, S_true, M_true) in enumerate(train):
    loss, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    out_accaltproj.append((L0, S0))

# %%
metrics = get_metrics(train, [x[:2] for x in train_est], out_bftrain, out_hat)
fro_norm_L_old, mse_S_old, fro_norm_S_old, count_nonzeros_S_old, relative_err_old, \
    fro_norm_L_new, mse_S_new, fro_norm_S_new, count_nonzeros_S_new, relative_err_new, \
    fro_norm_L_bftrain, mse_S_bftrain, fro_norm_S_bftrain, count_nonzeros_S_bftrain, relative_err_bftrain \
        = metrics.values()
fro_norm_L_accaltproj, mse_S_accaltproj, fro_norm_S_accaltproj, count_nonzeros_S_accaltproj, relative_err_accaltproj \
    = list(get_metrics(train, out_accaltproj, out_bftrain, out_hat).values())[:5]

fig, ax = plt.subplots()
ax.boxplot([relative_err_old, relative_err_new, relative_err_bftrain, relative_err_accaltproj], notch = True)
ax.set_xticklabels(["relative_err_old", "relative_err_new", "relative_err_bftrain", "relative_err_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_L_old, fro_norm_L_new, fro_norm_L_bftrain, fro_norm_L_accaltproj], notch = True)
ax.set_xticklabels(["fro_norm_L_old", "fro_norm_L_new", "fro_norm_L_bfaftrain", "fro_norm_L_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([mse_S_old, mse_S_new, mse_S_bftrain, mse_S_accaltproj], notch = True)
ax.set_xticklabels(["mse_S_old", "mse_S_new", "mse_S_bfaftrain", "mse_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_S_old, fro_norm_S_new, fro_norm_S_bftrain, fro_norm_S_accaltproj], notch = True)
ax.set_xticklabels(["fro_norm_S_old", "fro_norm_S_new", "fro_norm_S_bfaftrain", "fro_norm_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([count_nonzeros_S_old, count_nonzeros_S_new, count_nonzeros_S_bftrain, count_nonzeros_S_accaltproj], notch = True)
ax.set_xticklabels(["count_nonzeros_S_old", "count_nonzeros_S_new", "count_nonzeros_S_bfaftrain", "count_nonzeros_S_accaltproj"])
plt.show()
# Out:
# /Users/elitanzc/Github/FYP/helper.py:254: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat1 = (torch.tensor(mat1) == 0)
# /Users/elitanzc/Github/FYP/helper.py:255: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat2 = (torch.tensor(mat2) == 0)

# %%
print("P-values from test of mean with H1: _new < _old")
print("relative_err_new, relative_err_old: ", stats.ttest_rel(relative_err_new, relative_err_old, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_old, alternative='less').pvalue)
print("mse_S_new, mse_S_old: ", stats.ttest_rel(mse_S_new, mse_S_old, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_old, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_old, alternative='less').pvalue)
print()
print("P-values from test of mean with H1: _new < _accaltproj")
print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(relative_err_new, relative_err_accaltproj, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_accaltproj, alternative='less').pvalue)
print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(mse_S_new, mse_S_accaltproj, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_accaltproj, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_accaltproj, alternative='less').pvalue)
print()
print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(relative_err_new, relative_err_bftrain, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_bftrain, alternative='less').pvalue)
print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(mse_S_new, mse_S_bftrain, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_bftrain, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_bftrain, alternative='less').pvalue)

# print("*Note: values are log-transformed before deriving p-values")
# print()
# print("relative_err_new, relative_err_old: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_old), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_old), alternative='less').pvalue)
# print("mse_S_new, mse_S_old: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_old), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_old), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_old), alternative='less').pvalue)
# print()
# print("P-values from test of mean with H1: _new < _accaltproj")
# print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_accaltproj), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_accaltproj), alternative='less').pvalue)
# print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_accaltproj), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_accaltproj), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_accaltproj), alternative='less').pvalue)
# print()
# print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_bftrain), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_bftrain), alternative='less').pvalue)
# print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_bftrain), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_bftrain), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_bftrain), alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new < _old
# relative_err_new, relative_err_old:  1.3045321345275995e-29
# fro_norm_L_new, fro_norm_L_old:  0.03667385880396659
# mse_S_new, mse_S_old:  1.1174283170965377e-13
# fro_norm_S_new, fro_norm_S_old:  6.17776753051694e-33
# count_nonzeros_S_new, count_nonzeros_S_old:  7.192315325970338e-47
#
# P-values from test of mean with H1: _new < _accaltproj
# relative_err_new, relative_err_accaltproj:  7.182014890334917e-53
# fro_norm_L_new, fro_norm_L_accaltproj:  3.733806593487735e-17
# mse_S_new, mse_S_accaltproj:  1.0078348332832505e-37
# fro_norm_S_new, fro_norm_S_accaltproj:  2.314816620635743e-53
# count_nonzeros_S_new, count_nonzeros_S_accaltproj:  2.3864017476716142e-48
#
# relative_err_new, relative_err_bftrain:  1.0
# fro_norm_L_new, fro_norm_L_bftrain:  2.3238649857459426e-49
# mse_S_new, mse_S_bftrain:  3.4113579390258314e-25
# fro_norm_S_new, fro_norm_S_bftrain:  2.4717269839622807e-65
# count_nonzeros_S_new, count_nonzeros_S_bftrain:  2.8088553392016664e-179

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_old[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_old[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_old[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_old[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2174885101.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 12/180 outliers
# fro_norm_L: 11/180 outliers
# mse_S: 30/180 outliers
# fro_norm_S: 25/180 outliers
# count_nonzeros_S: 0/180 outliers

# %%
print("P-values from test of mean with H1: _new/_old < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_old < 1
# relative_err:  1.0600364306635654e-42
# fro_norm_L:  0.9490010013281129
# mse_S:  2.592058071929932e-31
# fro_norm_S:  4.251253777063609e-59
# count_nonzeros_S:  nan

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_accaltproj[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_accaltproj[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_accaltproj[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_accaltproj[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2948823882.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 10/180 outliers
# fro_norm_L: 13/180 outliers
# mse_S: 29/180 outliers
# fro_norm_S: 21/180 outliers
# count_nonzeros_S: 0/180 outliers

# %%
print("P-values from test of mean with H1: _new/_accaltproj < 1")
#print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_accaltproj < 1
# relative_err:  1.013752099038056e-65
# fro_norm_L:  6.747640399230733e-14
# mse_S:  8.417938768150798e-91
# fro_norm_S:  8.711771336035677e-88
# count_nonzeros_S:  nan

# %%
print(np.median(count_nonzeros_S_new), np.mean(count_nonzeros_S_new))
print(np.median(count_nonzeros_S_accaltproj), np.mean(count_nonzeros_S_accaltproj))
# Out:
# 0.0 5.2444443e-06
# 3.2e-05 2.96e-05

# %% [markdown]
# #### Evaluating unrolled network on test dataset

# %%
out_bftrain_ontest, out_hat_ontest = get_net_outputs(net, LearnedAAP(max_iter, d1, d2), r, test)
out_accaltproj_ontest = []
out_ircur_ontest = []
for (L_true, S_true, M_true) in test:
    loss0, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    out_accaltproj_ontest.append((L0, S0))
    loss0, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    out_ircur_ontest.append((L0, S0))

# %%
metrics = get_metrics(test, out_ircur_ontest, out_bftrain_ontest, out_hat_ontest)
fro_norm_L_old, mse_S_old, fro_norm_S_old, count_nonzeros_S_old, relative_err_old, \
    fro_norm_L_new, mse_S_new, fro_norm_S_new, count_nonzeros_S_new, relative_err_new, \
    fro_norm_L_bftrain, mse_S_bftrain, fro_norm_S_bftrain, count_nonzeros_S_bftrain, relative_err_bftrain \
        = metrics.values()
fro_norm_L_accaltproj, mse_S_accaltproj, fro_norm_S_accaltproj, count_nonzeros_S_accaltproj, relative_err_accaltproj \
    = list(get_metrics(test, out_accaltproj_ontest, out_bftrain_ontest, out_hat_ontest).values())[:5]

fig, ax = plt.subplots()
ax.boxplot([relative_err_old, relative_err_new, relative_err_bftrain, relative_err_accaltproj], notch = True)
ax.set_xticklabels(["relative_err_old", "relative_err_new", "relative_err_bftrain", "relative_err_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_L_old, fro_norm_L_new, fro_norm_L_bftrain, fro_norm_L_accaltproj], notch = True)
ax.set_xticklabels(["fro_norm_L_old", "fro_norm_L_new", "fro_norm_L_bfaftrain", "fro_norm_L_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([mse_S_old, mse_S_new, mse_S_bftrain, mse_S_accaltproj], notch = True)
ax.set_xticklabels(["mse_S_old", "mse_S_new", "mse_S_bfaftrain", "mse_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_S_old, fro_norm_S_new, fro_norm_S_bftrain, fro_norm_S_accaltproj], notch = True)
ax.set_xticklabels(["fro_norm_S_old", "fro_norm_S_new", "fro_norm_S_bfaftrain", "fro_norm_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([count_nonzeros_S_old, count_nonzeros_S_new, count_nonzeros_S_bftrain, count_nonzeros_S_accaltproj], notch = True)
ax.set_xticklabels(["count_nonzeros_S_old", "count_nonzeros_S_new", "count_nonzeros_S_bfaftrain", "count_nonzeros_S_accaltproj"])
plt.show()
# Out:
# /Users/elitanzc/Github/FYP/helper.py:254: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat1 = (torch.tensor(mat1) == 0)
# /Users/elitanzc/Github/FYP/helper.py:255: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat2 = (torch.tensor(mat2) == 0)

# %%
print("P-values from test of mean with H1: _new < _old")
print("relative_err_new, relative_err_old: ", stats.ttest_rel(relative_err_new, relative_err_old, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_old, alternative='less').pvalue)
print("mse_S_new, mse_S_old: ", stats.ttest_rel(mse_S_new, mse_S_old, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_old, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_old, alternative='less').pvalue)
print()
print("P-values from test of mean with H1: _new < _accaltproj")
print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(relative_err_new, relative_err_accaltproj, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_accaltproj, alternative='less').pvalue)
print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(mse_S_new, mse_S_accaltproj, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_accaltproj, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_accaltproj, alternative='less').pvalue)
print()
print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(relative_err_new, relative_err_bftrain, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_bftrain, alternative='less').pvalue)
print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(mse_S_new, mse_S_bftrain, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_bftrain, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_bftrain, alternative='less').pvalue)

# print("*Note: values are log-transformed before deriving p-values")
# print()
# print("relative_err_new, relative_err_old: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_old), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_old), alternative='less').pvalue)
# print("mse_S_new, mse_S_old: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_old), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_old), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_old), alternative='less').pvalue)
# print()
# print("P-values from test of mean with H1: _new < _accaltproj")
# print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_accaltproj), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_accaltproj), alternative='less').pvalue)
# print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_accaltproj), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_accaltproj), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_accaltproj), alternative='less').pvalue)
# print()
# print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_bftrain), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_bftrain), alternative='less').pvalue)
# print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_bftrain), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_bftrain), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_bftrain), alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new < _old
# relative_err_new, relative_err_old:  1.7715138883136574e-17
# fro_norm_L_new, fro_norm_L_old:  0.552254532928856
# mse_S_new, mse_S_old:  9.41569530048597e-06
# fro_norm_S_new, fro_norm_S_old:  1.0563448462247925e-19
# count_nonzeros_S_new, count_nonzeros_S_old:  9.720055498086535e-27
#
# P-values from test of mean with H1: _new < _accaltproj
# relative_err_new, relative_err_accaltproj:  5.2557668946730994e-33
# fro_norm_L_new, fro_norm_L_accaltproj:  1.350833418865009e-14
# mse_S_new, mse_S_accaltproj:  7.344589131035352e-23
# fro_norm_S_new, fro_norm_S_accaltproj:  4.923429575666746e-30
# count_nonzeros_S_new, count_nonzeros_S_accaltproj:  7.110427658818149e-25
#
# relative_err_new, relative_err_bftrain:  1.0
# fro_norm_L_new, fro_norm_L_bftrain:  3.508462148892859e-38
# mse_S_new, mse_S_bftrain:  5.065987085698776e-21
# fro_norm_S_new, fro_norm_S_bftrain:  7.527612788463888e-49
# count_nonzeros_S_new, count_nonzeros_S_bftrain:  2.9829945799497826e-121

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_old[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_old[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_old[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_old[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err, \
     "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/3102520907.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 11/120 outliers
# fro_norm_L: 4/120 outliers
# mse_S: 24/120 outliers
# fro_norm_S: 21/120 outliers
# count_nonzeros_S: 0/120 outliers

# %%
print("P-values from test of mean with H1: _new/_old < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_old < 1
# relative_err:  2.986236258221441e-24
# fro_norm_L:  0.997839137490733
# mse_S:  1.0668526860547295e-10
# fro_norm_S:  5.784417225062791e-30
# count_nonzeros_S:  nan

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_accaltproj[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_accaltproj[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_accaltproj[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_accaltproj[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err, \
     "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/3730118138.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 5/120 outliers
# fro_norm_L: 6/120 outliers
# mse_S: 17/120 outliers
# fro_norm_S: 3/120 outliers
# count_nonzeros_S: 0/120 outliers

# %%
print("P-values from test of mean with H1: _new/_accaltproj < 1")
#print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_accaltproj < 1
# relative_err:  1.2421076841042095e-40
# fro_norm_L:  5.829176662018734e-13
# mse_S:  4.5792325209586757e-42
# fro_norm_S:  5.291709499273532e-45
# count_nonzeros_S:  nan

# %%
print(np.median(count_nonzeros_S_new), np.mean(count_nonzeros_S_new), np.max(count_nonzeros_S_new))
print(np.median(count_nonzeros_S_accaltproj), np.mean(count_nonzeros_S_accaltproj), np.max(count_nonzeros_S_accaltproj))
# Out:
# 0.0 4.5333336e-06 4.8e-05
# 1.6e-05 2.4133335e-05 6.4e-05

# %% [markdown]
# ### Scenario 2:
# **alpha = 0.3** (higher sparsity), **c = 1**, r = 2, dimension = 250x250
#
# gamma=7.433e-01,; beta=5.649e-02

# %%
## ======================== 0. set constants ========================
#d1 = 250                   # num. of rows
#d2 = 250                   # num. of columns
#max_iter = 100              # num. of layers trained
alpha_true = 0.3
c_true = 1
#r = 2
#dataset_size = 300

## ======================== 1. generate data ========================
train2, test2 =  generate_train_test(dataset_size, r, d1, d2, alpha_true, c_true)
# Out:
# train dataset size: 180
# test dataset size: 120

# %% [markdown]
# #### Training

# %%
## ======================== 2. estimations by classical ========================
train_est2 = []
for i, (L_true, S_true, M_true) in enumerate(train2):
    loss, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    train_est2.append((L0, S0, M_true))

# %%
## ======================== 3. train unrolled network with estimated data ========================
net2, params_bftrain2, params_aftrain2, l0_norm_of_S_Shat2 = train_nn(LearnedAAP(max_iter, d1, d2), r \
                                                                    , lr=7e-03, weight_decay=0 \
                                                                    , nepochs=8, dataset=train_est2)
# Out:
# [Parameter containing:
# tensor(7.070e-01, requires_grad=True), Parameter containing:
# tensor(3.862e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.413e-05) tensor(-1.621e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.233776970366307e-06
# [Parameter containing:
# tensor(7.027e-01, requires_grad=True), Parameter containing:
# tensor(3.463e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.467e-05) tensor(6.875e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.3535277427508845e-07
# [Parameter containing:
# tensor(7.023e-01, requires_grad=True), Parameter containing:
# tensor(3.457e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.672e-05) tensor(-4.761e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.344047953163681e-07
# [Parameter containing:
# tensor(7.009e-01, requires_grad=True), Parameter containing:
# tensor(3.344e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.282e-05) tensor(2.336e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.3951483879282023e-07
# [Parameter containing:
# tensor(7.001e-01, requires_grad=True), Parameter containing:
# tensor(3.284e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.845e-06) tensor(-7.994e-06, dtype=torch.float64)
# Epoch 1/8 at cost=4.7080942522370606e-07
# [Parameter containing:
# tensor(7.006e-01, requires_grad=True), Parameter containing:
# tensor(3.361e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.013e-05) tensor(-3.229e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.11580196871364e-07
# [Parameter containing:
# tensor(7.018e-01, requires_grad=True), Parameter containing:
# tensor(3.516e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.371e-05) tensor(-2.482e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.630827620781929e-07
# [Parameter containing:
# tensor(7.021e-01, requires_grad=True), Parameter containing:
# tensor(3.577e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.057e-05) tensor(2.065e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.4666170500277076e-07
# [Parameter containing:
# tensor(7.033e-01, requires_grad=True), Parameter containing:
# tensor(3.717e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.647e-05) tensor(-2.618e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.96358211421466e-07
# [Parameter containing:
# tensor(7.059e-01, requires_grad=True), Parameter containing:
# tensor(3.986e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.728e-05) tensor(-5.436e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.26132782347122e-07
# [Parameter containing:
# tensor(7.056e-01, requires_grad=True), Parameter containing:
# tensor(3.986e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.361e-05) tensor(8.316e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.390402293414809e-07
# [Parameter containing:
# tensor(7.044e-01, requires_grad=True), Parameter containing:
# tensor(3.900e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.240e-05) tensor(3.730e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.684731950670539e-07
# [Parameter containing:
# tensor(7.054e-01, requires_grad=True), Parameter containing:
# tensor(4.019e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.055e-04) tensor(-9.557e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.02730460488965e-07
# [Parameter containing:
# tensor(7.050e-01, requires_grad=True), Parameter containing:
# tensor(3.994e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.905e-05) tensor(6.949e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.085538532512146e-07
# [Parameter containing:
# tensor(7.036e-01, requires_grad=True), Parameter containing:
# tensor(3.875e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.375e-05) tensor(5.638e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.6554282562283333e-07
# [Parameter containing:
# tensor(7.017e-01, requires_grad=True), Parameter containing:
# tensor(3.712e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.643e-05) tensor(3.344e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.1808735318227264e-07
# [Parameter containing:
# tensor(6.998e-01, requires_grad=True), Parameter containing:
# tensor(3.535e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.796e-05) tensor(1.707e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.1929550914355787e-07
# [Parameter containing:
# tensor(6.985e-01, requires_grad=True), Parameter containing:
# tensor(3.422e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.697e-05) tensor(-2.706e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.1546818541319226e-06
# [Parameter containing:
# tensor(6.977e-01, requires_grad=True), Parameter containing:
# tensor(3.372e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.874e-05) tensor(-2.998e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.1576125820720335e-06
# [Parameter containing:
# tensor(6.976e-01, requires_grad=True), Parameter containing:
# tensor(3.387e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.311e-05) tensor(-3.447e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.8886150883190567e-06
# [Parameter containing:
# tensor(6.978e-01, requires_grad=True), Parameter containing:
# tensor(3.429e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.665e-05) tensor(-1.724e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.407960419594019e-07
# [Parameter containing:
# tensor(6.981e-01, requires_grad=True), Parameter containing:
# tensor(3.496e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.556e-05) tensor(-1.601e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.780000146340171e-07
# [Parameter containing:
# tensor(6.988e-01, requires_grad=True), Parameter containing:
# tensor(3.589e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.847e-05) tensor(-1.856e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.4086212369620625e-07
# [Parameter containing:
# tensor(6.992e-01, requires_grad=True), Parameter containing:
# tensor(3.657e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.180e-06) tensor(9.079e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.0077629752913708e-07
# [Parameter containing:
# tensor(6.989e-01, requires_grad=True), Parameter containing:
# tensor(3.648e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.208e-05) tensor(4.013e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.2648051495034451e-07
# [Parameter containing:
# tensor(6.991e-01, requires_grad=True), Parameter containing:
# tensor(3.689e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.941e-05) tensor(-2.808e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.907727261776017e-07
# [Parameter containing:
# tensor(7.004e-01, requires_grad=True), Parameter containing:
# tensor(3.837e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.928e-05) tensor(-6.571e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.919991051290708e-07
# [Parameter containing:
# tensor(7.026e-01, requires_grad=True), Parameter containing:
# tensor(4.070e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.697e-05) tensor(-6.096e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.187950312621979e-07
# [Parameter containing:
# tensor(7.051e-01, requires_grad=True), Parameter containing:
# tensor(4.332e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.607e-05) tensor(-3.132e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.2518108860604116e-06
# [Parameter containing:
# tensor(7.063e-01, requires_grad=True), Parameter containing:
# tensor(4.476e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.508e-05) tensor(5.357e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.902465088387544e-07
# [Parameter containing:
# tensor(7.059e-01, requires_grad=True), Parameter containing:
# tensor(4.471e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.035e-04) tensor(8.140e-05, dtype=torch.float64)
# Epoch 1/8 at cost=8.396237944907625e-07
# [Parameter containing:
# tensor(7.042e-01, requires_grad=True), Parameter containing:
# tensor(4.353e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.322e-05) tensor(7.393e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.048725948749052e-06
# [Parameter containing:
# tensor(7.022e-01, requires_grad=True), Parameter containing:
# tensor(4.201e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.669e-05) tensor(2.958e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.873155094424874e-07
# [Parameter containing:
# tensor(7.007e-01, requires_grad=True), Parameter containing:
# tensor(4.088e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.995e-05) tensor(-1.680e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.0593758399154467e-07
# [Parameter containing:
# tensor(6.985e-01, requires_grad=True), Parameter containing:
# tensor(3.916e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.336e-05) tensor(4.581e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.2065232485601882e-07
# [Parameter containing:
# tensor(6.973e-01, requires_grad=True), Parameter containing:
# tensor(3.828e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.874e-05) tensor(-4.349e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.857126896240516e-07
# [Parameter containing:
# tensor(6.969e-01, requires_grad=True), Parameter containing:
# tensor(3.830e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.617e-05) tensor(-5.118e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.476609660741815e-07
# [Parameter containing:
# tensor(6.973e-01, requires_grad=True), Parameter containing:
# tensor(3.893e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.398e-05) tensor(-4.014e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.054760213672125e-07
# [Parameter containing:
# tensor(6.981e-01, requires_grad=True), Parameter containing:
# tensor(4.007e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.060e-05) tensor(-3.653e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.248582629566954e-07
# [Parameter containing:
# tensor(6.988e-01, requires_grad=True), Parameter containing:
# tensor(4.102e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.810e-06) tensor(5.955e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.1460531368356897e-07
# [Parameter containing:
# tensor(7.002e-01, requires_grad=True), Parameter containing:
# tensor(4.265e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.834e-05) tensor(-4.969e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.8736576496157795e-07
# [Parameter containing:
# tensor(7.022e-01, requires_grad=True), Parameter containing:
# tensor(4.478e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.198e-05) tensor(-4.296e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.437801529391436e-06
# [Parameter containing:
# tensor(7.029e-01, requires_grad=True), Parameter containing:
# tensor(4.578e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.493e-05) tensor(5.879e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.776009857072495e-07
# [Parameter containing:
# tensor(7.028e-01, requires_grad=True), Parameter containing:
# tensor(4.597e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.793e-05) tensor(4.482e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.204645271485788e-07
# [Parameter containing:
# tensor(7.018e-01, requires_grad=True), Parameter containing:
# tensor(4.539e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.423e-05) tensor(4.940e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.991672082927835e-07
# [Parameter containing:
# tensor(6.998e-01, requires_grad=True), Parameter containing:
# tensor(4.382e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.799e-05) tensor(6.850e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.289908244776598e-07
# [Parameter containing:
# tensor(6.968e-01, requires_grad=True), Parameter containing:
# tensor(4.136e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.926e-05) tensor(7.165e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.790767439364572e-07
# [Parameter containing:
# tensor(6.948e-01, requires_grad=True), Parameter containing:
# tensor(3.981e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.258e-05) tensor(-4.450e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.953076881974994e-07
# [Parameter containing:
# tensor(6.930e-01, requires_grad=True), Parameter containing:
# tensor(3.840e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.098e-07) tensor(-4.336e-07, dtype=torch.float64)
# Epoch 1/8 at cost=9.472892088524532e-07
# [Parameter containing:
# tensor(6.920e-01, requires_grad=True), Parameter containing:
# tensor(3.775e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.565e-05) tensor(-4.021e-05, dtype=torch.float64)
# Epoch 1/8 at cost=0.0009244594257324934
# [Parameter containing:
# tensor(6.915e-01, requires_grad=True), Parameter containing:
# tensor(3.760e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.133e-05) tensor(-2.906e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.560170610711793e-07
# [Parameter containing:
# tensor(6.912e-01, requires_grad=True), Parameter containing:
# tensor(3.760e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.511e-06) tensor(-8.651e-06, dtype=torch.float64)
# Epoch 1/8 at cost=4.36575248841109e-07
# [Parameter containing:
# tensor(6.913e-01, requires_grad=True), Parameter containing:
# tensor(3.807e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.243e-05) tensor(-2.990e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.9839541209876188e-07
# [Parameter containing:
# tensor(6.917e-01, requires_grad=True), Parameter containing:
# tensor(3.881e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.236e-05) tensor(-2.046e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.0538809647187009e-06
# [Parameter containing:
# tensor(6.925e-01, requires_grad=True), Parameter containing:
# tensor(3.985e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.620e-05) tensor(-2.336e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.578720561061346e-07
# [Parameter containing:
# tensor(6.934e-01, requires_grad=True), Parameter containing:
# tensor(4.101e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.593e-05) tensor(-1.415e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.1997540241281968e-06
# [Parameter containing:
# tensor(6.944e-01, requires_grad=True), Parameter containing:
# tensor(4.231e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.795e-05) tensor(-1.526e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.205716888667666e-07
# [Parameter containing:
# tensor(6.957e-01, requires_grad=True), Parameter containing:
# tensor(4.374e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.876e-05) tensor(-1.554e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.26865154470579e-06
# [Parameter containing:
# tensor(6.968e-01, requires_grad=True), Parameter containing:
# tensor(4.506e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.948e-06) tensor(-1.402e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.8847903504592978e-07
# [Parameter containing:
# tensor(6.974e-01, requires_grad=True), Parameter containing:
# tensor(4.590e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.865e-05) tensor(2.204e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.4681557420080935e-07
# [Parameter containing:
# tensor(6.975e-01, requires_grad=True), Parameter containing:
# tensor(4.618e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.747e-05) tensor(2.869e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.732177731308184e-07
# [Parameter containing:
# tensor(6.980e-01, requires_grad=True), Parameter containing:
# tensor(4.685e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.357e-05) tensor(-2.518e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.500279828789644e-07
# [Parameter containing:
# tensor(6.977e-01, requires_grad=True), Parameter containing:
# tensor(4.681e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.280e-05) tensor(3.928e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.6539187792404846e-07
# [Parameter containing:
# tensor(6.986e-01, requires_grad=True), Parameter containing:
# tensor(4.777e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.179e-05) tensor(-6.096e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.790270958845213e-07
# [Parameter containing:
# tensor(6.992e-01, requires_grad=True), Parameter containing:
# tensor(4.861e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.014e-06) tensor(2.161e-06, dtype=torch.float64)
# Epoch 1/8 at cost=0.0006107244989834726
# [Parameter containing:
# tensor(6.988e-01, requires_grad=True), Parameter containing:
# tensor(4.844e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.682e-05) tensor(5.574e-05, dtype=torch.float64)
# Epoch 1/8 at cost=8.253149985648633e-07
# [Parameter containing:
# tensor(6.977e-01, requires_grad=True), Parameter containing:
# tensor(4.775e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.529e-05) tensor(3.288e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.375111816694698e-07
# [Parameter containing:
# tensor(6.978e-01, requires_grad=True), Parameter containing:
# tensor(4.801e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.333e-05) tensor(-5.389e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.1809360103143263e-06
# [Parameter containing:
# tensor(6.967e-01, requires_grad=True), Parameter containing:
# tensor(4.724e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.511e-05) tensor(6.178e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.694319161695603e-07
# [Parameter containing:
# tensor(6.947e-01, requires_grad=True), Parameter containing:
# tensor(4.565e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.585e-05) tensor(5.595e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.342963961789792e-07
# [Parameter containing:
# tensor(6.934e-01, requires_grad=True), Parameter containing:
# tensor(4.467e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.742e-05) tensor(-2.842e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.2409558653180284e-07
# [Parameter containing:
# tensor(6.930e-01, requires_grad=True), Parameter containing:
# tensor(4.446e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.284e-05) tensor(-4.105e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.9993119571590796e-07
# [Parameter containing:
# tensor(6.929e-01, requires_grad=True), Parameter containing:
# tensor(4.462e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.788e-05) tensor(-2.190e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.845064141700277e-07
# [Parameter containing:
# tensor(6.932e-01, requires_grad=True), Parameter containing:
# tensor(4.506e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.247e-05) tensor(-1.756e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.8708990384984645e-07
# [Parameter containing:
# tensor(6.933e-01, requires_grad=True), Parameter containing:
# tensor(4.525e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.583e-05) tensor(1.232e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.639963849394917e-08
# [Parameter containing:
# tensor(6.939e-01, requires_grad=True), Parameter containing:
# tensor(4.598e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.385e-05) tensor(-3.352e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.852230060554575e-07
# [Parameter containing:
# tensor(6.951e-01, requires_grad=True), Parameter containing:
# tensor(4.722e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.600e-05) tensor(-3.481e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.065045343144448e-07
# [Parameter containing:
# tensor(6.969e-01, requires_grad=True), Parameter containing:
# tensor(4.893e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.862e-05) tensor(-3.632e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.71929837431162e-07
# [Parameter containing:
# tensor(6.973e-01, requires_grad=True), Parameter containing:
# tensor(4.946e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.553e-05) tensor(6.098e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.610730345826596e-07
# [Parameter containing:
# tensor(6.959e-01, requires_grad=True), Parameter containing:
# tensor(4.846e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.291e-04) tensor(9.090e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.159242846275447e-07
# [Parameter containing:
# tensor(6.942e-01, requires_grad=True), Parameter containing:
# tensor(4.714e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.548e-05) tensor(2.532e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.3919002956063196e-07
# [Parameter containing:
# tensor(6.923e-01, requires_grad=True), Parameter containing:
# tensor(4.556e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.194e-05) tensor(2.376e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.6636703864824085e-07
# [Parameter containing:
# tensor(6.910e-01, requires_grad=True), Parameter containing:
# tensor(4.467e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.175e-05) tensor(-3.229e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.000028873932024e-06
# [Parameter containing:
# tensor(6.903e-01, requires_grad=True), Parameter containing:
# tensor(4.419e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.608e-05) tensor(-2.024e-05, dtype=torch.float64)
# Epoch 1/8 at cost=8.896243457456876e-07
# [Parameter containing:
# tensor(6.900e-01, requires_grad=True), Parameter containing:
# tensor(4.409e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.612e-05) tensor(-2.038e-05, dtype=torch.float64)
# Epoch 1/8 at cost=8.599302532275033e-07
# [Parameter containing:
# tensor(6.901e-01, requires_grad=True), Parameter containing:
# tensor(4.437e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.811e-05) tensor(-2.195e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.7044593505488592e-06
# [Parameter containing:
# tensor(6.904e-01, requires_grad=True), Parameter containing:
# tensor(4.489e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.020e-05) tensor(-1.602e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.2918205527512328e-07
# [Parameter containing:
# tensor(6.911e-01, requires_grad=True), Parameter containing:
# tensor(4.564e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.203e-05) tensor(-1.702e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.7588819168377086e-07
# [Parameter containing:
# tensor(6.919e-01, requires_grad=True), Parameter containing:
# tensor(4.662e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.372e-05) tensor(-1.800e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.6781594069925632e-07
# [Parameter containing:
# tensor(6.932e-01, requires_grad=True), Parameter containing:
# tensor(4.795e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.494e-05) tensor(-2.609e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.580943766541168e-07
# [Parameter containing:
# tensor(6.949e-01, requires_grad=True), Parameter containing:
# tensor(4.955e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.310e-05) tensor(-2.391e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.51486670272061e-07
# [Parameter containing:
# tensor(6.956e-01, requires_grad=True), Parameter containing:
# tensor(5.040e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.970e-05) tensor(3.503e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.5207588666708034e-07
# [Parameter containing:
# tensor(6.955e-01, requires_grad=True), Parameter containing:
# tensor(5.045e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.101e-05) tensor(4.221e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.1228365199021937e-07
# [Parameter containing:
# tensor(6.943e-01, requires_grad=True), Parameter containing:
# tensor(4.957e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.968e-05) tensor(5.505e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.5563084566092584e-07
# [Parameter containing:
# tensor(6.925e-01, requires_grad=True), Parameter containing:
# tensor(4.824e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.545e-05) tensor(3.142e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.48482156166574e-05
# [Parameter containing:
# tensor(6.914e-01, requires_grad=True), Parameter containing:
# tensor(4.747e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.555e-05) tensor(-2.517e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.622425641784503e-07
# [Parameter containing:
# tensor(6.915e-01, requires_grad=True), Parameter containing:
# tensor(4.768e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.370e-05) tensor(-5.381e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.7056756241327093e-07
# [Parameter containing:
# tensor(6.919e-01, requires_grad=True), Parameter containing:
# tensor(4.822e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.745e-05) tensor(-1.990e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.749513883936743e-07
# [Parameter containing:
# tensor(6.932e-01, requires_grad=True), Parameter containing:
# tensor(4.951e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.654e-05) tensor(-4.789e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.033899009911693e-07
# [Parameter containing:
# tensor(6.948e-01, requires_grad=True), Parameter containing:
# tensor(5.107e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.308e-05) tensor(-2.319e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.841063349023898e-07
# [Parameter containing:
# tensor(6.953e-01, requires_grad=True), Parameter containing:
# tensor(5.162e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.390e-05) tensor(5.043e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.9864488599050674e-07
# [Parameter containing:
# tensor(6.950e-01, requires_grad=True), Parameter containing:
# tensor(5.154e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.976e-05) tensor(3.348e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.9905095288995653e-07
# [Parameter containing:
# tensor(6.950e-01, requires_grad=True), Parameter containing:
# tensor(5.174e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.276e-05) tensor(-1.558e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.5009111343242694e-07
# [Parameter containing:
# tensor(6.960e-01, requires_grad=True), Parameter containing:
# tensor(5.265e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.419e-05) tensor(-4.304e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.688153580900689e-07
# [Parameter containing:
# tensor(6.956e-01, requires_grad=True), Parameter containing:
# tensor(5.249e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.692e-05) tensor(5.750e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.481226139636419e-07
# [Parameter containing:
# tensor(6.945e-01, requires_grad=True), Parameter containing:
# tensor(5.170e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.650e-05) tensor(3.759e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.7464041585953964e-07
# [Parameter containing:
# tensor(6.945e-01, requires_grad=True), Parameter containing:
# tensor(5.182e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.181e-05) tensor(-4.856e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.848309001521557e-07
# [Parameter containing:
# tensor(6.952e-01, requires_grad=True), Parameter containing:
# tensor(5.250e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.920e-05) tensor(-3.356e-05, dtype=torch.float64)
# Epoch 1/8 at cost=0.00011528823961270973
# [Parameter containing:
# tensor(6.970e-01, requires_grad=True), Parameter containing:
# tensor(5.409e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.768e-05) tensor(-5.798e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.886066436592955e-07
# [Parameter containing:
# tensor(6.973e-01, requires_grad=True), Parameter containing:
# tensor(5.451e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.151e-05) tensor(5.970e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.793331752101949e-07
# [Parameter containing:
# tensor(6.962e-01, requires_grad=True), Parameter containing:
# tensor(5.369e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.115e-04) tensor(7.149e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.674441467817815e-07
# [Parameter containing:
# tensor(6.946e-01, requires_grad=True), Parameter containing:
# tensor(5.244e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.720e-05) tensor(3.057e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.0141105728253024e-07
# [Parameter containing:
# tensor(6.928e-01, requires_grad=True), Parameter containing:
# tensor(5.108e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.065e-05) tensor(1.360e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.0626932812083396e-07
# [Parameter containing:
# tensor(6.911e-01, requires_grad=True), Parameter containing:
# tensor(4.977e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.826e-06) tensor(5.278e-06, dtype=torch.float64)
# Epoch 1/8 at cost=2.707971020754485e-07
# [Parameter containing:
# tensor(6.891e-01, requires_grad=True), Parameter containing:
# tensor(4.814e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.683e-05) tensor(2.565e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.3094077644382196e-07
# [Parameter containing:
# tensor(6.872e-01, requires_grad=True), Parameter containing:
# tensor(4.663e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.105e-06) tensor(2.890e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.3637504991947935e-07
# [Parameter containing:
# tensor(6.861e-01, requires_grad=True), Parameter containing:
# tensor(4.574e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.806e-05) tensor(-2.814e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.967066390941909e-07
# [Parameter containing:
# tensor(6.854e-01, requires_grad=True), Parameter containing:
# tensor(4.529e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.721e-05) tensor(-2.037e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.956389716426202e-07
# [Parameter containing:
# tensor(6.850e-01, requires_grad=True), Parameter containing:
# tensor(4.512e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.805e-05) tensor(-1.391e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.2645772358155227e-06
# [Parameter containing:
# tensor(6.848e-01, requires_grad=True), Parameter containing:
# tensor(4.518e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.642e-05) tensor(-1.252e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.6622831228451105e-07
# [Parameter containing:
# tensor(6.849e-01, requires_grad=True), Parameter containing:
# tensor(4.542e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.422e-05) tensor(-1.080e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.995466381136794e-07
# [Parameter containing:
# tensor(6.852e-01, requires_grad=True), Parameter containing:
# tensor(4.583e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.479e-05) tensor(-1.112e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.729609829861147e-07
# [Parameter containing:
# tensor(6.857e-01, requires_grad=True), Parameter containing:
# tensor(4.648e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.112e-05) tensor(-1.601e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.295021641264611e-07
# [Parameter containing:
# tensor(6.866e-01, requires_grad=True), Parameter containing:
# tensor(4.752e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.447e-05) tensor(-2.589e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.2443920190416975e-06
# [Parameter containing:
# tensor(6.883e-01, requires_grad=True), Parameter containing:
# tensor(4.916e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.641e-05) tensor(-4.072e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.3310698199784383e-07
# [Parameter containing:
# tensor(6.907e-01, requires_grad=True), Parameter containing:
# tensor(5.153e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.314e-05) tensor(-5.124e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.477432859559485e-07
# [Parameter containing:
# tensor(6.938e-01, requires_grad=True), Parameter containing:
# tensor(5.444e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.618e-05) tensor(-4.504e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.213729314666125e-06
# [Parameter containing:
# tensor(6.959e-01, requires_grad=True), Parameter containing:
# tensor(5.655e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.740e-05) tensor(2.991e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.3139323224750115e-07
# [Parameter containing:
# tensor(6.970e-01, requires_grad=True), Parameter containing:
# tensor(5.775e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.404e-05) tensor(3.965e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.332474526971055e-07
# [Parameter containing:
# tensor(6.972e-01, requires_grad=True), Parameter containing:
# tensor(5.829e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.166e-05) tensor(3.143e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.848931436958082e-07
# [Parameter containing:
# tensor(6.959e-01, requires_grad=True), Parameter containing:
# tensor(5.754e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.185e-04) tensor(7.102e-05, dtype=torch.float64)
# Epoch 1/8 at cost=8.29910675292922e-07
# [Parameter containing:
# tensor(6.931e-01, requires_grad=True), Parameter containing:
# tensor(5.564e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.187e-04) tensor(7.207e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.168545153035666e-07
# [Parameter containing:
# tensor(6.896e-01, requires_grad=True), Parameter containing:
# tensor(5.304e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.296e-05) tensor(5.180e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.085439115897316e-07
# [Parameter containing:
# tensor(6.866e-01, requires_grad=True), Parameter containing:
# tensor(5.086e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.556e-05) tensor(-9.900e-06, dtype=torch.float64)
# Epoch 1/8 at cost=2.3807629645489214e-07
# [Parameter containing:
# tensor(6.843e-01, requires_grad=True), Parameter containing:
# tensor(4.922e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.709e-05) tensor(-1.853e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.3382792114243784e-07
# [Parameter containing:
# tensor(6.823e-01, requires_grad=True), Parameter containing:
# tensor(4.792e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.541e-05) tensor(-1.072e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.629645667999284e-07
# [Parameter containing:
# tensor(6.809e-01, requires_grad=True), Parameter containing:
# tensor(4.704e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.407e-05) tensor(-1.724e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.983773689877125e-07
# [Parameter containing:
# tensor(6.799e-01, requires_grad=True), Parameter containing:
# tensor(4.650e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.981e-05) tensor(-1.442e-05, dtype=torch.float64)
# Epoch 1/8 at cost=7.589455321976857e-07
# [Parameter containing:
# tensor(6.791e-01, requires_grad=True), Parameter containing:
# tensor(4.615e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.018e-05) tensor(-7.706e-06, dtype=torch.float64)
# Epoch 1/8 at cost=9.752646974447998e-07
# [Parameter containing:
# tensor(6.787e-01, requires_grad=True), Parameter containing:
# tensor(4.610e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.057e-05) tensor(-1.523e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.272127279771667e-07
# [Parameter containing:
# tensor(6.784e-01, requires_grad=True), Parameter containing:
# tensor(4.616e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.407e-06) tensor(-6.405e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.0461059218869195e-06
# [Parameter containing:
# tensor(6.783e-01, requires_grad=True), Parameter containing:
# tensor(4.639e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.288e-05) tensor(-9.461e-06, dtype=torch.float64)
# Epoch 1/8 at cost=3.982964642545994e-07
# [Parameter containing:
# tensor(6.784e-01, requires_grad=True), Parameter containing:
# tensor(4.677e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.257e-05) tensor(-9.624e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.0423624416944222e-06
# [Parameter containing:
# tensor(6.786e-01, requires_grad=True), Parameter containing:
# tensor(4.713e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.264e-06) tensor(-1.163e-06, dtype=torch.float64)
# Epoch 1/8 at cost=8.873287811184127e-07
# [Parameter containing:
# tensor(6.788e-01, requires_grad=True), Parameter containing:
# tensor(4.763e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.393e-05) tensor(-1.012e-05, dtype=torch.float64)
# Epoch 1/8 at cost=8.998393923320691e-07
# [Parameter containing:
# tensor(6.794e-01, requires_grad=True), Parameter containing:
# tensor(4.841e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.461e-05) tensor(-1.780e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.7014185687003192e-06
# [Parameter containing:
# tensor(6.803e-01, requires_grad=True), Parameter containing:
# tensor(4.945e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.710e-05) tensor(-1.900e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.8911741739866557e-07
# [Parameter containing:
# tensor(6.813e-01, requires_grad=True), Parameter containing:
# tensor(5.054e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.229e-05) tensor(-8.495e-06, dtype=torch.float64)
# Epoch 1/8 at cost=7.614925721100008e-07
# [Parameter containing:
# tensor(6.824e-01, requires_grad=True), Parameter containing:
# tensor(5.169e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.353e-05) tensor(-9.124e-06, dtype=torch.float64)
# Epoch 1/8 at cost=6.083120638322725e-07
# [Parameter containing:
# tensor(6.836e-01, requires_grad=True), Parameter containing:
# tensor(5.296e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.894e-05) tensor(-1.251e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.6615313092625e-07
# [Parameter containing:
# tensor(6.850e-01, requires_grad=True), Parameter containing:
# tensor(5.439e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.386e-05) tensor(-1.564e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.117131879866065e-07
# [Parameter containing:
# tensor(6.867e-01, requires_grad=True), Parameter containing:
# tensor(5.600e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.819e-05) tensor(-1.780e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.7190085916117823e-07
# [Parameter containing:
# tensor(6.889e-01, requires_grad=True), Parameter containing:
# tensor(5.794e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.702e-05) tensor(-2.651e-05, dtype=torch.float64)
# Epoch 1/8 at cost=0.00019381559104658663
# [Parameter containing:
# tensor(6.902e-01, requires_grad=True), Parameter containing:
# tensor(5.921e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.409e-05) tensor(2.623e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.0739844330819324e-07
# [Parameter containing:
# tensor(6.908e-01, requires_grad=True), Parameter containing:
# tensor(5.987e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.490e-05) tensor(2.620e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.36917935328529e-07
# [Parameter containing:
# tensor(6.902e-01, requires_grad=True), Parameter containing:
# tensor(5.951e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.455e-05) tensor(5.222e-05, dtype=torch.float64)
# Epoch 1/8 at cost=0.0014941757544875145
# [Parameter containing:
# tensor(6.891e-01, requires_grad=True), Parameter containing:
# tensor(5.876e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.035e-05) tensor(2.343e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.953921350330347e-07
# [Parameter containing:
# tensor(6.888e-01, requires_grad=True), Parameter containing:
# tensor(5.869e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.634e-05) tensor(-3.315e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.3918581721081864e-07
# [Parameter containing:
# tensor(6.887e-01, requires_grad=True), Parameter containing:
# tensor(5.869e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.484e-06) tensor(-3.842e-06, dtype=torch.float64)
# Epoch 1/8 at cost=3.2699787766432564e-07
# [Parameter containing:
# tensor(6.891e-01, requires_grad=True), Parameter containing:
# tensor(5.915e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.114e-05) tensor(-2.420e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.1615711628110148e-06
# [Parameter containing:
# tensor(6.907e-01, requires_grad=True), Parameter containing:
# tensor(6.048e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.615e-05) tensor(-5.033e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.4778175429673865e-05
# [Parameter containing:
# tensor(6.932e-01, requires_grad=True), Parameter containing:
# tensor(6.250e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.855e-05) tensor(-4.510e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.180000120068144e-07
# [Parameter containing:
# tensor(6.945e-01, requires_grad=True), Parameter containing:
# tensor(6.363e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.850e-05) tensor(3.796e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.0097000995301642e-06
# [Parameter containing:
# tensor(6.940e-01, requires_grad=True), Parameter containing:
# tensor(6.334e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.299e-04) tensor(7.118e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.640552889322862e-07
# [Parameter containing:
# tensor(6.953e-01, requires_grad=True), Parameter containing:
# tensor(6.446e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.396e-04) tensor(-7.669e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.2478987438698823e-07
# [Parameter containing:
# tensor(6.955e-01, requires_grad=True), Parameter containing:
# tensor(6.474e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.464e-05) tensor(4.063e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.372490932131768e-07
# [Parameter containing:
# tensor(6.941e-01, requires_grad=True), Parameter containing:
# tensor(6.383e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.200e-04) tensor(6.449e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.77160766524321e-07
# [Parameter containing:
# tensor(6.916e-01, requires_grad=True), Parameter containing:
# tensor(6.200e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.030e-04) tensor(5.646e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.893527147942223e-07
# [Parameter containing:
# tensor(6.884e-01, requires_grad=True), Parameter containing:
# tensor(5.969e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.784e-05) tensor(3.773e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.856355187461304e-07
# [Parameter containing:
# tensor(6.845e-01, requires_grad=True), Parameter containing:
# tensor(5.673e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.484e-05) tensor(4.923e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.62514668950098e-07
# [Parameter containing:
# tensor(6.816e-01, requires_grad=True), Parameter containing:
# tensor(5.457e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.670e-05) tensor(-2.838e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.574232997991203e-07
# [Parameter containing:
# tensor(6.793e-01, requires_grad=True), Parameter containing:
# tensor(5.294e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.830e-05) tensor(-1.766e-05, dtype=torch.float64)
# Epoch 1/8 at cost=8.287658488370653e-07
# [Parameter containing:
# tensor(6.775e-01, requires_grad=True), Parameter containing:
# tensor(5.171e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.097e-05) tensor(-1.355e-05, dtype=torch.float64)
# Epoch 1/8 at cost=5.748190119447827e-07
# [Parameter containing:
# tensor(6.762e-01, requires_grad=True), Parameter containing:
# tensor(5.081e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.742e-05) tensor(-1.169e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.0794581157824723e-06
# [Parameter containing:
# tensor(6.752e-01, requires_grad=True), Parameter containing:
# tensor(5.027e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.277e-05) tensor(-1.518e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.134314389782958e-07
# [Parameter containing:
# tensor(6.747e-01, requires_grad=True), Parameter containing:
# tensor(5.009e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.470e-05) tensor(-1.677e-05, dtype=torch.float64)
# Epoch 1/8 at cost=6.063200999051332e-07
# [Parameter containing:
# tensor(6.742e-01, requires_grad=True), Parameter containing:
# tensor(5.000e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.057e-06) tensor(-4.092e-06, dtype=torch.float64)
# Epoch 1/8 at cost=6.908466616550868e-07
# [Parameter containing:
# tensor(6.739e-01, requires_grad=True), Parameter containing:
# tensor(5.000e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.564e-06) tensor(-4.498e-06, dtype=torch.float64)
# Epoch 1/8 at cost=8.6564972434644e-07
# [Parameter containing:
# tensor(6.739e-01, requires_grad=True), Parameter containing:
# tensor(5.018e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.424e-05) tensor(-9.603e-06, dtype=torch.float64)
# Epoch 1/8 at cost=2.476730287526152e-07
# [Parameter containing:
# tensor(6.740e-01, requires_grad=True), Parameter containing:
# tensor(5.056e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.814e-05) tensor(-1.214e-05, dtype=torch.float64)
# Epoch 1/8 at cost=4.314167199481744e-06
# [Parameter containing:
# tensor(6.743e-01, requires_grad=True), Parameter containing:
# tensor(5.099e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.717e-06) tensor(-4.567e-06, dtype=torch.float64)
# Epoch 2/8 at cost=1.3998903796164086e-06
# [Parameter containing:
# tensor(6.746e-01, requires_grad=True), Parameter containing:
# tensor(5.149e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.666e-06) tensor(-5.961e-06, dtype=torch.float64)
# Epoch 2/8 at cost=8.011517707018356e-07
# [Parameter containing:
# tensor(6.751e-01, requires_grad=True), Parameter containing:
# tensor(5.209e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.266e-05) tensor(-8.364e-06, dtype=torch.float64)
# Epoch 2/8 at cost=1.3489882348949322e-06
# [Parameter containing:
# tensor(6.756e-01, requires_grad=True), Parameter containing:
# tensor(5.270e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.788e-06) tensor(-3.853e-06, dtype=torch.float64)
# Epoch 2/8 at cost=3.5227998296250007e-07
# [Parameter containing:
# tensor(6.764e-01, requires_grad=True), Parameter containing:
# tensor(5.358e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.689e-05) tensor(-1.737e-05, dtype=torch.float64)
# Epoch 2/8 at cost=7.106474413376418e-07
# [Parameter containing:
# tensor(6.773e-01, requires_grad=True), Parameter containing:
# tensor(5.456e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.614e-05) tensor(-1.013e-05, dtype=torch.float64)
# Epoch 2/8 at cost=6.625615469602053e-07
# [Parameter containing:
# tensor(6.785e-01, requires_grad=True), Parameter containing:
# tensor(5.572e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.322e-05) tensor(-1.440e-05, dtype=torch.float64)
# Epoch 2/8 at cost=5.082809479972639e-07
# [Parameter containing:
# tensor(6.797e-01, requires_grad=True), Parameter containing:
# tensor(5.693e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.494e-05) tensor(-9.048e-06, dtype=torch.float64)
# Epoch 2/8 at cost=1.4033383877176675e-07
# [Parameter containing:
# tensor(6.816e-01, requires_grad=True), Parameter containing:
# tensor(5.862e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.382e-05) tensor(-3.225e-05, dtype=torch.float64)
# Epoch 2/8 at cost=7.683592571083864e-07
# [Parameter containing:
# tensor(6.837e-01, requires_grad=True), Parameter containing:
# tensor(6.057e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.765e-05) tensor(-2.198e-05, dtype=torch.float64)
# Epoch 2/8 at cost=9.57499196374556e-07
# [Parameter containing:
# tensor(6.864e-01, requires_grad=True), Parameter containing:
# tensor(6.287e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.230e-05) tensor(-2.963e-05, dtype=torch.float64)
# Epoch 2/8 at cost=4.002605464847875e-07
# [Parameter containing:
# tensor(6.892e-01, requires_grad=True), Parameter containing:
# tensor(6.528e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.211e-05) tensor(-1.759e-05, dtype=torch.float64)
# Epoch 2/8 at cost=4.6136867126733705e-07
# [Parameter containing:
# tensor(6.934e-01, requires_grad=True), Parameter containing:
# tensor(6.871e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.290e-04) tensor(-6.804e-05, dtype=torch.float64)
# Epoch 2/8 at cost=4.7163786121018347e-07
# [Parameter containing:
# tensor(6.959e-01, requires_grad=True), Parameter containing:
# tensor(7.090e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.468e-05) tensor(4.799e-05, dtype=torch.float64)
# Epoch 2/8 at cost=1.4439032156587928e-06
# [Parameter containing:
# tensor(6.951e-01, requires_grad=True), Parameter containing:
# tensor(7.070e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.352e-04) tensor(1.159e-04, dtype=torch.float64)
# Epoch 2/8 at cost=1.9270096345280763e-06
# [Parameter containing:
# tensor(6.914e-01, requires_grad=True), Parameter containing:
# tensor(6.828e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.574e-04) tensor(1.269e-04, dtype=torch.float64)
# Epoch 2/8 at cost=1.934141664605704e-06
# [Parameter containing:
# tensor(6.866e-01, requires_grad=True), Parameter containing:
# tensor(6.499e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.246e-04) tensor(6.347e-05, dtype=torch.float64)
# Epoch 2/8 at cost=1.4112273447608459e-06
# [Parameter containing:
# tensor(6.832e-01, requires_grad=True), Parameter containing:
# tensor(6.266e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.902e-05) tensor(-3.628e-05, dtype=torch.float64)
# ...
# tensor(1.283e-01, dtype=torch.float64, requires_grad=True)]
# tensor(6.292e-05) tensor(1.599e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.8316576699817233e-07
# [Parameter containing:
# tensor(6.558e-01, requires_grad=True), Parameter containing:
# tensor(1.268e-01, dtype=torch.float64, requires_grad=True)]
# tensor(2.021e-05) tensor(5.265e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.4535734749188123e-07
# [Parameter containing:
# tensor(6.543e-01, requires_grad=True), Parameter containing:
# tensor(1.258e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.505e-05) tensor(-6.505e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.4245005053890054e-07
# [Parameter containing:
# tensor(6.533e-01, requires_grad=True), Parameter containing:
# tensor(1.250e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.333e-05) tensor(-5.992e-06, dtype=torch.float64)
# Epoch 8/8 at cost=4.3904935864702566e-07
# [Parameter containing:
# tensor(6.526e-01, requires_grad=True), Parameter containing:
# tensor(1.245e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.196e-05) tensor(-5.630e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.1996622788501554e-06
# [Parameter containing:
# tensor(6.523e-01, requires_grad=True), Parameter containing:
# tensor(1.243e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.182e-05) tensor(-5.732e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.450559293265542e-07
# [Parameter containing:
# tensor(6.522e-01, requires_grad=True), Parameter containing:
# tensor(1.243e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.050e-05) tensor(-5.306e-06, dtype=torch.float64)
# Epoch 8/8 at cost=5.665448838954035e-07
# [Parameter containing:
# tensor(6.523e-01, requires_grad=True), Parameter containing:
# tensor(1.244e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.483e-05) tensor(-4.044e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.559038646017143e-07
# [Parameter containing:
# tensor(6.525e-01, requires_grad=True), Parameter containing:
# tensor(1.246e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-7.765e-06) tensor(-2.056e-06, dtype=torch.float64)
# Epoch 8/8 at cost=9.140403562923893e-07
# [Parameter containing:
# tensor(6.530e-01, requires_grad=True), Parameter containing:
# tensor(1.249e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.303e-05) tensor(-6.157e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.219691734557273e-06
# [Parameter containing:
# tensor(6.535e-01, requires_grad=True), Parameter containing:
# tensor(1.253e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-8.788e-06) tensor(-2.284e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.645469348612096e-07
# [Parameter containing:
# tensor(6.542e-01, requires_grad=True), Parameter containing:
# tensor(1.259e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.395e-05) tensor(-6.372e-06, dtype=torch.float64)
# Epoch 8/8 at cost=8.415822208007739e-07
# [Parameter containing:
# tensor(6.552e-01, requires_grad=True), Parameter containing:
# tensor(1.267e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.413e-05) tensor(-6.500e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.509776888677152e-06
# [Parameter containing:
# tensor(6.564e-01, requires_grad=True), Parameter containing:
# tensor(1.276e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.718e-05) tensor(-7.052e-06, dtype=torch.float64)
# Epoch 8/8 at cost=7.038370313239284e-07
# [Parameter containing:
# tensor(6.580e-01, requires_grad=True), Parameter containing:
# tensor(1.288e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.955e-05) tensor(-1.010e-05, dtype=torch.float64)
# Epoch 8/8 at cost=6.313383096312464e-07
# [Parameter containing:
# tensor(6.597e-01, requires_grad=True), Parameter containing:
# tensor(1.301e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.871e-05) tensor(-7.259e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.608460872328578e-07
# [Parameter containing:
# tensor(6.608e-01, requires_grad=True), Parameter containing:
# tensor(1.309e-01, dtype=torch.float64, requires_grad=True)]
# tensor(4.325e-05) tensor(1.120e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.568234182514061e-07
# [Parameter containing:
# tensor(6.613e-01, requires_grad=True), Parameter containing:
# tensor(1.313e-01, dtype=torch.float64, requires_grad=True)]
# tensor(3.355e-05) tensor(8.527e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.5628602884353313e-07
# [Parameter containing:
# tensor(6.608e-01, requires_grad=True), Parameter containing:
# tensor(1.310e-01, dtype=torch.float64, requires_grad=True)]
# tensor(8.305e-05) tensor(2.088e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.087117962901175e-07
# [Parameter containing:
# tensor(6.601e-01, requires_grad=True), Parameter containing:
# tensor(1.305e-01, dtype=torch.float64, requires_grad=True)]
# tensor(2.169e-05) tensor(5.622e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.4866415060387226e-07
# [Parameter containing:
# tensor(6.595e-01, requires_grad=True), Parameter containing:
# tensor(1.301e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-4.212e-06) tensor(-1.129e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.946225663436053e-07
# [Parameter containing:
# tensor(6.594e-01, requires_grad=True), Parameter containing:
# tensor(1.300e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.923e-05) tensor(-1.020e-05, dtype=torch.float64)
# Epoch 8/8 at cost=4.3643237290780235e-07
# [Parameter containing:
# tensor(6.600e-01, requires_grad=True), Parameter containing:
# tensor(1.305e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-5.375e-05) tensor(-1.351e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.726826835441898e-07
# [Parameter containing:
# tensor(6.611e-01, requires_grad=True), Parameter containing:
# tensor(1.313e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-4.433e-05) tensor(-1.126e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.9591313932542107e-07
# [Parameter containing:
# tensor(6.626e-01, requires_grad=True), Parameter containing:
# tensor(1.324e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-4.388e-05) tensor(-1.071e-05, dtype=torch.float64)
# Epoch 8/8 at cost=4.827542738894408e-07
# [Parameter containing:
# tensor(6.634e-01, requires_grad=True), Parameter containing:
# tensor(1.330e-01, dtype=torch.float64, requires_grad=True)]
# tensor(4.231e-05) tensor(1.057e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.5772143291978864e-07
# [Parameter containing:
# tensor(6.643e-01, requires_grad=True), Parameter containing:
# tensor(1.336e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.109e-05) tensor(-2.531e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.134689166017779e-07
# [Parameter containing:
# tensor(6.644e-01, requires_grad=True), Parameter containing:
# tensor(1.338e-01, dtype=torch.float64, requires_grad=True)]
# tensor(5.439e-05) tensor(1.368e-05, dtype=torch.float64)
# Epoch 8/8 at cost=5.627044288303296e-07
# [Parameter containing:
# tensor(6.645e-01, requires_grad=True), Parameter containing:
# tensor(1.338e-01, dtype=torch.float64, requires_grad=True)]
# tensor(5.667e-06) tensor(1.467e-06, dtype=torch.float64)
# Epoch 8/8 at cost=4.268654834049812e-07
# [Parameter containing:
# tensor(6.636e-01, requires_grad=True), Parameter containing:
# tensor(1.332e-01, dtype=torch.float64, requires_grad=True)]
# tensor(7.524e-05) tensor(1.862e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.2624228651911835e-07
# [Parameter containing:
# tensor(6.626e-01, requires_grad=True), Parameter containing:
# tensor(1.325e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.821e-05) tensor(4.544e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.562106544701237e-07
# [Parameter containing:
# tensor(6.624e-01, requires_grad=True), Parameter containing:
# tensor(1.324e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-5.879e-05) tensor(-1.499e-05, dtype=torch.float64)
# Epoch 8/8 at cost=9.969646725949133e-07
# [Parameter containing:
# tensor(6.613e-01, requires_grad=True), Parameter containing:
# tensor(1.315e-01, dtype=torch.float64, requires_grad=True)]
# tensor(7.916e-05) tensor(1.993e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.4497000456212845e-07
# [Parameter containing:
# tensor(6.607e-01, requires_grad=True), Parameter containing:
# tensor(1.311e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.409e-05) tensor(-8.491e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.97102161539442e-07
# [Parameter containing:
# tensor(6.605e-01, requires_grad=True), Parameter containing:
# tensor(1.310e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.116e-05) tensor(-8.000e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.627193964599428e-07
# [Parameter containing:
# tensor(6.597e-01, requires_grad=True), Parameter containing:
# tensor(1.305e-01, dtype=torch.float64, requires_grad=True)]
# tensor(5.190e-05) tensor(1.308e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.1601618982458604e-07
# [Parameter containing:
# tensor(6.593e-01, requires_grad=True), Parameter containing:
# tensor(1.302e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.380e-05) tensor(-6.085e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.9257213068613055e-07
# [Parameter containing:
# tensor(6.593e-01, requires_grad=True), Parameter containing:
# tensor(1.302e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.817e-05) tensor(-7.143e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.1339120337415807e-07
# [Parameter containing:
# tensor(6.606e-01, requires_grad=True), Parameter containing:
# tensor(1.312e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-1.078e-04) tensor(-2.857e-05, dtype=torch.float64)
# Epoch 8/8 at cost=0.00019375409465283155
# [Parameter containing:
# tensor(6.617e-01, requires_grad=True), Parameter containing:
# tensor(1.321e-01, dtype=torch.float64, requires_grad=True)]
# tensor(6.549e-07) tensor(3.652e-07, dtype=torch.float64)
# Epoch 8/8 at cost=1.9869152367846254e-07
# [Parameter containing:
# tensor(6.620e-01, requires_grad=True), Parameter containing:
# tensor(1.323e-01, dtype=torch.float64, requires_grad=True)]
# tensor(6.071e-05) tensor(1.523e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.5079958732021623e-07
# [Parameter containing:
# tensor(6.606e-01, requires_grad=True), Parameter containing:
# tensor(1.310e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.408e-04) tensor(4.493e-05, dtype=torch.float64)
# Epoch 8/8 at cost=0.001494043623097241
# [Parameter containing:
# tensor(6.589e-01, requires_grad=True), Parameter containing:
# tensor(1.295e-01, dtype=torch.float64, requires_grad=True)]
# tensor(3.083e-05) tensor(7.859e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.4349898808395665e-07
# [Parameter containing:
# tensor(6.579e-01, requires_grad=True), Parameter containing:
# tensor(1.286e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-4.216e-05) tensor(-1.090e-05, dtype=torch.float64)
# Epoch 8/8 at cost=5.459260705720226e-07
# [Parameter containing:
# tensor(6.578e-01, requires_grad=True), Parameter containing:
# tensor(1.283e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-6.502e-05) tensor(-1.655e-05, dtype=torch.float64)
# Epoch 8/8 at cost=6.206186071722186e-07
# [Parameter containing:
# tensor(6.581e-01, requires_grad=True), Parameter containing:
# tensor(1.283e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.830e-05) tensor(-7.152e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.3976971331430832e-06
# [Parameter containing:
# tensor(6.587e-01, requires_grad=True), Parameter containing:
# tensor(1.286e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.714e-05) tensor(-9.705e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.506375494704116e-05
# [Parameter containing:
# tensor(6.599e-01, requires_grad=True), Parameter containing:
# tensor(1.293e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-4.186e-05) tensor(-1.085e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.294559638154169e-06
# [Parameter containing:
# tensor(6.603e-01, requires_grad=True), Parameter containing:
# tensor(1.295e-01, dtype=torch.float64, requires_grad=True)]
# tensor(4.808e-05) tensor(1.238e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.5502555445200414e-07
# [Parameter containing:
# tensor(6.610e-01, requires_grad=True), Parameter containing:
# tensor(1.299e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.774e-05) tensor(-7.072e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.796331213834492e-07
# [Parameter containing:
# tensor(6.625e-01, requires_grad=True), Parameter containing:
# tensor(1.310e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-7.408e-05) tensor(-1.903e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.1040684739782591e-06
# [Parameter containing:
# tensor(6.646e-01, requires_grad=True), Parameter containing:
# tensor(1.324e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-5.409e-05) tensor(-1.369e-05, dtype=torch.float64)
# Epoch 8/8 at cost=6.387848543454311e-07
# [Parameter containing:
# tensor(6.659e-01, requires_grad=True), Parameter containing:
# tensor(1.333e-01, dtype=torch.float64, requires_grad=True)]
# tensor(4.657e-05) tensor(1.173e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.162177790727583e-07
# [Parameter containing:
# tensor(6.681e-01, requires_grad=True), Parameter containing:
# tensor(1.348e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-9.105e-05) tensor(-2.259e-05, dtype=torch.float64)
# Epoch 8/8 at cost=5.171327757125255e-07
# [Parameter containing:
# tensor(6.681e-01, requires_grad=True), Parameter containing:
# tensor(1.348e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.655e-04) tensor(4.150e-05, dtype=torch.float64)
# Epoch 8/8 at cost=9.597606549505144e-07
# [Parameter containing:
# tensor(6.663e-01, requires_grad=True), Parameter containing:
# tensor(1.334e-01, dtype=torch.float64, requires_grad=True)]
# tensor(1.520e-04) tensor(3.802e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.2540496072688256e-06
# [Parameter containing:
# tensor(6.640e-01, requires_grad=True), Parameter containing:
# tensor(1.317e-01, dtype=torch.float64, requires_grad=True)]
# tensor(5.697e-05) tensor(1.442e-05, dtype=torch.float64)
# Epoch 8/8 at cost=6.055079779798689e-07
# [Parameter containing:
# tensor(6.623e-01, requires_grad=True), Parameter containing:
# tensor(1.304e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-2.863e-05) tensor(-7.028e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.4581915997478063e-07
# [Parameter containing:
# tensor(6.600e-01, requires_grad=True), Parameter containing:
# tensor(1.287e-01, dtype=torch.float64, requires_grad=True)]
# tensor(5.874e-05) tensor(1.493e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.6023229793281644e-07
# [Parameter containing:
# tensor(6.591e-01, requires_grad=True), Parameter containing:
# tensor(1.280e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-9.316e-05) tensor(-2.398e-05, dtype=torch.float64)
# Epoch 8/8 at cost=6.330399742182635e-07
# [Parameter containing:
# tensor(6.583e-01, requires_grad=True), Parameter containing:
# tensor(1.274e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-6.400e-06) tensor(-1.683e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.803237665853885e-07
# [Parameter containing:
# tensor(6.584e-01, requires_grad=True), Parameter containing:
# tensor(1.274e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-6.089e-05) tensor(-1.568e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.6457595936335565e-07
# [Parameter containing:
# tensor(6.589e-01, requires_grad=True), Parameter containing:
# tensor(1.278e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-3.709e-05) tensor(-9.561e-06, dtype=torch.float64)
# Epoch 8/8 at cost=3.308726661543915e-07
# [Parameter containing:
# tensor(6.600e-01, requires_grad=True), Parameter containing:
# tensor(1.287e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-6.208e-05) tensor(-1.608e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.4642297919162957e-07
# [Parameter containing:
# tensor(6.603e-01, requires_grad=True), Parameter containing:
# tensor(1.289e-01, dtype=torch.float64, requires_grad=True)]
# tensor(7.044e-05) tensor(1.823e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.567581643437734e-07
# [Parameter containing:
# tensor(6.614e-01, requires_grad=True), Parameter containing:
# tensor(1.297e-01, dtype=torch.float64, requires_grad=True)]
# tensor(-7.349e-05) tensor(-1.879e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.7734530451416504e-06
# Finished Training

# %% [markdown]
# #### Evaluating unrolled network on train dataset

# %%
out_bftrain2, out_hat2 = get_net_outputs(net2, LearnedAAP(max_iter, d1, d2), r, train2)
out_accaltproj2 = []
for i, (L_true, S_true, M_true) in enumerate(train2):
    loss, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    out_accaltproj2.append((L0, S0))

# %%
metrics = get_metrics(train2, [x[:2] for x in train_est2], out_bftrain2, out_hat2)
fro_norm_L_old, mse_S_old, fro_norm_S_old, count_nonzeros_S_old, relative_err_old, \
    fro_norm_L_new, mse_S_new, fro_norm_S_new, count_nonzeros_S_new, relative_err_new, \
    fro_norm_L_bftrain, mse_S_bftrain, fro_norm_S_bftrain, count_nonzeros_S_bftrain, relative_err_bftrain \
        = metrics.values()
fro_norm_L_accaltproj, mse_S_accaltproj, fro_norm_S_accaltproj, count_nonzeros_S_accaltproj, relative_err_accaltproj \
    = list(get_metrics(train2, out_accaltproj2, out_bftrain2, out_hat2).values())[:5]

fig, ax = plt.subplots()
ax.boxplot([relative_err_old, relative_err_new, relative_err_bftrain, relative_err_accaltproj], notch = True, showfliers=True)
ax.set_xticklabels(["relative_err_old", "relative_err_new", "relative_err_bftrain", "relative_err_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_L_old, fro_norm_L_new, fro_norm_L_bftrain, fro_norm_L_accaltproj], notch = True, showfliers=True)
ax.set_xticklabels(["fro_norm_L_old", "fro_norm_L_new", "fro_norm_L_bfaftrain", "fro_norm_L_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([mse_S_old, mse_S_new, mse_S_bftrain, mse_S_accaltproj], notch = True, showfliers=True)
ax.set_xticklabels(["mse_S_old", "mse_S_new", "mse_S_bfaftrain", "mse_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_S_old, fro_norm_S_new, fro_norm_S_bftrain, fro_norm_S_accaltproj], notch = True, showfliers=True)
ax.set_xticklabels(["fro_norm_S_old", "fro_norm_S_new", "fro_norm_S_bfaftrain", "fro_norm_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([count_nonzeros_S_old, count_nonzeros_S_new, count_nonzeros_S_bftrain, count_nonzeros_S_accaltproj], notch = True, showfliers=True)
ax.set_xticklabels(["count_nonzeros_S_old", "count_nonzeros_S_new", "count_nonzeros_S_bfaftrain", "count_nonzeros_S_accaltproj"])
plt.show()
# Out:
# /Users/elitanzc/Github/FYP/helper.py:254: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat1 = (torch.tensor(mat1) == 0)
# /Users/elitanzc/Github/FYP/helper.py:255: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat2 = (torch.tensor(mat2) == 0)

# %%
print("P-values from test of mean with H1: _new < _old")
# print("relative_err_new, relative_err_old: ", stats.ttest_rel(relative_err_new, relative_err_old, alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_old, alternative='less').pvalue)
# print("mse_S_new, mse_S_old: ", stats.ttest_rel(mse_S_new, mse_S_old, alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_old, alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_old, alternative='less').pvalue)
# print()
# print("P-values from test of mean with H1: _new < _accaltproj")
# print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(relative_err_new, relative_err_accaltproj, alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_accaltproj, alternative='less').pvalue)
# print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(mse_S_new, mse_S_accaltproj, alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_accaltproj, alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_accaltproj, alternative='less').pvalue)
# print()
# print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(relative_err_new, relative_err_bftrain, alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_bftrain, alternative='less').pvalue)
# print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(mse_S_new, mse_S_bftrain, alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_bftrain, alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_bftrain, alternative='less').pvalue)

print("*Note: values are log-transformed before deriving p-values")
print()
print("relative_err_new, relative_err_old: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_old), alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_old), alternative='less').pvalue)
print("mse_S_new, mse_S_old: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_old), alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_old), alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_old), alternative='less').pvalue)
print()
print("P-values from test of mean with H1: _new < _accaltproj")
print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_accaltproj), alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_accaltproj), alternative='less').pvalue)
print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_accaltproj), alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_accaltproj), alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_accaltproj), alternative='less').pvalue)
print()
print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_bftrain), alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_bftrain), alternative='less').pvalue)
print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_bftrain), alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_bftrain), alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_bftrain), alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new < _old
# *Note: values are log-transformed before deriving p-values
#
# relative_err_new, relative_err_old:  7.117071218997168e-34
# fro_norm_L_new, fro_norm_L_old:  8.204904056391584e-46
# mse_S_new, mse_S_old:  8.89099695740757e-09
# fro_norm_S_new, fro_norm_S_old:  8.891007662226547e-09
# count_nonzeros_S_new, count_nonzeros_S_old:  8.427683749053845e-09
#
# P-values from test of mean with H1: _new < _accaltproj
# relative_err_new, relative_err_accaltproj:  1.0
# fro_norm_L_new, fro_norm_L_accaltproj:  1.0
# mse_S_new, mse_S_accaltproj:  1.0
# fro_norm_S_new, fro_norm_S_accaltproj:  1.0
# count_nonzeros_S_new, count_nonzeros_S_accaltproj:  1.0
#
# relative_err_new, relative_err_bftrain:  1.0
# fro_norm_L_new, fro_norm_L_bftrain:  1.0
# mse_S_new, mse_S_bftrain:  1.0
# fro_norm_S_new, fro_norm_S_bftrain:  1.0
# count_nonzeros_S_new, count_nonzeros_S_bftrain:  1.0

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_old[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_old[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_old[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_old[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2174885101.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 11/180 outliers
# fro_norm_L: 10/180 outliers
# mse_S: 19/180 outliers
# fro_norm_S: 9/180 outliers
# count_nonzeros_S: 0/180 outliers

# %%
print("P-values from test of mean with H1: _new/_old < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_old < 1
# relative_err:  6.64062234087967e-55
# fro_norm_L:  4.517993023522323e-16
# mse_S:  1.830772393409045e-63
# fro_norm_S:  3.011294223593633e-67
# count_nonzeros_S:  nan

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_accaltproj[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_accaltproj[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_accaltproj[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_accaltproj[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2948823882.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 10/180 outliers
# fro_norm_L: 15/180 outliers
# mse_S: 14/180 outliers
# fro_norm_S: 8/180 outliers
# count_nonzeros_S: 0/180 outliers

# %%
print("P-values from test of mean with H1: _new/_accaltproj < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_accaltproj < 1
# relative_err:  2.023081173624699e-106
# fro_norm_L:  2.944308115562993e-28
# mse_S:  1.2586236136924157e-154
# fro_norm_S:  1.1397876691038662e-127
# count_nonzeros_S:  nan

# %%
print(np.median(count_nonzeros_S_new), np.mean(count_nonzeros_S_new), np.max(count_nonzeros_S_new))
print(np.median(count_nonzeros_S_accaltproj), np.mean(count_nonzeros_S_accaltproj), np.max(count_nonzeros_S_accaltproj))
print(np.median(count_nonzeros_S_old), np.mean(count_nonzeros_S_old), np.max(count_nonzeros_S_old))
# Out:
# 1.6e-05 1.3333334e-05 6.4e-05
# 6.4e-05 6.088889e-05 0.000144
# 4.8e-05 0.00012764444 0.002944

# %% [markdown]
# #### Evaluating unrolled network on test dataset

# %%
out_bftrain_ontest2, out_hat_ontest2 = get_net_outputs(net2, LearnedAAP(max_iter, d1, d2), r, test2)
out_accaltproj_ontest2 = []
out_ircur_ontest2 = []
for (L_true, S_true, M_true) in test2:
    loss0, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    out_accaltproj_ontest2.append((L0, S0))
    loss0, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    out_ircur_ontest2.append((L0, S0))

# %%
metrics = get_metrics(test2, out_ircur_ontest2, out_bftrain_ontest2, out_hat_ontest2)
fro_norm_L_old, mse_S_old, fro_norm_S_old, count_nonzeros_S_old, relative_err_old, \
    fro_norm_L_new, mse_S_new, fro_norm_S_new, count_nonzeros_S_new, relative_err_new, \
    fro_norm_L_bftrain, mse_S_bftrain, fro_norm_S_bftrain, count_nonzeros_S_bftrain, relative_err_bftrain \
        = metrics.values()
fro_norm_L_accaltproj, mse_S_accaltproj, fro_norm_S_accaltproj, count_nonzeros_S_accaltproj, relative_err_accaltproj \
    = list(get_metrics(test2, out_accaltproj_ontest2, out_bftrain_ontest2, out_hat_ontest2).values())[:5]

fig, ax = plt.subplots()
ax.boxplot([relative_err_old, relative_err_new, relative_err_bftrain, relative_err_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["relative_err_old", "relative_err_new", "relative_err_bftrain", "relative_err_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_L_old, fro_norm_L_new, fro_norm_L_bftrain, fro_norm_L_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["fro_norm_L_old", "fro_norm_L_new", "fro_norm_L_bfaftrain", "fro_norm_L_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([mse_S_old, mse_S_new, mse_S_bftrain, mse_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["mse_S_old", "mse_S_new", "mse_S_bfaftrain", "mse_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_S_old, fro_norm_S_new, fro_norm_S_bftrain, fro_norm_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["fro_norm_S_old", "fro_norm_S_new", "fro_norm_S_bfaftrain", "fro_norm_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([count_nonzeros_S_old, count_nonzeros_S_new, count_nonzeros_S_bftrain, count_nonzeros_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["count_nonzeros_S_old", "count_nonzeros_S_new", "count_nonzeros_S_bfaftrain", "count_nonzeros_S_accaltproj"])
plt.show()
# Out:
# /Users/elitanzc/Github/FYP/helper.py:254: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat1 = (torch.tensor(mat1) == 0)
# /Users/elitanzc/Github/FYP/helper.py:255: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat2 = (torch.tensor(mat2) == 0)

# %%
print("P-values from test of mean with H1: _new < _old")
print("relative_err_new, relative_err_old: ", stats.ttest_rel(relative_err_new, relative_err_old, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_old, alternative='less').pvalue)
print("mse_S_new, mse_S_old: ", stats.ttest_rel(mse_S_new, mse_S_old, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_old, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_old, alternative='less').pvalue)
print()
print("P-values from test of mean with H1: _new < _accaltproj")
print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(relative_err_new, relative_err_accaltproj, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_accaltproj, alternative='less').pvalue)
print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(mse_S_new, mse_S_accaltproj, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_accaltproj, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_accaltproj, alternative='less').pvalue)
print()
print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(relative_err_new, relative_err_bftrain, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_bftrain, alternative='less').pvalue)
print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(mse_S_new, mse_S_bftrain, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_bftrain, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_bftrain, alternative='less').pvalue)

# print("*Note: values are log-transformed before deriving p-values")
# print()
# print("relative_err_new, relative_err_old: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_old), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_old), alternative='less').pvalue)
# print("mse_S_new, mse_S_old: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_old), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_old), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_old), alternative='less').pvalue)
# print()
# print("P-values from test of mean with H1: _new < _accaltproj")
# print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_accaltproj), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_accaltproj), alternative='less').pvalue)
# print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_accaltproj), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_accaltproj), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_accaltproj), alternative='less').pvalue)
# print()
# print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_bftrain), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_bftrain), alternative='less').pvalue)
# print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_bftrain), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_bftrain), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_bftrain), alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new < _old
# relative_err_new, relative_err_old:  3.139155649576208e-25
# fro_norm_L_new, fro_norm_L_old:  0.02353100104112257
# mse_S_new, mse_S_old:  0.06974796441293656
# fro_norm_S_new, fro_norm_S_old:  0.023382380402424845
# count_nonzeros_S_new, count_nonzeros_S_old:  0.0005400215209348978
#
# P-values from test of mean with H1: _new < _accaltproj
# relative_err_new, relative_err_accaltproj:  2.328039999275116e-51
# fro_norm_L_new, fro_norm_L_accaltproj:  1.0801733006532677e-17
# mse_S_new, mse_S_accaltproj:  1.2173695587094345e-42
# fro_norm_S_new, fro_norm_S_accaltproj:  1.6842623513476184e-55
# count_nonzeros_S_new, count_nonzeros_S_accaltproj:  2.6659296937880377e-46
#
# relative_err_new, relative_err_bftrain:  1.0
# fro_norm_L_new, fro_norm_L_bftrain:  2.901502675966444e-32
# mse_S_new, mse_S_bftrain:  1.0961059115965054e-16
# fro_norm_S_new, fro_norm_S_bftrain:  8.263770240747033e-41
# count_nonzeros_S_new, count_nonzeros_S_bftrain:  3.386929307347482e-129

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_old[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_old[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_old[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_old[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2174885101.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 9/120 outliers
# fro_norm_L: 12/120 outliers
# mse_S: 11/120 outliers
# fro_norm_S: 7/120 outliers
# count_nonzeros_S: 0/120 outliers

# %%
print("P-values from test of mean with H1: _new/_old < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_old < 1
# relative_err:  8.4568097608936e-27
# fro_norm_L:  1.1715909281390202e-06
# mse_S:  7.441214911321548e-21
# fro_norm_S:  3.649061000965725e-36
# count_nonzeros_S:  nan

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_accaltproj[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_accaltproj[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_accaltproj[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_accaltproj[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# relative_err: 5/120 outliers
# fro_norm_L: 6/120 outliers
# mse_S: 6/120 outliers
# fro_norm_S: 5/120 outliers
# count_nonzeros_S: 2/120 outliers

# %%
print("P-values from test of mean with H1: _new/_accaltproj < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_accaltproj < 1
# relative_err:  2.3436773556969833e-60
# fro_norm_L:  4.4028226398430876e-16
# mse_S:  3.532607882202473e-78
# fro_norm_S:  1.802329809326574e-74
# count_nonzeros_S:  4.246607275033571e-68

# %%
print(np.median(count_nonzeros_S_new), np.mean(count_nonzeros_S_new), np.max(count_nonzeros_S_new))
print(np.median(count_nonzeros_S_accaltproj), np.mean(count_nonzeros_S_accaltproj), np.max(count_nonzeros_S_accaltproj))
print(np.median(count_nonzeros_S_old), np.mean(count_nonzeros_S_old), np.max(count_nonzeros_S_old))
# Out:
# 1.6e-05 1.4400001e-05 6.4e-05
# 6.4e-05 6.0000002e-05 0.000144
# 4.8e-05 0.00019653332 0.002912

# %% [markdown]
# ### Scenario 3:
# **alpha = 0.01** (lower sparsity), **c = 1**, r = 2, dimension = 250x250
#
# gamma=7.195e-01; beta=1.112e-01
#
# *** ***

# %%
## ======================== 0. set constants ========================
# d1 = 250                   # num. of rows
# d2 = 250                   # num. of columns
# max_iter = 100              # num. of layers trained
alpha_true = 0.01
c_true = 1
# r = 2
# dataset_size = 300

## ======================== 1. generate data ========================
train3, test3 =  generate_train_test(dataset_size, r, d1, d2, alpha_true, c_true)
# Out:
# train dataset size: 180
# test dataset size: 120

# %% [markdown]
# #### Training

# %%
## ======================== 2. estimations by classical ========================
train_est3 = []
for i, (L_true, S_true, M_true) in enumerate(train3):
    loss, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    train_est3.append((L0, S0, M_true))

# %%
## ======================== 3. train unrolled network with estimated data ========================
net3, params_bftrain3, params_aftrain3, l0_norm_of_S_Shat3 = train_nn(LearnedAAP(max_iter, d1, d2), r \
                                                                    , lr=2e-03, weight_decay=0 \
                                                                    , nepochs=8, dataset=train_est3)
# Out:
# [Parameter containing:
# tensor(7.020e-01, requires_grad=True), Parameter containing:
# tensor(3.362e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.197e-05) tensor(-1.394e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.1073531115689548e-06
# [Parameter containing:
# tensor(7.033e-01, requires_grad=True), Parameter containing:
# tensor(3.494e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.978e-07) tensor(2.174e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.1622221336438088e-06
# [Parameter containing:
# tensor(7.043e-01, requires_grad=True), Parameter containing:
# tensor(3.595e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.525e-09) tensor(4.063e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.0659443328009388e-09
# [Parameter containing:
# tensor(7.052e-01, requires_grad=True), Parameter containing:
# tensor(3.679e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.706e-12) tensor(1.996e-12, dtype=torch.float64)
# Epoch 1/8 at cost=6.159832199870152e-09
# [Parameter containing:
# tensor(7.059e-01, requires_grad=True), Parameter containing:
# tensor(3.749e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.987e-14) tensor(1.862e-14, dtype=torch.float64)
# Epoch 1/8 at cost=1.5041753953504156e-10
# [Parameter containing:
# tensor(7.065e-01, requires_grad=True), Parameter containing:
# tensor(3.809e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.737e-09) tensor(3.909e-09, dtype=torch.float64)
# Epoch 1/8 at cost=4.437228362519363e-11
# [Parameter containing:
# tensor(7.070e-01, requires_grad=True), Parameter containing:
# tensor(3.862e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.845e-10) tensor(-1.888e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.340218269696436e-09
# [Parameter containing:
# tensor(7.075e-01, requires_grad=True), Parameter containing:
# tensor(3.909e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.680e-08) tensor(2.582e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.994559847342316e-07
# [Parameter containing:
# tensor(7.078e-01, requires_grad=True), Parameter containing:
# tensor(3.946e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.778e-07) tensor(5.504e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.64846502904004e-10
# [Parameter containing:
# tensor(7.088e-01, requires_grad=True), Parameter containing:
# tensor(4.046e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.477e-04) tensor(-1.325e-04, dtype=torch.float64)
# Epoch 1/8 at cost=4.025853428402115e-08
# [Parameter containing:
# tensor(7.097e-01, requires_grad=True), Parameter containing:
# tensor(4.135e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.715e-07) tensor(8.960e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.690006439820536e-09
# [Parameter containing:
# tensor(7.105e-01, requires_grad=True), Parameter containing:
# tensor(4.215e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.494e-11) tensor(1.416e-11, dtype=torch.float64)
# Epoch 1/8 at cost=5.866241963303764e-07
# [Parameter containing:
# tensor(7.101e-01, requires_grad=True), Parameter containing:
# tensor(4.182e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.070e-04) tensor(1.745e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.5840398646105314e-06
# [Parameter containing:
# tensor(7.091e-01, requires_grad=True), Parameter containing:
# tensor(4.086e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.553e-04) tensor(3.017e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.8797283019011957e-07
# [Parameter containing:
# tensor(7.083e-01, requires_grad=True), Parameter containing:
# tensor(3.999e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.255e-12) tensor(1.368e-12, dtype=torch.float64)
# Epoch 1/8 at cost=5.123773627602191e-10
# [Parameter containing:
# tensor(7.074e-01, requires_grad=True), Parameter containing:
# tensor(3.921e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.700e-07) tensor(2.540e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.1341832595899177e-07
# [Parameter containing:
# tensor(7.067e-01, requires_grad=True), Parameter containing:
# tensor(3.849e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.048e-07) tensor(8.593e-07, dtype=torch.float64)
# Epoch 1/8 at cost=4.900786620964936e-07
# [Parameter containing:
# tensor(7.061e-01, requires_grad=True), Parameter containing:
# tensor(3.784e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.116e-10) tensor(1.279e-10, dtype=torch.float64)
# Epoch 1/8 at cost=5.290905491506237e-09
# [Parameter containing:
# tensor(7.054e-01, requires_grad=True), Parameter containing:
# tensor(3.724e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.394e-06) tensor(2.351e-06, dtype=torch.float64)
# Epoch 1/8 at cost=3.3498802167741815e-06
# [Parameter containing:
# tensor(7.045e-01, requires_grad=True), Parameter containing:
# tensor(3.626e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.358e-04) tensor(2.233e-04, dtype=torch.float64)
# Epoch 1/8 at cost=4.514319584814075e-07
# [Parameter containing:
# tensor(7.036e-01, requires_grad=True), Parameter containing:
# tensor(3.536e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.960e-07) tensor(6.094e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.518381309573158e-09
# [Parameter containing:
# tensor(7.028e-01, requires_grad=True), Parameter containing:
# tensor(3.454e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.602e-10) tensor(3.951e-10, dtype=torch.float64)
# Epoch 1/8 at cost=6.545351425302215e-07
# [Parameter containing:
# tensor(7.021e-01, requires_grad=True), Parameter containing:
# tensor(3.379e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.877e-12) tensor(-2.134e-12, dtype=torch.float64)
# Epoch 1/8 at cost=7.138540354389988e-07
# [Parameter containing:
# tensor(7.014e-01, requires_grad=True), Parameter containing:
# tensor(3.311e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.045e-12) tensor(3.937e-12, dtype=torch.float64)
# Epoch 1/8 at cost=3.1758006002746697e-07
# [Parameter containing:
# tensor(7.008e-01, requires_grad=True), Parameter containing:
# tensor(3.250e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.587e-08) tensor(-4.008e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.6834228517836891e-06
# [Parameter containing:
# tensor(7.002e-01, requires_grad=True), Parameter containing:
# tensor(3.196e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.570e-06) tensor(-1.086e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.4850937734299805e-06
# [Parameter containing:
# tensor(6.998e-01, requires_grad=True), Parameter containing:
# tensor(3.150e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.102e-05) tensor(-1.271e-05, dtype=torch.float64)
# Epoch 1/8 at cost=3.986697265645489e-07
# [Parameter containing:
# tensor(6.999e-01, requires_grad=True), Parameter containing:
# tensor(3.177e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.575e-04) tensor(-2.859e-04, dtype=torch.float64)
# Epoch 1/8 at cost=4.636896449028427e-07
# [Parameter containing:
# tensor(7.001e-01, requires_grad=True), Parameter containing:
# tensor(3.201e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.192e-08) tensor(1.459e-08, dtype=torch.float64)
# Epoch 1/8 at cost=5.218947496388182e-10
# [Parameter containing:
# tensor(7.002e-01, requires_grad=True), Parameter containing:
# tensor(3.223e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.989e-11) tensor(-1.296e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.607059457204741e-07
# [Parameter containing:
# tensor(7.004e-01, requires_grad=True), Parameter containing:
# tensor(3.263e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.270e-05) tensor(-8.983e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.838378598823965e-08
# [Parameter containing:
# tensor(7.007e-01, requires_grad=True), Parameter containing:
# tensor(3.298e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.541e-11) tensor(2.066e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.8088777831447587e-11
# [Parameter containing:
# tensor(7.009e-01, requires_grad=True), Parameter containing:
# tensor(3.331e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.263e-11) tensor(-1.427e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.397205716737517e-07
# [Parameter containing:
# tensor(7.014e-01, requires_grad=True), Parameter containing:
# tensor(3.396e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.591e-04) tensor(-1.673e-04, dtype=torch.float64)
# Epoch 1/8 at cost=8.295278348668944e-07
# [Parameter containing:
# tensor(7.019e-01, requires_grad=True), Parameter containing:
# tensor(3.454e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.969e-07) tensor(5.402e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.0091327207770746e-09
# [Parameter containing:
# tensor(7.024e-01, requires_grad=True), Parameter containing:
# tensor(3.508e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.120e-08) tensor(5.476e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.1608306538235524e-09
# [Parameter containing:
# tensor(7.028e-01, requires_grad=True), Parameter containing:
# tensor(3.556e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.160e-15) tensor(-8.162e-15, dtype=torch.float64)
# Epoch 1/8 at cost=2.414653810234313e-09
# [Parameter containing:
# tensor(7.031e-01, requires_grad=True), Parameter containing:
# tensor(3.601e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.103e-12) tensor(-2.609e-12, dtype=torch.float64)
# Epoch 1/8 at cost=2.297811940721317e-09
# [Parameter containing:
# tensor(7.034e-01, requires_grad=True), Parameter containing:
# tensor(3.642e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.103e-06) tensor(-3.189e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.3209569438288327e-08
# [Parameter containing:
# tensor(7.038e-01, requires_grad=True), Parameter containing:
# tensor(3.687e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.569e-05) tensor(-3.447e-05, dtype=torch.float64)
# Epoch 1/8 at cost=8.266278328505905e-09
# [Parameter containing:
# tensor(7.042e-01, requires_grad=True), Parameter containing:
# tensor(3.728e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.147e-11) tensor(1.491e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.290209272752918e-09
# [Parameter containing:
# tensor(7.045e-01, requires_grad=True), Parameter containing:
# tensor(3.766e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.321e-09) tensor(1.386e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.7920941397520096e-09
# [Parameter containing:
# tensor(7.048e-01, requires_grad=True), Parameter containing:
# tensor(3.800e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.616e-07) tensor(2.576e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.899040145251888e-10
# [Parameter containing:
# tensor(7.050e-01, requires_grad=True), Parameter containing:
# tensor(3.831e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.420e-09) tensor(1.463e-09, dtype=torch.float64)
# Epoch 1/8 at cost=7.06553704432622e-11
# [Parameter containing:
# tensor(7.046e-01, requires_grad=True), Parameter containing:
# tensor(3.796e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.973e-04) tensor(2.736e-04, dtype=torch.float64)
# Epoch 1/8 at cost=5.725611913476314e-07
# [Parameter containing:
# tensor(7.043e-01, requires_grad=True), Parameter containing:
# tensor(3.765e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.293e-09) tensor(-1.412e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.9821972951916678e-09
# [Parameter containing:
# tensor(7.039e-01, requires_grad=True), Parameter containing:
# tensor(3.736e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.386e-07) tensor(-6.287e-07, dtype=torch.float64)
# Epoch 1/8 at cost=4.725629594304337e-07
# [Parameter containing:
# tensor(7.037e-01, requires_grad=True), Parameter containing:
# tensor(3.710e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.595e-08) tensor(1.582e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.8412375741027063e-07
# [Parameter containing:
# tensor(7.034e-01, requires_grad=True), Parameter containing:
# tensor(3.686e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.088e-06) tensor(2.084e-06, dtype=torch.float64)
# Epoch 1/8 at cost=3.090159736984788e-07
# [Parameter containing:
# tensor(7.031e-01, requires_grad=True), Parameter containing:
# tensor(3.664e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.083e-06) tensor(1.087e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.5246005569125032e-09
# [Parameter containing:
# tensor(7.029e-01, requires_grad=True), Parameter containing:
# tensor(3.644e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.381e-11) tensor(1.562e-11, dtype=torch.float64)
# Epoch 1/8 at cost=7.940657575922216e-10
# [Parameter containing:
# tensor(7.027e-01, requires_grad=True), Parameter containing:
# tensor(3.626e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.546e-12) tensor(-1.120e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.2112282277729776e-10
# [Parameter containing:
# tensor(7.025e-01, requires_grad=True), Parameter containing:
# tensor(3.610e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.928e-10) tensor(2.451e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.5804220083737164e-06
# [Parameter containing:
# tensor(7.023e-01, requires_grad=True), Parameter containing:
# tensor(3.595e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.498e-09) tensor(3.781e-09, dtype=torch.float64)
# Epoch 1/8 at cost=6.533471097469601e-09
# [Parameter containing:
# tensor(7.022e-01, requires_grad=True), Parameter containing:
# tensor(3.581e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.471e-10) tensor(-7.725e-10, dtype=torch.float64)
# Epoch 1/8 at cost=8.63285720686946e-10
# [Parameter containing:
# tensor(7.020e-01, requires_grad=True), Parameter containing:
# tensor(3.569e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.684e-12) tensor(-1.065e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.9351344970885975e-09
# [Parameter containing:
# tensor(7.019e-01, requires_grad=True), Parameter containing:
# tensor(3.558e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.035e-06) tensor(-1.072e-06, dtype=torch.float64)
# Epoch 1/8 at cost=5.497426958100959e-09
# [Parameter containing:
# tensor(7.020e-01, requires_grad=True), Parameter containing:
# tensor(3.571e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.587e-05) tensor(-9.457e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.7415552494858275e-08
# [Parameter containing:
# tensor(7.021e-01, requires_grad=True), Parameter containing:
# tensor(3.583e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.857e-07) tensor(1.921e-07, dtype=torch.float64)
# Epoch 1/8 at cost=9.988541478378465e-07
# [Parameter containing:
# tensor(7.022e-01, requires_grad=True), Parameter containing:
# tensor(3.594e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.255e-12) tensor(1.867e-12, dtype=torch.float64)
# Epoch 1/8 at cost=7.66054483847256e-07
# [Parameter containing:
# tensor(7.026e-01, requires_grad=True), Parameter containing:
# tensor(3.643e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.683e-04) tensor(-1.644e-04, dtype=torch.float64)
# Epoch 1/8 at cost=8.385568150970357e-08
# [Parameter containing:
# tensor(7.035e-01, requires_grad=True), Parameter containing:
# tensor(3.736e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.296e-04) tensor(-2.214e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.1015001746272901e-06
# [Parameter containing:
# tensor(7.044e-01, requires_grad=True), Parameter containing:
# tensor(3.821e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.666e-10) tensor(-3.952e-10, dtype=torch.float64)
# Epoch 1/8 at cost=8.089170364655729e-07
# [Parameter containing:
# tensor(7.051e-01, requires_grad=True), Parameter containing:
# tensor(3.898e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.441e-10) tensor(4.626e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.814879434571594e-08
# [Parameter containing:
# tensor(7.058e-01, requires_grad=True), Parameter containing:
# tensor(3.967e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.573e-08) tensor(2.448e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.279305869658856e-07
# [Parameter containing:
# tensor(7.064e-01, requires_grad=True), Parameter containing:
# tensor(4.031e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.406e-11) tensor(1.504e-11, dtype=torch.float64)
# Epoch 1/8 at cost=7.351300723712484e-07
# [Parameter containing:
# tensor(7.078e-01, requires_grad=True), Parameter containing:
# tensor(4.177e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.351e-04) tensor(-5.565e-04, dtype=torch.float64)
# Epoch 1/8 at cost=9.303661272497266e-07
# [Parameter containing:
# tensor(7.092e-01, requires_grad=True), Parameter containing:
# tensor(4.311e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.587e-12) tensor(-1.810e-12, dtype=torch.float64)
# Epoch 1/8 at cost=2.987073628446524e-07
# [Parameter containing:
# tensor(7.103e-01, requires_grad=True), Parameter containing:
# tensor(4.419e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.082e-05) tensor(6.648e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.2048682052068216e-08
# [Parameter containing:
# tensor(7.097e-01, requires_grad=True), Parameter containing:
# tensor(4.376e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.031e-03) tensor(8.290e-04, dtype=torch.float64)
# Epoch 1/8 at cost=7.210982744254579e-07
# [Parameter containing:
# tensor(7.088e-01, requires_grad=True), Parameter containing:
# tensor(4.294e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.255e-04) tensor(3.451e-04, dtype=torch.float64)
# Epoch 1/8 at cost=6.555030722665833e-07
# [Parameter containing:
# tensor(7.075e-01, requires_grad=True), Parameter containing:
# tensor(4.183e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.574e-04) tensor(2.949e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.7422141240786004e-07
# [Parameter containing:
# tensor(7.064e-01, requires_grad=True), Parameter containing:
# tensor(4.082e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.494e-11) tensor(6.434e-11, dtype=torch.float64)
# Epoch 1/8 at cost=4.843442091839734e-09
# [Parameter containing:
# tensor(7.054e-01, requires_grad=True), Parameter containing:
# tensor(3.991e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.070e-10) tensor(-1.028e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.0106109544524315e-09
# [Parameter containing:
# tensor(7.045e-01, requires_grad=True), Parameter containing:
# tensor(3.909e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.140e-07) tensor(1.063e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.9099504078876635e-07
# [Parameter containing:
# tensor(7.037e-01, requires_grad=True), Parameter containing:
# tensor(3.834e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.834e-09) tensor(5.660e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.7276063835633977e-07
# [Parameter containing:
# tensor(7.029e-01, requires_grad=True), Parameter containing:
# tensor(3.766e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.227e-07) tensor(3.118e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.871530264097032e-09
# [Parameter containing:
# tensor(7.022e-01, requires_grad=True), Parameter containing:
# tensor(3.704e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.523e-07) tensor(4.443e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.32400878938688e-09
# [Parameter containing:
# tensor(7.016e-01, requires_grad=True), Parameter containing:
# tensor(3.649e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.956e-08) tensor(2.949e-08, dtype=torch.float64)
# Epoch 1/8 at cost=5.026987714984443e-10
# [Parameter containing:
# tensor(7.011e-01, requires_grad=True), Parameter containing:
# tensor(3.609e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.157e-05) tensor(-7.842e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.8401840051751606e-08
# [Parameter containing:
# tensor(7.007e-01, requires_grad=True), Parameter containing:
# tensor(3.573e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.754e-08) tensor(-1.053e-07, dtype=torch.float64)
# Epoch 1/8 at cost=4.943090061715338e-07
# [Parameter containing:
# tensor(7.003e-01, requires_grad=True), Parameter containing:
# tensor(3.540e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.180e-14) tensor(-2.862e-14, dtype=torch.float64)
# Epoch 1/8 at cost=1.6213911324669539e-09
# [Parameter containing:
# tensor(7.000e-01, requires_grad=True), Parameter containing:
# tensor(3.511e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.988e-07) tensor(-5.192e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.3469746085756924e-07
# [Parameter containing:
# tensor(6.997e-01, requires_grad=True), Parameter containing:
# tensor(3.484e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.396e-09) tensor(5.979e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.2920672027026967e-09
# [Parameter containing:
# tensor(6.994e-01, requires_grad=True), Parameter containing:
# tensor(3.460e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.479e-14) tensor(4.366e-14, dtype=torch.float64)
# Epoch 1/8 at cost=7.63585375485043e-11
# [Parameter containing:
# tensor(6.991e-01, requires_grad=True), Parameter containing:
# tensor(3.438e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.776e-07) tensor(2.953e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.039414480099367e-07
# [Parameter containing:
# tensor(6.989e-01, requires_grad=True), Parameter containing:
# tensor(3.421e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.933e-05) tensor(-1.965e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.4488581427940517e-06
# [Parameter containing:
# tensor(6.987e-01, requires_grad=True), Parameter containing:
# tensor(3.406e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.296e-11) tensor(1.170e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.5680131443550636e-07
# [Parameter containing:
# tensor(6.986e-01, requires_grad=True), Parameter containing:
# tensor(3.392e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.822e-14) tensor(-2.049e-13, dtype=torch.float64)
# Epoch 1/8 at cost=5.420179718385043e-07
# [Parameter containing:
# tensor(6.984e-01, requires_grad=True), Parameter containing:
# tensor(3.379e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.234e-07) tensor(1.337e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.3488151157380344e-07
# [Parameter containing:
# tensor(6.983e-01, requires_grad=True), Parameter containing:
# tensor(3.368e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.047e-13) tensor(2.646e-12, dtype=torch.float64)
# Epoch 1/8 at cost=3.377108725999278e-08
# [Parameter containing:
# tensor(6.982e-01, requires_grad=True), Parameter containing:
# tensor(3.357e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.639e-11) tensor(-6.408e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.222109998228916e-07
# [Parameter containing:
# tensor(6.980e-01, requires_grad=True), Parameter containing:
# tensor(3.348e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.036e-11) tensor(1.265e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.525384784097696e-07
# [Parameter containing:
# tensor(6.979e-01, requires_grad=True), Parameter containing:
# tensor(3.339e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.895e-09) tensor(-7.568e-09, dtype=torch.float64)
# Epoch 1/8 at cost=9.20839624996006e-07
# [Parameter containing:
# tensor(6.981e-01, requires_grad=True), Parameter containing:
# tensor(3.361e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.898e-04) tensor(-1.984e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.0426843033428668e-07
# [Parameter containing:
# tensor(6.982e-01, requires_grad=True), Parameter containing:
# tensor(3.381e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.244e-10) tensor(1.428e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.7507934338412134e-11
# [Parameter containing:
# tensor(6.983e-01, requires_grad=True), Parameter containing:
# tensor(3.399e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.180e-12) tensor(7.280e-12, dtype=torch.float64)
# Epoch 1/8 at cost=2.75300124030764e-07
# [Parameter containing:
# tensor(6.984e-01, requires_grad=True), Parameter containing:
# tensor(3.415e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.178e-09) tensor(5.600e-09, dtype=torch.float64)
# Epoch 1/8 at cost=9.415520594302507e-07
# [Parameter containing:
# tensor(6.985e-01, requires_grad=True), Parameter containing:
# tensor(3.430e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.198e-06) tensor(-2.365e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.110435619011696e-06
# [Parameter containing:
# tensor(6.992e-01, requires_grad=True), Parameter containing:
# tensor(3.505e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.312e-04) tensor(-4.391e-04, dtype=torch.float64)
# Epoch 1/8 at cost=9.629079613659997e-07
# [Parameter containing:
# tensor(6.997e-01, requires_grad=True), Parameter containing:
# tensor(3.574e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.734e-07) tensor(-1.022e-06, dtype=torch.float64)
# Epoch 1/8 at cost=9.08205151972652e-07
# [Parameter containing:
# tensor(7.004e-01, requires_grad=True), Parameter containing:
# tensor(3.649e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.232e-05) tensor(-9.037e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.9399172873922907e-08
# [Parameter containing:
# tensor(7.009e-01, requires_grad=True), Parameter containing:
# tensor(3.717e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.771e-07) tensor(-2.955e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.955432698101504e-07
# [Parameter containing:
# tensor(7.014e-01, requires_grad=True), Parameter containing:
# tensor(3.779e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.031e-06) tensor(-1.023e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.0771616416604957e-06
# [Parameter containing:
# tensor(7.019e-01, requires_grad=True), Parameter containing:
# tensor(3.835e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.297e-11) tensor(1.433e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.1493703200879963e-09
# [Parameter containing:
# tensor(7.023e-01, requires_grad=True), Parameter containing:
# tensor(3.885e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.259e-09) tensor(1.283e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.248258053645259e-07
# [Parameter containing:
# tensor(7.027e-01, requires_grad=True), Parameter containing:
# tensor(3.931e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.414e-10) tensor(-1.343e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.292689315121834e-09
# [Parameter containing:
# tensor(7.031e-01, requires_grad=True), Parameter containing:
# tensor(3.972e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.976e-07) tensor(4.682e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.1027558866061327e-09
# [Parameter containing:
# tensor(7.034e-01, requires_grad=True), Parameter containing:
# tensor(4.009e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.525e-13) tensor(-2.804e-13, dtype=torch.float64)
# Epoch 1/8 at cost=3.8140640867823095e-07
# [Parameter containing:
# tensor(7.037e-01, requires_grad=True), Parameter containing:
# tensor(4.043e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.369e-12) tensor(-9.304e-12, dtype=torch.float64)
# Epoch 1/8 at cost=7.810918987161131e-07
# [Parameter containing:
# tensor(7.035e-01, requires_grad=True), Parameter containing:
# tensor(4.029e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.391e-04) tensor(2.951e-04, dtype=torch.float64)
# Epoch 1/8 at cost=6.337049285320973e-07
# [Parameter containing:
# tensor(7.033e-01, requires_grad=True), Parameter containing:
# tensor(4.017e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.368e-07) tensor(2.176e-07, dtype=torch.float64)
# Epoch 1/8 at cost=7.322076722715565e-09
# [Parameter containing:
# tensor(7.031e-01, requires_grad=True), Parameter containing:
# tensor(4.005e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.244e-10) tensor(8.020e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.6179051421392217e-10
# [Parameter containing:
# tensor(7.030e-01, requires_grad=True), Parameter containing:
# tensor(3.995e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.246e-09) tensor(-1.285e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.9063500076299533e-06
# [Parameter containing:
# tensor(7.028e-01, requires_grad=True), Parameter containing:
# tensor(3.979e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.640e-05) tensor(4.080e-05, dtype=torch.float64)
# Epoch 1/8 at cost=9.591463623337404e-09
# [Parameter containing:
# tensor(7.027e-01, requires_grad=True), Parameter containing:
# tensor(3.966e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.496e-08) tensor(-4.411e-08, dtype=torch.float64)
# Epoch 1/8 at cost=5.815037980028137e-07
# [Parameter containing:
# tensor(7.028e-01, requires_grad=True), Parameter containing:
# tensor(3.985e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.418e-04) tensor(-2.143e-04, dtype=torch.float64)
# Epoch 1/8 at cost=6.564105206052773e-07
# [Parameter containing:
# tensor(7.030e-01, requires_grad=True), Parameter containing:
# tensor(4.003e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.546e-12) tensor(8.887e-12, dtype=torch.float64)
# Epoch 1/8 at cost=4.679661103068611e-10
# [Parameter containing:
# tensor(7.031e-01, requires_grad=True), Parameter containing:
# tensor(4.019e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.900e-07) tensor(1.756e-07, dtype=torch.float64)
# Epoch 1/8 at cost=7.715430072607887e-09
# [Parameter containing:
# tensor(7.032e-01, requires_grad=True), Parameter containing:
# tensor(4.034e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.383e-11) tensor(1.344e-11, dtype=torch.float64)
# Epoch 1/8 at cost=9.39793687315671e-10
# [Parameter containing:
# tensor(7.033e-01, requires_grad=True), Parameter containing:
# tensor(4.047e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.550e-13) tensor(4.133e-13, dtype=torch.float64)
# Epoch 1/8 at cost=3.395732619537739e-07
# [Parameter containing:
# tensor(7.034e-01, requires_grad=True), Parameter containing:
# tensor(4.059e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.124e-07) tensor(3.772e-07, dtype=torch.float64)
# Epoch 1/8 at cost=4.327351916799671e-07
# [Parameter containing:
# tensor(7.035e-01, requires_grad=True), Parameter containing:
# tensor(4.069e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.755e-10) tensor(2.616e-10, dtype=torch.float64)
# Epoch 1/8 at cost=5.402078784300102e-10
# [Parameter containing:
# tensor(7.036e-01, requires_grad=True), Parameter containing:
# tensor(4.079e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.705e-07) tensor(3.371e-07, dtype=torch.float64)
# Epoch 1/8 at cost=7.690749157518439e-07
# [Parameter containing:
# tensor(7.042e-01, requires_grad=True), Parameter containing:
# tensor(4.142e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.241e-04) tensor(-3.657e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.7161827372547123e-06
# [Parameter containing:
# tensor(7.048e-01, requires_grad=True), Parameter containing:
# tensor(4.200e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.810e-06) tensor(1.620e-06, dtype=torch.float64)
# Epoch 1/8 at cost=3.2544525652156153e-07
# [Parameter containing:
# tensor(7.050e-01, requires_grad=True), Parameter containing:
# tensor(4.226e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.975e-04) tensor(1.658e-04, dtype=torch.float64)
# Epoch 1/8 at cost=7.031629678522222e-08
# [Parameter containing:
# tensor(7.053e-01, requires_grad=True), Parameter containing:
# tensor(4.250e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.029e-11) tensor(6.903e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.976026619056938e-07
# [Parameter containing:
# tensor(7.055e-01, requires_grad=True), Parameter containing:
# tensor(4.271e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.577e-11) tensor(4.698e-11, dtype=torch.float64)
# Epoch 1/8 at cost=5.371574296475501e-09
# [Parameter containing:
# tensor(7.056e-01, requires_grad=True), Parameter containing:
# tensor(4.290e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.503e-08) tensor(1.309e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.164707524343612e-08
# [Parameter containing:
# tensor(7.052e-01, requires_grad=True), Parameter containing:
# tensor(4.250e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.725e-04) tensor(3.885e-04, dtype=torch.float64)
# Epoch 1/8 at cost=5.967034439890995e-07
# [Parameter containing:
# tensor(7.048e-01, requires_grad=True), Parameter containing:
# tensor(4.213e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.085e-07) tensor(5.314e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.0533212907736242e-09
# [Parameter containing:
# tensor(7.044e-01, requires_grad=True), Parameter containing:
# tensor(4.180e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.296e-07) tensor(7.314e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.393595626732804e-09
# [Parameter containing:
# tensor(7.041e-01, requires_grad=True), Parameter containing:
# tensor(4.150e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.637e-13) tensor(-4.957e-13, dtype=torch.float64)
# Epoch 1/8 at cost=3.072040897222905e-07
# [Parameter containing:
# tensor(7.038e-01, requires_grad=True), Parameter containing:
# tensor(4.122e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.956e-11) tensor(-9.905e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.769594581979561e-09
# [Parameter containing:
# tensor(7.035e-01, requires_grad=True), Parameter containing:
# tensor(4.098e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.493e-07) tensor(1.341e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.2468219046677405e-07
# [Parameter containing:
# tensor(7.033e-01, requires_grad=True), Parameter containing:
# tensor(4.076e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.415e-12) tensor(8.818e-12, dtype=torch.float64)
# Epoch 1/8 at cost=1.7840965371718198e-09
# [Parameter containing:
# tensor(7.027e-01, requires_grad=True), Parameter containing:
# tensor(4.017e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.022e-04) tensor(2.607e-04, dtype=torch.float64)
# Epoch 1/8 at cost=8.62776801113796e-07
# [Parameter containing:
# tensor(7.021e-01, requires_grad=True), Parameter containing:
# tensor(3.963e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.107e-07) tensor(1.940e-07, dtype=torch.float64)
# Epoch 1/8 at cost=8.143846152997014e-10
# [Parameter containing:
# tensor(7.016e-01, requires_grad=True), Parameter containing:
# tensor(3.915e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.261e-09) tensor(8.648e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.190541164599381e-10
# [Parameter containing:
# tensor(7.016e-01, requires_grad=True), Parameter containing:
# tensor(3.915e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.181e-04) tensor(-2.850e-04, dtype=torch.float64)
# Epoch 1/8 at cost=2.460600398990209e-07
# [Parameter containing:
# tensor(7.016e-01, requires_grad=True), Parameter containing:
# tensor(3.915e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.094e-09) tensor(8.643e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.917497792826907e-07
# [Parameter containing:
# tensor(7.015e-01, requires_grad=True), Parameter containing:
# tensor(3.915e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.913e-12) tensor(4.649e-12, dtype=torch.float64)
# Epoch 1/8 at cost=4.3984895725657225e-09
# [Parameter containing:
# tensor(7.015e-01, requires_grad=True), Parameter containing:
# tensor(3.915e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.790e-09) tensor(1.781e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.3714341884352166e-09
# [Parameter containing:
# tensor(7.015e-01, requires_grad=True), Parameter containing:
# tensor(3.915e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.808e-12) tensor(7.388e-12, dtype=torch.float64)
# Epoch 1/8 at cost=3.8352493447746383e-07
# [Parameter containing:
# tensor(7.016e-01, requires_grad=True), Parameter containing:
# tensor(3.924e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.407e-05) tensor(-6.637e-05, dtype=torch.float64)
# Epoch 1/8 at cost=2.2048645860195393e-06
# [Parameter containing:
# tensor(7.016e-01, requires_grad=True), Parameter containing:
# tensor(3.933e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.522e-07) tensor(1.432e-07, dtype=torch.float64)
# Epoch 1/8 at cost=4.383991836220957e-09
# [Parameter containing:
# tensor(7.017e-01, requires_grad=True), Parameter containing:
# tensor(3.942e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.763e-10) tensor(-2.819e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.5285534611139155e-07
# [Parameter containing:
# tensor(7.018e-01, requires_grad=True), Parameter containing:
# tensor(3.949e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.089e-08) tensor(2.896e-08, dtype=torch.float64)
# Epoch 1/8 at cost=8.155644493079706e-10
# [Parameter containing:
# tensor(7.018e-01, requires_grad=True), Parameter containing:
# tensor(3.955e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.471e-13) tensor(-5.809e-13, dtype=torch.float64)
# Epoch 1/8 at cost=1.1737535388078868e-09
# [Parameter containing:
# tensor(7.015e-01, requires_grad=True), Parameter containing:
# tensor(3.920e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.032e-04) tensor(2.690e-04, dtype=torch.float64)
# Epoch 1/8 at cost=2.996841601543565e-07
# [Parameter containing:
# tensor(7.016e-01, requires_grad=True), Parameter containing:
# tensor(3.931e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.135e-04) tensor(-2.804e-04, dtype=torch.float64)
# Epoch 1/8 at cost=2.3232989576627006e-07
# [Parameter containing:
# tensor(7.013e-01, requires_grad=True), Parameter containing:
# tensor(3.904e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.823e-04) tensor(2.519e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.6963221582955157e-07
# [Parameter containing:
# tensor(7.010e-01, requires_grad=True), Parameter containing:
# tensor(3.879e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.755e-10) tensor(5.378e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.852886981154825e-09
# [Parameter containing:
# tensor(7.008e-01, requires_grad=True), Parameter containing:
# tensor(3.856e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.678e-07) tensor(4.453e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.794280167834785e-10
# [Parameter containing:
# tensor(7.006e-01, requires_grad=True), Parameter containing:
# tensor(3.835e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.441e-10) tensor(1.454e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.0375804659901178e-09
# [Parameter containing:
# tensor(7.004e-01, requires_grad=True), Parameter containing:
# tensor(3.817e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.144e-13) tensor(-7.383e-13, dtype=torch.float64)
# Epoch 1/8 at cost=3.3795552667470474e-07
# [Parameter containing:
# tensor(7.002e-01, requires_grad=True), Parameter containing:
# tensor(3.801e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.084e-06) tensor(-2.012e-06, dtype=torch.float64)
# Epoch 1/8 at cost=3.26691811380897e-08
# [Parameter containing:
# tensor(7.001e-01, requires_grad=True), Parameter containing:
# tensor(3.786e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.001e-12) tensor(9.074e-12, dtype=torch.float64)
# Epoch 1/8 at cost=6.059388407697597e-11
# [Parameter containing:
# tensor(6.999e-01, requires_grad=True), Parameter containing:
# tensor(3.772e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.686e-13) tensor(-9.098e-13, dtype=torch.float64)
# Epoch 1/8 at cost=7.597328988140362e-09
# [Parameter containing:
# tensor(6.998e-01, requires_grad=True), Parameter containing:
# tensor(3.760e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.442e-10) tensor(1.573e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.917340336556663e-07
# [Parameter containing:
# tensor(6.997e-01, requires_grad=True), Parameter containing:
# tensor(3.750e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.549e-06) tensor(-3.476e-06, dtype=torch.float64)
# Epoch 1/8 at cost=3.950702591737354e-07
# [Parameter containing:
# tensor(6.996e-01, requires_grad=True), Parameter containing:
# tensor(3.741e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.150e-09) tensor(2.112e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.7228937799227424e-07
# [Parameter containing:
# tensor(6.995e-01, requires_grad=True), Parameter containing:
# tensor(3.732e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.000e-12) tensor(-2.201e-12, dtype=torch.float64)
# Epoch 1/8 at cost=4.405226849968358e-09
# [Parameter containing:
# tensor(6.995e-01, requires_grad=True), Parameter containing:
# tensor(3.727e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.581e-05) tensor(-1.559e-05, dtype=torch.float64)
# Epoch 1/8 at cost=1.3771685871688533e-06
# [Parameter containing:
# tensor(6.994e-01, requires_grad=True), Parameter containing:
# tensor(3.722e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.523e-10) tensor(2.893e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.7911467581631655e-10
# [Parameter containing:
# tensor(6.994e-01, requires_grad=True), Parameter containing:
# tensor(3.718e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.647e-07) tensor(-7.562e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.179221437221713e-07
# [Parameter containing:
# tensor(6.995e-01, requires_grad=True), Parameter containing:
# tensor(3.731e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.129e-04) tensor(-1.075e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.4632493048338802e-06
# [Parameter containing:
# tensor(6.996e-01, requires_grad=True), Parameter containing:
# tensor(3.743e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.804e-06) tensor(-2.767e-06, dtype=torch.float64)
# Epoch 1/8 at cost=1.9475150381254025e-08
# [Parameter containing:
# tensor(6.997e-01, requires_grad=True), Parameter containing:
# tensor(3.754e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.820e-10) tensor(7.081e-10, dtype=torch.float64)
# Epoch 1/8 at cost=6.114733719364551e-12
# [Parameter containing:
# tensor(7.001e-01, requires_grad=True), Parameter containing:
# tensor(3.801e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.500e-04) tensor(-2.329e-04, dtype=torch.float64)
# Epoch 1/8 at cost=1.7778079097752197e-07
# [Parameter containing:
# tensor(7.005e-01, requires_grad=True), Parameter containing:
# tensor(3.842e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.885e-13) tensor(5.649e-13, dtype=torch.float64)
# Epoch 1/8 at cost=1.1964025325994498e-09
# [Parameter containing:
# tensor(7.008e-01, requires_grad=True), Parameter containing:
# tensor(3.880e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.281e-10) tensor(1.382e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.8859150208736537e-07
# [Parameter containing:
# tensor(7.012e-01, requires_grad=True), Parameter containing:
# tensor(3.914e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.184e-12) tensor(-8.139e-12, dtype=torch.float64)
# Epoch 1/8 at cost=6.807310826140167e-10
# [Parameter containing:
# tensor(7.014e-01, requires_grad=True), Parameter containing:
# tensor(3.945e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.073e-10) tensor(-3.239e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.473120025963226e-08
# [Parameter containing:
# tensor(7.017e-01, requires_grad=True), Parameter containing:
# tensor(3.973e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.636e-11) tensor(4.849e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.2797794207995992e-10
# [Parameter containing:
# tensor(7.019e-01, requires_grad=True), Parameter containing:
# tensor(3.998e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.385e-10) tensor(2.374e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.747578259880811e-08
# [Parameter containing:
# tensor(7.021e-01, requires_grad=True), Parameter containing:
# tensor(4.020e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.171e-07) tensor(2.006e-07, dtype=torch.float64)
# Epoch 1/8 at cost=8.204908419351398e-10
# [Parameter containing:
# tensor(7.023e-01, requires_grad=True), Parameter containing:
# tensor(4.041e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.549e-12) tensor(6.689e-12, dtype=torch.float64)
# Epoch 1/8 at cost=6.618111569878238e-07
# [Parameter containing:
# tensor(7.016e-01, requires_grad=True), Parameter containing:
# tensor(3.968e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.857e-04) tensor(5.962e-04, dtype=torch.float64)
# Epoch 1/8 at cost=6.471224764936778e-07
# [Parameter containing:
# tensor(7.013e-01, requires_grad=True), Parameter containing:
# tensor(3.938e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.601e-04) tensor(-2.300e-04, dtype=torch.float64)
# Epoch 2/8 at cost=1.895093532766623e-06
# [Parameter containing:
# tensor(7.014e-01, requires_grad=True), Parameter containing:
# tensor(3.955e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.366e-04) tensor(-2.997e-04, dtype=torch.float64)
# Epoch 2/8 at cost=5.924013635194569e-07
# [Parameter containing:
# tensor(7.015e-01, requires_grad=True), Parameter containing:
# tensor(3.970e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.690e-06) tensor(1.577e-06, dtype=torch.float64)
# Epoch 2/8 at cost=2.0545793955051295e-09
# [Parameter containing:
# tensor(7.016e-01, requires_grad=True), Parameter containing:
# tensor(3.984e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.171e-12) tensor(-1.210e-12, dtype=torch.float64)
# Epoch 2/8 at cost=6.162159671418976e-09
# [Parameter containing:
# tensor(7.017e-01, requires_grad=True), Parameter containing:
# tensor(3.996e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.918e-14) tensor(-1.100e-13, dtype=torch.float64)
# Epoch 2/8 at cost=1.506108432414166e-10
# [Parameter containing:
# tensor(7.018e-01, requires_grad=True), Parameter containing:
# tensor(4.008e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.754e-13) tensor(5.661e-13, dtype=torch.float64)
# Epoch 2/8 at cost=4.150372406863667e-11
# [Parameter containing:
# tensor(7.019e-01, requires_grad=True), Parameter containing:
# tensor(4.018e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.024e-10) tensor(8.755e-10, dtype=torch.float64)
# Epoch 2/8 at cost=1.3417024158357549e-09
# [Parameter containing:
# tensor(7.020e-01, requires_grad=True), Parameter containing:
# tensor(4.027e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.264e-11) tensor(6.200e-11, dtype=torch.float64)
# Epoch 2/8 at cost=1.3409813537368365e-10
# [Parameter containing:
# tensor(7.021e-01, requires_grad=True), Parameter containing:
# tensor(4.035e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.178e-09) tensor(4.751e-09, dtype=torch.float64)
# Epoch 2/8 at cost=2.7589121959215035e-11
# [Parameter containing:
# tensor(7.021e-01, requires_grad=True), Parameter containing:
# tensor(4.043e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.290e-09) tensor(-5.113e-09, dtype=torch.float64)
# Epoch 2/8 at cost=8.746377488932922e-07
# [Parameter containing:
# tensor(7.024e-01, requires_grad=True), Parameter containing:
# tensor(4.069e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.511e-04) tensor(-1.312e-04, dtype=torch.float64)
# Epoch 2/8 at cost=5.323954610503279e-08
# [Parameter containing:
# tensor(7.031e-01, requires_grad=True), Parameter containing:
# tensor(4.140e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.613e-04) tensor(-3.118e-04, dtype=torch.float64)
# Epoch 2/8 at cost=2.68972655703692e-07
# [Parameter containing:
# tensor(7.037e-01, requires_grad=True), Parameter containing:
# tensor(4.203e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.057e-14) tensor(-6.255e-14, dtype=torch.float64)
# Epoch 2/8 at cost=1.0107506795975496e-06
# [Parameter containing:
# tensor(7.043e-01, requires_grad=True), Parameter containing:
# tensor(4.260e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.212e-12) tensor(-6.168e-12, dtype=torch.float64)
# Epoch 2/8 at cost=4.3294286911077506e-07
# [Parameter containing:
# tensor(7.048e-01, requires_grad=True), Parameter containing:
# tensor(4.312e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.345e-08) tensor(5.521e-08, dtype=torch.float64)
# Epoch 2/8 at cost=1.7634713134206947e-10
# [Parameter containing:
# tensor(7.053e-01, requires_grad=True), Parameter containing:
# tensor(4.358e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.074e-08) tensor(2.791e-08, dtype=torch.float64)
# Epoch 2/8 at cost=3.133525581233698e-07
# [Parameter containing:
# tensor(7.057e-01, requires_grad=True), Parameter containing:
# tensor(4.400e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.184e-09) tensor(3.764e-09, dtype=torch.float64)
# Epoch 2/8 at cost=4.904200636701717e-07
# [Parameter containing:
# tensor(7.053e-01, requires_grad=True), Parameter containing:
# tensor(4.371e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.585e-04) tensor(4.478e-04, dtype=torch.float64)
# Epoch 2/8 at cost=4.618267723799363e-07
# [Parameter containing:
# ...
# tensor(6.932e-01, requires_grad=True), Parameter containing:
# tensor(5.821e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.181e-11) tensor(-8.971e-12, dtype=torch.float64)
# Epoch 8/8 at cost=4.1411567508475855e-07
# [Parameter containing:
# tensor(6.940e-01, requires_grad=True), Parameter containing:
# tensor(5.884e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.523e-05) tensor(2.098e-05, dtype=torch.float64)
# Epoch 8/8 at cost=5.83465123327187e-07
# [Parameter containing:
# tensor(6.946e-01, requires_grad=True), Parameter containing:
# tensor(5.941e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.784e-12) tensor(1.233e-12, dtype=torch.float64)
# Epoch 8/8 at cost=5.339030550999269e-09
# [Parameter containing:
# tensor(6.952e-01, requires_grad=True), Parameter containing:
# tensor(5.992e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.628e-07) tensor(2.233e-07, dtype=torch.float64)
# Epoch 8/8 at cost=1.0176983700205255e-09
# [Parameter containing:
# tensor(6.950e-01, requires_grad=True), Parameter containing:
# tensor(5.982e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.701e-04) tensor(2.727e-04, dtype=torch.float64)
# Epoch 8/8 at cost=7.969861712808779e-07
# [Parameter containing:
# tensor(6.949e-01, requires_grad=True), Parameter containing:
# tensor(5.973e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.705e-12) tensor(-1.229e-12, dtype=torch.float64)
# Epoch 8/8 at cost=9.425350500080754e-10
# [Parameter containing:
# tensor(6.948e-01, requires_grad=True), Parameter containing:
# tensor(5.965e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.761e-07) tensor(2.303e-07, dtype=torch.float64)
# Epoch 8/8 at cost=3.398366743567749e-07
# [Parameter containing:
# tensor(6.946e-01, requires_grad=True), Parameter containing:
# tensor(5.949e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.538e-05) tensor(4.390e-05, dtype=torch.float64)
# Epoch 8/8 at cost=1.2428119866569887e-08
# [Parameter containing:
# tensor(6.944e-01, requires_grad=True), Parameter containing:
# tensor(5.934e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.902e-07) tensor(2.398e-07, dtype=torch.float64)
# Epoch 8/8 at cost=4.694549602390907e-07
# [Parameter containing:
# tensor(6.942e-01, requires_grad=True), Parameter containing:
# tensor(5.921e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.549e-07) tensor(2.802e-07, dtype=torch.float64)
# Epoch 8/8 at cost=7.705762641307956e-07
# [Parameter containing:
# tensor(6.940e-01, requires_grad=True), Parameter containing:
# tensor(5.909e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.181e-09) tensor(-2.072e-09, dtype=torch.float64)
# Epoch 8/8 at cost=1.3586410432253615e-06
# [Parameter containing:
# tensor(6.939e-01, requires_grad=True), Parameter containing:
# tensor(5.898e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.193e-07) tensor(7.387e-08, dtype=torch.float64)
# Epoch 8/8 at cost=3.2632362945150817e-07
# [Parameter containing:
# tensor(6.929e-01, requires_grad=True), Parameter containing:
# tensor(5.818e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.902e-04) tensor(3.472e-04, dtype=torch.float64)
# Epoch 8/8 at cost=4.152031749526941e-07
# [Parameter containing:
# tensor(6.920e-01, requires_grad=True), Parameter containing:
# tensor(5.746e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.652e-09) tensor(1.160e-09, dtype=torch.float64)
# Epoch 8/8 at cost=3.9759612491252483e-07
# [Parameter containing:
# tensor(6.918e-01, requires_grad=True), Parameter containing:
# tensor(5.725e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.562e-04) tensor(-2.145e-04, dtype=torch.float64)
# Epoch 8/8 at cost=2.314611293741109e-07
# [Parameter containing:
# tensor(6.915e-01, requires_grad=True), Parameter containing:
# tensor(5.705e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.827e-08) tensor(3.069e-08, dtype=torch.float64)
# Epoch 8/8 at cost=2.163288570500299e-08
# [Parameter containing:
# tensor(6.911e-01, requires_grad=True), Parameter containing:
# tensor(5.671e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.378e-04) tensor(8.353e-05, dtype=torch.float64)
# Epoch 8/8 at cost=3.0942587159188406e-07
# [Parameter containing:
# tensor(6.907e-01, requires_grad=True), Parameter containing:
# tensor(5.640e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.596e-07) tensor(1.665e-07, dtype=torch.float64)
# Epoch 8/8 at cost=1.0749232615125948e-09
# [Parameter containing:
# tensor(6.904e-01, requires_grad=True), Parameter containing:
# tensor(5.613e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.913e-07) tensor(-1.232e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.8463038592718704e-09
# [Parameter containing:
# tensor(6.896e-01, requires_grad=True), Parameter containing:
# tensor(5.550e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.990e-04) tensor(1.839e-04, dtype=torch.float64)
# Epoch 8/8 at cost=2.2558847945219895e-07
# [Parameter containing:
# tensor(6.890e-01, requires_grad=True), Parameter containing:
# tensor(5.494e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.343e-11) tensor(9.826e-12, dtype=torch.float64)
# Epoch 8/8 at cost=4.4325015879920215e-10
# [Parameter containing:
# tensor(6.884e-01, requires_grad=True), Parameter containing:
# tensor(5.444e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.305e-07) tensor(2.842e-07, dtype=torch.float64)
# Epoch 8/8 at cost=3.23639824273414e-07
# [Parameter containing:
# tensor(6.878e-01, requires_grad=True), Parameter containing:
# tensor(5.398e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.178e-10) tensor(-1.529e-10, dtype=torch.float64)
# Epoch 8/8 at cost=1.7877042068903393e-09
# [Parameter containing:
# tensor(6.874e-01, requires_grad=True), Parameter containing:
# tensor(5.357e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.551e-10) tensor(1.096e-10, dtype=torch.float64)
# Epoch 8/8 at cost=6.01942551359258e-10
# [Parameter containing:
# tensor(6.869e-01, requires_grad=True), Parameter containing:
# tensor(5.320e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.819e-12) tensor(-2.113e-12, dtype=torch.float64)
# Epoch 8/8 at cost=8.612024288146003e-11
# [Parameter containing:
# tensor(6.865e-01, requires_grad=True), Parameter containing:
# tensor(5.287e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.413e-07) tensor(-9.590e-08, dtype=torch.float64)
# Epoch 8/8 at cost=2.758047230599914e-07
# [Parameter containing:
# tensor(6.862e-01, requires_grad=True), Parameter containing:
# tensor(5.257e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.994e-11) tensor(-2.233e-11, dtype=torch.float64)
# Epoch 8/8 at cost=3.458275443790626e-07
# [Parameter containing:
# tensor(6.859e-01, requires_grad=True), Parameter containing:
# tensor(5.230e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.956e-11) tensor(2.436e-11, dtype=torch.float64)
# Epoch 8/8 at cost=3.9173008303805545e-07
# [Parameter containing:
# tensor(6.856e-01, requires_grad=True), Parameter containing:
# tensor(5.206e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.906e-09) tensor(3.576e-09, dtype=torch.float64)
# Epoch 8/8 at cost=3.0351088753377553e-07
# [Parameter containing:
# tensor(6.856e-01, requires_grad=True), Parameter containing:
# tensor(5.211e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.050e-04) tensor(-1.350e-04, dtype=torch.float64)
# Epoch 8/8 at cost=3.9257446360352333e-07
# [Parameter containing:
# tensor(6.857e-01, requires_grad=True), Parameter containing:
# tensor(5.216e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.890e-11) tensor(6.110e-11, dtype=torch.float64)
# Epoch 8/8 at cost=3.8346587416526745e-07
# [Parameter containing:
# tensor(6.857e-01, requires_grad=True), Parameter containing:
# tensor(5.222e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.103e-06) tensor(-3.530e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.5668273337942082e-06
# [Parameter containing:
# tensor(6.858e-01, requires_grad=True), Parameter containing:
# tensor(5.234e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.627e-05) tensor(-3.694e-05, dtype=torch.float64)
# Epoch 8/8 at cost=2.7540647806745255e-07
# [Parameter containing:
# tensor(6.859e-01, requires_grad=True), Parameter containing:
# tensor(5.245e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.785e-12) tensor(-1.487e-12, dtype=torch.float64)
# Epoch 8/8 at cost=4.5288581418390095e-07
# [Parameter containing:
# tensor(6.860e-01, requires_grad=True), Parameter containing:
# tensor(5.255e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.020e-13) tensor(-6.436e-14, dtype=torch.float64)
# Epoch 8/8 at cost=2.8384616257426387e-07
# [Parameter containing:
# tensor(6.861e-01, requires_grad=True), Parameter containing:
# tensor(5.264e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.358e-13) tensor(8.424e-14, dtype=torch.float64)
# Epoch 8/8 at cost=2.7462078833195847e-07
# [Parameter containing:
# tensor(6.862e-01, requires_grad=True), Parameter containing:
# tensor(5.273e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.431e-12) tensor(7.011e-12, dtype=torch.float64)
# Epoch 8/8 at cost=8.361774348486506e-07
# [Parameter containing:
# tensor(6.862e-01, requires_grad=True), Parameter containing:
# tensor(5.280e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.809e-06) tensor(-1.239e-06, dtype=torch.float64)
# Epoch 8/8 at cost=6.844146014373109e-07
# [Parameter containing:
# tensor(6.863e-01, requires_grad=True), Parameter containing:
# tensor(5.287e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.912e-08) tensor(-1.992e-08, dtype=torch.float64)
# Epoch 8/8 at cost=4.785494223114029e-10
# [Parameter containing:
# tensor(6.863e-01, requires_grad=True), Parameter containing:
# tensor(5.293e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.908e-09) tensor(-1.376e-09, dtype=torch.float64)
# Epoch 8/8 at cost=4.547558773992932e-09
# [Parameter containing:
# tensor(6.864e-01, requires_grad=True), Parameter containing:
# tensor(5.299e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.415e-11) tensor(4.618e-11, dtype=torch.float64)
# Epoch 8/8 at cost=1.1151717743684841e-10
# [Parameter containing:
# tensor(6.864e-01, requires_grad=True), Parameter containing:
# tensor(5.304e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.811e-12) tensor(2.133e-12, dtype=torch.float64)
# Epoch 8/8 at cost=1.0354010981927786e-09
# [Parameter containing:
# tensor(6.865e-01, requires_grad=True), Parameter containing:
# tensor(5.308e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.230e-09) tensor(8.847e-10, dtype=torch.float64)
# Epoch 8/8 at cost=3.379406336989632e-07
# [Parameter containing:
# tensor(6.865e-01, requires_grad=True), Parameter containing:
# tensor(5.312e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.359e-06) tensor(-9.250e-07, dtype=torch.float64)
# Epoch 8/8 at cost=3.6769751687870667e-08
# [Parameter containing:
# tensor(6.866e-01, requires_grad=True), Parameter containing:
# tensor(5.316e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.636e-12) tensor(-1.972e-12, dtype=torch.float64)
# Epoch 8/8 at cost=6.043921613185788e-11
# [Parameter containing:
# tensor(6.866e-01, requires_grad=True), Parameter containing:
# tensor(5.320e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.827e-12) tensor(-4.800e-12, dtype=torch.float64)
# Epoch 8/8 at cost=7.593944140182884e-09
# [Parameter containing:
# tensor(6.866e-01, requires_grad=True), Parameter containing:
# tensor(5.323e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.041e-10) tensor(7.874e-11, dtype=torch.float64)
# Epoch 8/8 at cost=3.9172522292574286e-07
# [Parameter containing:
# tensor(6.869e-01, requires_grad=True), Parameter containing:
# tensor(5.346e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.543e-04) tensor(-9.954e-05, dtype=torch.float64)
# Epoch 8/8 at cost=4.6155133759384626e-07
# [Parameter containing:
# tensor(6.871e-01, requires_grad=True), Parameter containing:
# tensor(5.367e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.655e-09) tensor(1.120e-09, dtype=torch.float64)
# Epoch 8/8 at cost=3.722889516666328e-07
# [Parameter containing:
# tensor(6.873e-01, requires_grad=True), Parameter containing:
# tensor(5.386e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.553e-13) tensor(5.297e-13, dtype=torch.float64)
# Epoch 8/8 at cost=4.399962172385585e-09
# [Parameter containing:
# tensor(6.875e-01, requires_grad=True), Parameter containing:
# tensor(5.404e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.783e-06) tensor(-5.899e-06, dtype=torch.float64)
# Epoch 8/8 at cost=1.3625777910419856e-06
# [Parameter containing:
# tensor(6.877e-01, requires_grad=True), Parameter containing:
# tensor(5.421e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.505e-11) tensor(-1.056e-11, dtype=torch.float64)
# Epoch 8/8 at cost=2.7771490662686915e-10
# [Parameter containing:
# tensor(6.881e-01, requires_grad=True), Parameter containing:
# tensor(5.464e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.163e-04) tensor(-1.372e-04, dtype=torch.float64)
# Epoch 8/8 at cost=1.2641744717711845e-07
# [Parameter containing:
# tensor(6.885e-01, requires_grad=True), Parameter containing:
# tensor(5.503e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.669e-10) tensor(-4.948e-10, dtype=torch.float64)
# Epoch 8/8 at cost=1.4068560858504497e-06
# [Parameter containing:
# tensor(6.889e-01, requires_grad=True), Parameter containing:
# tensor(5.538e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.510e-12) tensor(6.296e-12, dtype=torch.float64)
# Epoch 8/8 at cost=1.548563588471552e-08
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.569e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.623e-14) tensor(2.275e-14, dtype=torch.float64)
# Epoch 8/8 at cost=6.199329244394036e-12
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.571e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.107e-04) tensor(1.304e-04, dtype=torch.float64)
# Epoch 8/8 at cost=4.276785716683662e-07
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.572e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.128e-12) tensor(2.411e-12, dtype=torch.float64)
# Epoch 8/8 at cost=1.1954414125270318e-09
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.573e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.822e-08) tensor(1.186e-08, dtype=torch.float64)
# Epoch 8/8 at cost=3.8860090967318683e-07
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.574e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.766e-10) tensor(1.887e-10, dtype=torch.float64)
# Epoch 8/8 at cost=6.803179131154025e-10
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.575e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.333e-07) tensor(2.820e-07, dtype=torch.float64)
# Epoch 8/8 at cost=1.4919638857691098e-08
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.575e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.997e-08) tensor(3.252e-08, dtype=torch.float64)
# Epoch 8/8 at cost=2.4061519443563384e-10
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.576e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.366e-10) tensor(1.655e-10, dtype=torch.float64)
# Epoch 8/8 at cost=1.7486629033669487e-08
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.577e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.161e-14) tensor(5.374e-14, dtype=torch.float64)
# Epoch 8/8 at cost=7.651226319183024e-10
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.577e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.833e-11) tensor(-3.379e-11, dtype=torch.float64)
# Epoch 8/8 at cost=6.618123506996199e-07
# [Parameter containing:
# tensor(6.893e-01, requires_grad=True), Parameter containing:
# tensor(5.578e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.475e-07) tensor(2.261e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.503546738807927e-07
# Finished Training

# %% [markdown]
# #### Evaluating unrolled network on train dataset

# %%
out_bftrain3, out_hat3 = get_net_outputs(net3, LearnedAAP(max_iter, d1, d2), r, train3)
out_accaltproj3 = []
for i, (L_true, S_true, M_true) in enumerate(train3):
    loss, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    out_accaltproj3.append((L0, S0))

# %%
metrics = get_metrics(train3, [x[:2] for x in train_est3], out_bftrain3, out_hat3)
fro_norm_L_old, mse_S_old, fro_norm_S_old, count_nonzeros_S_old, relative_err_old, \
    fro_norm_L_new, mse_S_new, fro_norm_S_new, count_nonzeros_S_new, relative_err_new, \
    fro_norm_L_bftrain, mse_S_bftrain, fro_norm_S_bftrain, count_nonzeros_S_bftrain, relative_err_bftrain \
        = metrics.values()
fro_norm_L_accaltproj, mse_S_accaltproj, fro_norm_S_accaltproj, count_nonzeros_S_accaltproj, relative_err_accaltproj \
    = list(get_metrics(train3, out_accaltproj3, out_bftrain3, out_hat3).values())[:5]

fig, ax = plt.subplots()
ax.boxplot([relative_err_old, relative_err_new, relative_err_bftrain, relative_err_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["relative_err_old", "relative_err_new", "relative_err_bftrain", "relative_err_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_L_old, fro_norm_L_new, fro_norm_L_bftrain, fro_norm_L_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["fro_norm_L_old", "fro_norm_L_new", "fro_norm_L_bfaftrain", "fro_norm_L_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([mse_S_old, mse_S_new, mse_S_bftrain, mse_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["mse_S_old", "mse_S_new", "mse_S_bfaftrain", "mse_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_S_old, fro_norm_S_new, fro_norm_S_bftrain, fro_norm_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["fro_norm_S_old", "fro_norm_S_new", "fro_norm_S_bfaftrain", "fro_norm_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([count_nonzeros_S_old, count_nonzeros_S_new, count_nonzeros_S_bftrain, count_nonzeros_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["count_nonzeros_S_old", "count_nonzeros_S_new", "count_nonzeros_S_bfaftrain", "count_nonzeros_S_accaltproj"])
plt.show()
# Out:
# /Users/elitanzc/Github/FYP/helper.py:254: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat1 = (torch.tensor(mat1) == 0)
# /Users/elitanzc/Github/FYP/helper.py:255: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat2 = (torch.tensor(mat2) == 0)

# %%
print("P-values from test of mean with H1: _new < _old")
print("relative_err_new, relative_err_old: ", stats.ttest_rel(relative_err_new, relative_err_old, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_old, alternative='less').pvalue)
print("mse_S_new, mse_S_old: ", stats.ttest_rel(mse_S_new, mse_S_old, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_old, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_old, alternative='less').pvalue)
print()
print("P-values from test of mean with H1: _new < _accaltproj")
print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(relative_err_new, relative_err_accaltproj, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_accaltproj, alternative='less').pvalue)
print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(mse_S_new, mse_S_accaltproj, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_accaltproj, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_accaltproj, alternative='less').pvalue)
print()
print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(relative_err_new, relative_err_bftrain, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_bftrain, alternative='less').pvalue)
print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(mse_S_new, mse_S_bftrain, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_bftrain, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_bftrain, alternative='less').pvalue)

# print("*Note: values are log-transformed before deriving p-values")
# print()
# print("relative_err_new, relative_err_old: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_old), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_old), alternative='less').pvalue)
# print("mse_S_new, mse_S_old: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_old), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_old), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_old), alternative='less').pvalue)
# print()
# print("P-values from test of mean with H1: _new < _accaltproj")
# print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_accaltproj), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_accaltproj), alternative='less').pvalue)
# print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_accaltproj), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_accaltproj), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_accaltproj), alternative='less').pvalue)
# print()
# print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_bftrain), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_bftrain), alternative='less').pvalue)
# print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_bftrain), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_bftrain), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_bftrain), alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new < _old
# relative_err_new, relative_err_old:  6.559089119779721e-17
# fro_norm_L_new, fro_norm_L_old:  0.9994114061246642
# mse_S_new, mse_S_old:  2.399054884843929e-06
# fro_norm_S_new, fro_norm_S_old:  1.6153117956347862e-17
# count_nonzeros_S_new, count_nonzeros_S_old:  2.390758124913258e-32
#
# P-values from test of mean with H1: _new < _accaltproj
# relative_err_new, relative_err_accaltproj:  8.042545913204077e-27
# fro_norm_L_new, fro_norm_L_accaltproj:  9.044108754730392e-21
# mse_S_new, mse_S_accaltproj:  1.8366283428967268e-08
# fro_norm_S_new, fro_norm_S_accaltproj:  4.983392022764173e-13
# count_nonzeros_S_new, count_nonzeros_S_accaltproj:  8.528939427616128e-10
#
# relative_err_new, relative_err_bftrain:  1.0
# fro_norm_L_new, fro_norm_L_bftrain:  1.444219023948675e-51
# mse_S_new, mse_S_bftrain:  8.670292439839795e-26
# fro_norm_S_new, fro_norm_S_bftrain:  6.303017468666525e-70
# count_nonzeros_S_new, count_nonzeros_S_bftrain:  2.708621814182311e-175

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_old[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_old[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_old[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_old[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2174885101.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 9/180 outliers
# fro_norm_L: 4/180 outliers
# mse_S: 22/180 outliers
# fro_norm_S: 4/180 outliers
# count_nonzeros_S: 0/180 outliers

# %%
print("P-values from test of mean with H1: _new/_old < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_old < 1
# relative_err:  2.68449764667248e-23
# fro_norm_L:  0.999999999853699
# mse_S:  1.1917107132213976e-05
# fro_norm_S:  2.1535859572592223e-26
# count_nonzeros_S:  nan

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_accaltproj[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_accaltproj[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_accaltproj[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_accaltproj[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2948823882.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 3/180 outliers
# fro_norm_L: 2/180 outliers
# mse_S: 7/180 outliers
# fro_norm_S: 1/180 outliers
# count_nonzeros_S: 0/180 outliers

# %%
print("P-values from test of mean with H1: _new/_accaltproj < 1")
#print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_accaltproj < 1
# relative_err:  2.2123296706440695e-27
# fro_norm_L:  2.1799247103752443e-20
# mse_S:  6.399915430258021e-35
# fro_norm_S:  1.011857804581503e-38
# count_nonzeros_S:  nan

# %%
print(np.median(count_nonzeros_S_new), np.mean(count_nonzeros_S_new), np.max(count_nonzeros_S_new))
print(np.median(count_nonzeros_S_accaltproj), np.mean(count_nonzeros_S_accaltproj), np.max(count_nonzeros_S_accaltproj))
print(np.median(count_nonzeros_S_old), np.mean(count_nonzeros_S_old), np.max(count_nonzeros_S_old))
# Out:
# 0.0 7.9999995e-07 1.6e-05
# 0.0 3.911111e-06 3.2e-05
# 1.6e-05 2.1155556e-05 8e-05

# %% [markdown]
# #### Evaluating unrolled network on test dataset

# %%
out_bftrain_ontest3, out_hat_ontest3 = get_net_outputs(net3, LearnedAAP(max_iter, d1, d2), r, test3)
out_accaltproj_ontest3 = []
out_ircur_ontest3 = []
for (L_true, S_true, M_true) in test3:
    loss0, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    out_accaltproj_ontest3.append((L0, S0))
    loss0, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    out_ircur_ontest3.append((L0, S0))

# %%
metrics = get_metrics(test3, out_ircur_ontest3, out_bftrain_ontest3, out_hat_ontest3)
fro_norm_L_old, mse_S_old, fro_norm_S_old, count_nonzeros_S_old, relative_err_old, \
    fro_norm_L_new, mse_S_new, fro_norm_S_new, count_nonzeros_S_new, relative_err_new, \
    fro_norm_L_bftrain, mse_S_bftrain, fro_norm_S_bftrain, count_nonzeros_S_bftrain, relative_err_bftrain \
        = metrics.values()
fro_norm_L_accaltproj, mse_S_accaltproj, fro_norm_S_accaltproj, count_nonzeros_S_accaltproj, relative_err_accaltproj \
    = list(get_metrics(test3, out_accaltproj_ontest3, out_bftrain_ontest3, out_hat_ontest3).values())[:5]

fig, ax = plt.subplots()
ax.boxplot([relative_err_old, relative_err_new, relative_err_bftrain, relative_err_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["relative_err_old", "relative_err_new", "relative_err_bftrain", "relative_err_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_L_old, fro_norm_L_new, fro_norm_L_bftrain, fro_norm_L_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["fro_norm_L_old", "fro_norm_L_new", "fro_norm_L_bfaftrain", "fro_norm_L_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([mse_S_old, mse_S_new, mse_S_bftrain, mse_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["mse_S_old", "mse_S_new", "mse_S_bfaftrain", "mse_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_S_old, fro_norm_S_new, fro_norm_S_bftrain, fro_norm_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["fro_norm_S_old", "fro_norm_S_new", "fro_norm_S_bfaftrain", "fro_norm_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([count_nonzeros_S_old, count_nonzeros_S_new, count_nonzeros_S_bftrain, count_nonzeros_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["count_nonzeros_S_old", "count_nonzeros_S_new", "count_nonzeros_S_bfaftrain", "count_nonzeros_S_accaltproj"])
plt.show()
# Out:
# /Users/elitanzc/Github/FYP/helper.py:254: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat1 = (torch.tensor(mat1) == 0)
# /Users/elitanzc/Github/FYP/helper.py:255: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat2 = (torch.tensor(mat2) == 0)

# %%
print("P-values from test of mean with H1: _new < _old")
print("relative_err_new, relative_err_old: ", stats.ttest_rel(relative_err_new, relative_err_old, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_old, alternative='less').pvalue)
print("mse_S_new, mse_S_old: ", stats.ttest_rel(mse_S_new, mse_S_old, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_old, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_old, alternative='less').pvalue)
print()
print("P-values from test of mean with H1: _new < _accaltproj")
print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(relative_err_new, relative_err_accaltproj, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_accaltproj, alternative='less').pvalue)
print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(mse_S_new, mse_S_accaltproj, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_accaltproj, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_accaltproj, alternative='less').pvalue)
print()
print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(relative_err_new, relative_err_bftrain, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_bftrain, alternative='less').pvalue)
print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(mse_S_new, mse_S_bftrain, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_bftrain, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_bftrain, alternative='less').pvalue)

# print("*Note: values are log-transformed before deriving p-values")
# print()
# print("relative_err_new, relative_err_old: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_old), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_old), alternative='less').pvalue)
# print("mse_S_new, mse_S_old: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_old), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_old), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_old), alternative='less').pvalue)
# print()
# print("P-values from test of mean with H1: _new < _accaltproj")
# print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_accaltproj), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_accaltproj), alternative='less').pvalue)
# print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_accaltproj), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_accaltproj), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_accaltproj), alternative='less').pvalue)
# print()
# print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_bftrain), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_bftrain), alternative='less').pvalue)
# print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_bftrain), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_bftrain), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_bftrain), alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new < _old
# relative_err_new, relative_err_old:  2.1274005261846353e-08
# fro_norm_L_new, fro_norm_L_old:  0.8619426980260989
# mse_S_new, mse_S_old:  0.020268141779057364
# fro_norm_S_new, fro_norm_S_old:  4.299616315186887e-09
# count_nonzeros_S_new, count_nonzeros_S_old:  2.448678209457295e-17
#
# P-values from test of mean with H1: _new < _accaltproj
# relative_err_new, relative_err_accaltproj:  1.0560786371492528e-17
# fro_norm_L_new, fro_norm_L_accaltproj:  4.245599752729798e-16
# mse_S_new, mse_S_accaltproj:  0.00015912995178441846
# fro_norm_S_new, fro_norm_S_accaltproj:  1.0395831445600261e-07
# count_nonzeros_S_new, count_nonzeros_S_accaltproj:  3.475107998788179e-05
#
# relative_err_new, relative_err_bftrain:  1.0
# fro_norm_L_new, fro_norm_L_bftrain:  1.3513058921330455e-40
# mse_S_new, mse_S_bftrain:  1.1364232395335338e-21
# fro_norm_S_new, fro_norm_S_bftrain:  3.6486811907623367e-53
# count_nonzeros_S_new, count_nonzeros_S_bftrain:  5.243294767305632e-121

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_old[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_old[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_old[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_old[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2174885101.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 2/120 outliers
# fro_norm_L: 3/120 outliers
# mse_S: 9/120 outliers
# fro_norm_S: 2/120 outliers
# count_nonzeros_S: 0/120 outliers

# %%
print("P-values from test of mean with H1: _new/_old < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_old < 1
# relative_err:  1.7573353978222205e-12
# fro_norm_L:  0.9993022265191092
# mse_S:  0.006325627833774059
# fro_norm_S:  6.868686464041275e-14
# count_nonzeros_S:  nan

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_accaltproj[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_accaltproj[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_accaltproj[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_accaltproj[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2948823882.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 3/120 outliers
# fro_norm_L: 6/120 outliers
# mse_S: 6/120 outliers
# fro_norm_S: 0/120 outliers
# count_nonzeros_S: 0/120 outliers

# %%
print("P-values from test of mean with H1: _new/_accaltproj < 1")
#print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_accaltproj < 1
# relative_err:  5.823610288219253e-19
# fro_norm_L:  3.617524149034986e-17
# mse_S:  7.43625533844258e-20
# fro_norm_S:  1.7351296696443784e-24
# count_nonzeros_S:  nan

# %%
print(np.median(count_nonzeros_S_new), np.mean(count_nonzeros_S_new), np.max(count_nonzeros_S_new))
print(np.median(count_nonzeros_S_accaltproj), np.mean(count_nonzeros_S_accaltproj), np.max(count_nonzeros_S_accaltproj))
print(np.median(count_nonzeros_S_old), np.mean(count_nonzeros_S_old), np.max(count_nonzeros_S_old))
# Out:
# 0.0 1.0666666e-06 3.2e-05
# 0.0 3.0666667e-06 3.2e-05
# 1.6e-05 1.7066668e-05 8e-05

# %% [markdown]
# ### Scenario 4:
# **alpha = 0.1** (higher sparsity), **c = 10**, r = 2, dimension = 250x250
#
# gamma=7.359e-01; beta=4.489e-02
#
# *** ***

# %%
## ======================== 0. set constants ========================
# d1 = 250                   # num. of rows
# d2 = 250                   # num. of columns
# max_iter = 100              # num. of layers trained
alpha_true = 0.1
c_true = 10
# r = 2
# dataset_size = 300

## ======================== 1. generate data ========================
train4, test4 =  generate_train_test(dataset_size, r, d1, d2, alpha_true, c_true)
# Out:
# train dataset size: 180
# test dataset size: 120

# %% [markdown]
# #### Training

# %%
## ======================== 2. estimations by classical ========================
train_est4 = []
for i, (L_true, S_true, M_true) in enumerate(train4):
    loss, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    train_est4.append((L0, S0, M_true))

# %%
## ======================== 3. train unrolled network with estimated data ========================
net4, params_bftrain4, params_aftrain4, l0_norm_of_S_Shat4 = train_nn(LearnedAAP(max_iter, d1, d2), r \
                                                                    , lr=2e-03, weight_decay=0 \
                                                                    , nepochs=8, dataset=train_est4)
# Out:
# [Parameter containing:
# tensor(7.001e-01, requires_grad=True), Parameter containing:
# tensor(3.173e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.950e-10) tensor(-5.509e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.73018629926014e-09
# [Parameter containing:
# tensor(7.001e-01, requires_grad=True), Parameter containing:
# tensor(3.180e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.479e-10) tensor(-2.192e-10, dtype=torch.float64)
# Epoch 1/8 at cost=8.563300291086762e-09
# [Parameter containing:
# tensor(7.002e-01, requires_grad=True), Parameter containing:
# tensor(3.185e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.773e-12) tensor(1.826e-12, dtype=torch.float64)
# Epoch 1/8 at cost=3.18367288087984e-09
# [Parameter containing:
# tensor(7.002e-01, requires_grad=True), Parameter containing:
# tensor(3.191e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.584e-10) tensor(-5.069e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.785397246185539e-09
# [Parameter containing:
# tensor(7.002e-01, requires_grad=True), Parameter containing:
# tensor(3.193e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.327e-10) tensor(3.910e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.402299387720518e-09
# [Parameter containing:
# tensor(7.012e-01, requires_grad=True), Parameter containing:
# tensor(3.288e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.024e-07) tensor(-2.219e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.600943904695896e-09
# [Parameter containing:
# tensor(7.020e-01, requires_grad=True), Parameter containing:
# tensor(3.369e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.424e-12) tensor(-9.609e-12, dtype=torch.float64)
# Epoch 1/8 at cost=2.653507635841379e-09
# [Parameter containing:
# tensor(7.030e-01, requires_grad=True), Parameter containing:
# tensor(3.473e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.013e-07) tensor(-1.052e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.5667561409647988e-09
# [Parameter containing:
# tensor(7.039e-01, requires_grad=True), Parameter containing:
# tensor(3.564e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.283e-10) tensor(1.299e-10, dtype=torch.float64)
# Epoch 1/8 at cost=6.925895412734917e-09
# [Parameter containing:
# tensor(7.049e-01, requires_grad=True), Parameter containing:
# tensor(3.658e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.884e-08) tensor(-4.038e-08, dtype=torch.float64)
# Epoch 1/8 at cost=6.369029303954221e-09
# [Parameter containing:
# tensor(7.057e-01, requires_grad=True), Parameter containing:
# tensor(3.744e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.113e-09) tensor(-7.868e-09, dtype=torch.float64)
# Epoch 1/8 at cost=9.073318096852745e-09
# [Parameter containing:
# tensor(7.065e-01, requires_grad=True), Parameter containing:
# tensor(3.822e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.590e-10) tensor(-9.908e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.801521319957146e-09
# [Parameter containing:
# tensor(7.072e-01, requires_grad=True), Parameter containing:
# tensor(3.891e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.071e-10) tensor(5.186e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.211333948234142e-09
# [Parameter containing:
# tensor(7.078e-01, requires_grad=True), Parameter containing:
# tensor(3.950e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.204e-08) tensor(1.151e-08, dtype=torch.float64)
# Epoch 1/8 at cost=7.540765234459457e-10
# [Parameter containing:
# tensor(7.084e-01, requires_grad=True), Parameter containing:
# tensor(4.016e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.585e-08) tensor(-4.325e-08, dtype=torch.float64)
# Epoch 1/8 at cost=6.145862041506689e-09
# [Parameter containing:
# tensor(7.090e-01, requires_grad=True), Parameter containing:
# tensor(4.071e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.592e-08) tensor(1.477e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.4034952633987814e-09
# [Parameter containing:
# tensor(7.095e-01, requires_grad=True), Parameter containing:
# tensor(4.121e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.465e-10) tensor(1.373e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.8731116657733082e-09
# [Parameter containing:
# tensor(7.105e-01, requires_grad=True), Parameter containing:
# tensor(4.218e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.106e-07) tensor(-2.674e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.053588271129115e-09
# [Parameter containing:
# tensor(7.114e-01, requires_grad=True), Parameter containing:
# tensor(4.306e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.501e-10) tensor(6.135e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.4015602839710937e-09
# [Parameter containing:
# tensor(7.122e-01, requires_grad=True), Parameter containing:
# tensor(4.385e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.339e-09) tensor(3.056e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.325724501872628e-09
# [Parameter containing:
# tensor(7.117e-01, requires_grad=True), Parameter containing:
# tensor(4.343e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.248e-07) tensor(5.887e-07, dtype=torch.float64)
# Epoch 1/8 at cost=9.250459287457602e-10
# [Parameter containing:
# tensor(7.113e-01, requires_grad=True), Parameter containing:
# tensor(4.305e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.400e-12) tensor(1.755e-12, dtype=torch.float64)
# Epoch 1/8 at cost=2.7456073525833347e-10
# [Parameter containing:
# tensor(7.109e-01, requires_grad=True), Parameter containing:
# tensor(4.272e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.087e-08) tensor(-9.979e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.4384543556289486e-09
# [Parameter containing:
# tensor(7.106e-01, requires_grad=True), Parameter containing:
# tensor(4.242e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.328e-10) tensor(4.055e-10, dtype=torch.float64)
# Epoch 1/8 at cost=9.631869607451549e-11
# [Parameter containing:
# tensor(7.102e-01, requires_grad=True), Parameter containing:
# tensor(4.215e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.401e-11) tensor(5.120e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.275728855887337e-09
# [Parameter containing:
# tensor(7.104e-01, requires_grad=True), Parameter containing:
# tensor(4.232e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.425e-07) tensor(-2.968e-07, dtype=torch.float64)
# Epoch 1/8 at cost=7.900806231475599e-09
# [Parameter containing:
# tensor(7.105e-01, requires_grad=True), Parameter containing:
# tensor(4.246e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.801e-09) tensor(6.896e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.6336774155689682e-09
# [Parameter containing:
# tensor(7.107e-01, requires_grad=True), Parameter containing:
# tensor(4.269e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.213e-08) tensor(-6.874e-08, dtype=torch.float64)
# Epoch 1/8 at cost=7.537120927381125e-10
# [Parameter containing:
# tensor(7.104e-01, requires_grad=True), Parameter containing:
# tensor(4.244e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.126e-07) tensor(3.435e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.446187945068459e-10
# [Parameter containing:
# tensor(7.101e-01, requires_grad=True), Parameter containing:
# tensor(4.222e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.514e-11) tensor(-8.100e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.236807405964214e-09
# [Parameter containing:
# tensor(7.102e-01, requires_grad=True), Parameter containing:
# tensor(4.236e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.261e-07) tensor(-2.725e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.1753922279922335e-08
# [Parameter containing:
# tensor(7.103e-01, requires_grad=True), Parameter containing:
# tensor(4.249e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.212e-10) tensor(-5.838e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.9544217355615956e-09
# [Parameter containing:
# tensor(7.104e-01, requires_grad=True), Parameter containing:
# tensor(4.261e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.317e-11) tensor(-9.722e-12, dtype=torch.float64)
# Epoch 1/8 at cost=2.2063679772088562e-09
# [Parameter containing:
# tensor(7.105e-01, requires_grad=True), Parameter containing:
# tensor(4.265e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.898e-08) tensor(4.917e-08, dtype=torch.float64)
# Epoch 1/8 at cost=4.0849856830504905e-10
# [Parameter containing:
# tensor(7.105e-01, requires_grad=True), Parameter containing:
# tensor(4.267e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.524e-08) tensor(1.347e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.8895636166860186e-09
# [Parameter containing:
# tensor(7.112e-01, requires_grad=True), Parameter containing:
# tensor(4.343e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.472e-07) tensor(-7.184e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.038566008863654e-09
# [Parameter containing:
# tensor(7.122e-01, requires_grad=True), Parameter containing:
# tensor(4.443e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.371e-07) tensor(-3.580e-07, dtype=torch.float64)
# Epoch 1/8 at cost=8.777957249961332e-10
# [Parameter containing:
# tensor(7.131e-01, requires_grad=True), Parameter containing:
# tensor(4.535e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.884e-09) tensor(2.564e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.2655207992651185e-09
# [Parameter containing:
# tensor(7.143e-01, requires_grad=True), Parameter containing:
# tensor(4.646e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.996e-07) tensor(-3.137e-07, dtype=torch.float64)
# Epoch 1/8 at cost=9.736502271096015e-09
# [Parameter containing:
# tensor(7.153e-01, requires_grad=True), Parameter containing:
# tensor(4.746e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.111e-08) tensor(8.989e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.8427154246936084e-09
# [Parameter containing:
# tensor(7.162e-01, requires_grad=True), Parameter containing:
# tensor(4.838e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.102e-09) tensor(-2.607e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.7749044728686556e-10
# [Parameter containing:
# tensor(7.160e-01, requires_grad=True), Parameter containing:
# tensor(4.826e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.309e-06) tensor(9.688e-07, dtype=torch.float64)
# Epoch 1/8 at cost=4.071204706690423e-09
# [Parameter containing:
# tensor(7.152e-01, requires_grad=True), Parameter containing:
# tensor(4.758e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.113e-06) tensor(8.259e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.004875625047589e-09
# [Parameter containing:
# tensor(7.143e-01, requires_grad=True), Parameter containing:
# tensor(4.680e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.940e-07) tensor(2.226e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.7630232829191073e-09
# [Parameter containing:
# tensor(7.135e-01, requires_grad=True), Parameter containing:
# tensor(4.609e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.015e-09) tensor(8.789e-10, dtype=torch.float64)
# Epoch 1/8 at cost=7.1500485532283165e-09
# [Parameter containing:
# tensor(7.128e-01, requires_grad=True), Parameter containing:
# tensor(4.538e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.033e-07) tensor(8.401e-08, dtype=torch.float64)
# Epoch 1/8 at cost=7.596891449246357e-10
# [Parameter containing:
# tensor(7.120e-01, requires_grad=True), Parameter containing:
# tensor(4.474e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.436e-10) tensor(2.942e-10, dtype=torch.float64)
# Epoch 1/8 at cost=5.218130372242058e-10
# [Parameter containing:
# tensor(7.113e-01, requires_grad=True), Parameter containing:
# tensor(4.404e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.993e-07) tensor(1.587e-07, dtype=torch.float64)
# Epoch 1/8 at cost=7.159208781359894e-10
# [Parameter containing:
# tensor(7.108e-01, requires_grad=True), Parameter containing:
# tensor(4.368e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.328e-07) tensor(-3.494e-07, dtype=torch.float64)
# Epoch 1/8 at cost=9.206386208937545e-10
# [Parameter containing:
# tensor(7.109e-01, requires_grad=True), Parameter containing:
# tensor(4.383e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.067e-07) tensor(-6.624e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.13513498390239e-09
# [Parameter containing:
# tensor(7.110e-01, requires_grad=True), Parameter containing:
# tensor(4.397e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.962e-10) tensor(5.040e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.2552260059427454e-10
# [Parameter containing:
# tensor(7.111e-01, requires_grad=True), Parameter containing:
# tensor(4.409e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.585e-11) tensor(4.423e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.7390676398942873e-10
# [Parameter containing:
# tensor(7.111e-01, requires_grad=True), Parameter containing:
# tensor(4.420e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.870e-09) tensor(1.637e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.593928765699417e-10
# [Parameter containing:
# tensor(7.112e-01, requires_grad=True), Parameter containing:
# tensor(4.430e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.687e-09) tensor(3.964e-09, dtype=torch.float64)
# Epoch 1/8 at cost=5.733440833211034e-09
# [Parameter containing:
# tensor(7.115e-01, requires_grad=True), Parameter containing:
# tensor(4.469e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.849e-07) tensor(-4.097e-07, dtype=torch.float64)
# Epoch 1/8 at cost=7.657496858826107e-09
# [Parameter containing:
# tensor(7.120e-01, requires_grad=True), Parameter containing:
# tensor(4.524e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.732e-07) tensor(-2.969e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.358988921396076e-09
# [Parameter containing:
# tensor(7.123e-01, requires_grad=True), Parameter containing:
# tensor(4.563e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.001e-07) tensor(1.578e-07, dtype=torch.float64)
# Epoch 1/8 at cost=6.559618181967153e-09
# [Parameter containing:
# tensor(7.126e-01, requires_grad=True), Parameter containing:
# tensor(4.598e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.577e-11) tensor(-3.271e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.144653426545574e-10
# [Parameter containing:
# tensor(7.129e-01, requires_grad=True), Parameter containing:
# tensor(4.631e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.755e-12) tensor(-6.440e-12, dtype=torch.float64)
# Epoch 1/8 at cost=1.5239416673029638e-10
# [Parameter containing:
# tensor(7.133e-01, requires_grad=True), Parameter containing:
# tensor(4.677e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.011e-07) tensor(-2.440e-07, dtype=torch.float64)
# Epoch 1/8 at cost=6.982424416435151e-09
# [Parameter containing:
# tensor(7.137e-01, requires_grad=True), Parameter containing:
# tensor(4.720e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.035e-09) tensor(-5.068e-09, dtype=torch.float64)
# Epoch 1/8 at cost=8.378987503832036e-10
# [Parameter containing:
# tensor(7.141e-01, requires_grad=True), Parameter containing:
# tensor(4.759e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.088e-09) tensor(9.130e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.4810013205266443e-10
# [Parameter containing:
# tensor(7.141e-01, requires_grad=True), Parameter containing:
# tensor(4.767e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.654e-07) tensor(3.552e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.4657729191801536e-09
# [Parameter containing:
# tensor(7.142e-01, requires_grad=True), Parameter containing:
# tensor(4.775e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.425e-10) tensor(1.181e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.1311388209710458e-09
# [Parameter containing:
# tensor(7.137e-01, requires_grad=True), Parameter containing:
# tensor(4.733e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.012e-07) tensor(6.742e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.4084646216570036e-09
# [Parameter containing:
# tensor(7.133e-01, requires_grad=True), Parameter containing:
# tensor(4.695e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.365e-09) tensor(1.993e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.1758577162245274e-09
# [Parameter containing:
# tensor(7.129e-01, requires_grad=True), Parameter containing:
# tensor(4.661e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.315e-10) tensor(-1.927e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.724786784038315e-09
# [Parameter containing:
# tensor(7.121e-01, requires_grad=True), Parameter containing:
# tensor(4.587e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.140e-07) tensor(6.238e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.6046542983261247e-09
# [Parameter containing:
# tensor(7.113e-01, requires_grad=True), Parameter containing:
# tensor(4.518e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.722e-08) tensor(3.040e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.8932397871651574e-09
# [Parameter containing:
# tensor(7.106e-01, requires_grad=True), Parameter containing:
# tensor(4.453e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.135e-08) tensor(3.427e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.400256216006369e-09
# [Parameter containing:
# tensor(7.101e-01, requires_grad=True), Parameter containing:
# tensor(4.401e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.229e-07) tensor(-9.511e-08, dtype=torch.float64)
# Epoch 1/8 at cost=9.640068743266283e-10
# [Parameter containing:
# tensor(7.096e-01, requires_grad=True), Parameter containing:
# tensor(4.354e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.870e-10) tensor(1.678e-10, dtype=torch.float64)
# Epoch 1/8 at cost=9.01660690555417e-10
# [Parameter containing:
# tensor(7.091e-01, requires_grad=True), Parameter containing:
# tensor(4.311e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.232e-11) tensor(2.243e-11, dtype=torch.float64)
# Epoch 1/8 at cost=9.288065316859218e-10
# [Parameter containing:
# tensor(7.087e-01, requires_grad=True), Parameter containing:
# tensor(4.273e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.209e-10) tensor(2.911e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.1609142536173067e-09
# [Parameter containing:
# tensor(7.083e-01, requires_grad=True), Parameter containing:
# tensor(4.238e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.002e-10) tensor(4.602e-10, dtype=torch.float64)
# Epoch 1/8 at cost=5.738389208254091e-10
# [Parameter containing:
# tensor(7.082e-01, requires_grad=True), Parameter containing:
# tensor(4.231e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.094e-07) tensor(-3.422e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.3514113706445414e-09
# [Parameter containing:
# tensor(7.081e-01, requires_grad=True), Parameter containing:
# tensor(4.225e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.767e-12) tensor(2.744e-12, dtype=torch.float64)
# Epoch 1/8 at cost=1.7721597800335331e-10
# [Parameter containing:
# tensor(7.081e-01, requires_grad=True), Parameter containing:
# tensor(4.220e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.321e-12) tensor(5.413e-12, dtype=torch.float64)
# Epoch 1/8 at cost=7.960296866116323e-10
# [Parameter containing:
# tensor(7.080e-01, requires_grad=True), Parameter containing:
# tensor(4.215e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.656e-11) tensor(1.638e-11, dtype=torch.float64)
# Epoch 1/8 at cost=5.918430329154845e-11
# [Parameter containing:
# tensor(7.079e-01, requires_grad=True), Parameter containing:
# tensor(4.207e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.446e-08) tensor(5.698e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.415240147295549e-09
# [Parameter containing:
# tensor(7.078e-01, requires_grad=True), Parameter containing:
# tensor(4.199e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.234e-09) tensor(-1.221e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.492949402466138e-09
# [Parameter containing:
# tensor(7.083e-01, requires_grad=True), Parameter containing:
# tensor(4.254e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.019e-06) tensor(-8.597e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.5022152410892886e-09
# [Parameter containing:
# tensor(7.088e-01, requires_grad=True), Parameter containing:
# tensor(4.309e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.320e-08) tensor(-7.293e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.991757425656715e-09
# [Parameter containing:
# tensor(7.092e-01, requires_grad=True), Parameter containing:
# tensor(4.356e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.325e-08) tensor(3.742e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.961872969109436e-09
# [Parameter containing:
# tensor(7.096e-01, requires_grad=True), Parameter containing:
# tensor(4.398e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.865e-09) tensor(-4.966e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.3265597781652048e-10
# [Parameter containing:
# tensor(7.099e-01, requires_grad=True), Parameter containing:
# tensor(4.436e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.493e-08) tensor(2.115e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.0147892526291002e-09
# [Parameter containing:
# tensor(7.102e-01, requires_grad=True), Parameter containing:
# tensor(4.469e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.152e-11) tensor(6.250e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.366616152522539e-10
# [Parameter containing:
# tensor(7.105e-01, requires_grad=True), Parameter containing:
# tensor(4.500e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.149e-10) tensor(1.892e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.152205664212147e-09
# [Parameter containing:
# tensor(7.111e-01, requires_grad=True), Parameter containing:
# tensor(4.566e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.838e-07) tensor(-5.391e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.9816531466053675e-09
# [Parameter containing:
# tensor(7.117e-01, requires_grad=True), Parameter containing:
# tensor(4.625e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.263e-12) tensor(-3.989e-12, dtype=torch.float64)
# Epoch 1/8 at cost=2.2937114707577422e-10
# [Parameter containing:
# tensor(7.122e-01, requires_grad=True), Parameter containing:
# tensor(4.679e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.273e-08) tensor(1.032e-08, dtype=torch.float64)
# Epoch 1/8 at cost=7.044878014283995e-10
# [Parameter containing:
# tensor(7.129e-01, requires_grad=True), Parameter containing:
# tensor(4.749e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.964e-07) tensor(-3.019e-07, dtype=torch.float64)
# Epoch 1/8 at cost=8.718709643140699e-10
# [Parameter containing:
# tensor(7.136e-01, requires_grad=True), Parameter containing:
# tensor(4.812e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.446e-09) tensor(1.203e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.329592962979632e-09
# [Parameter containing:
# tensor(7.137e-01, requires_grad=True), Parameter containing:
# tensor(4.826e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.790e-07) tensor(5.775e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.0481498719249203e-09
# [Parameter containing:
# tensor(7.138e-01, requires_grad=True), Parameter containing:
# tensor(4.839e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.155e-09) tensor(9.369e-10, dtype=torch.float64)
# Epoch 1/8 at cost=3.50817064287412e-09
# [Parameter containing:
# tensor(7.139e-01, requires_grad=True), Parameter containing:
# tensor(4.850e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.059e-10) tensor(5.090e-10, dtype=torch.float64)
# Epoch 1/8 at cost=5.083759524460163e-10
# [Parameter containing:
# tensor(7.129e-01, requires_grad=True), Parameter containing:
# tensor(4.764e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.059e-06) tensor(1.517e-06, dtype=torch.float64)
# Epoch 1/8 at cost=4.403511777439917e-09
# [Parameter containing:
# tensor(7.129e-01, requires_grad=True), Parameter containing:
# tensor(4.763e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.651e-06) tensor(-1.236e-06, dtype=torch.float64)
# Epoch 1/8 at cost=4.845003953590776e-09
# [Parameter containing:
# tensor(7.128e-01, requires_grad=True), Parameter containing:
# tensor(4.763e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.975e-10) tensor(3.323e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.0434126895830786e-09
# [Parameter containing:
# tensor(7.130e-01, requires_grad=True), Parameter containing:
# tensor(4.786e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.160e-07) tensor(-3.861e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.786131573870534e-10
# [Parameter containing:
# tensor(7.130e-01, requires_grad=True), Parameter containing:
# tensor(4.784e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.059e-07) tensor(3.787e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.4681063031929398e-09
# [Parameter containing:
# tensor(7.130e-01, requires_grad=True), Parameter containing:
# tensor(4.786e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.023e-08) tensor(-6.300e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.1770416580579877e-09
# [Parameter containing:
# tensor(7.126e-01, requires_grad=True), Parameter containing:
# tensor(4.756e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.361e-07) tensor(5.483e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.8334371232906506e-09
# [Parameter containing:
# tensor(7.121e-01, requires_grad=True), Parameter containing:
# tensor(4.707e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.910e-07) tensor(3.694e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.2252147074676145e-09
# [Parameter containing:
# tensor(7.116e-01, requires_grad=True), Parameter containing:
# tensor(4.663e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.803e-10) tensor(5.688e-10, dtype=torch.float64)
# Epoch 1/8 at cost=9.44311961958988e-10
# [Parameter containing:
# tensor(7.112e-01, requires_grad=True), Parameter containing:
# tensor(4.619e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.940e-08) tensor(5.576e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.2115632941345211e-09
# [Parameter containing:
# tensor(7.107e-01, requires_grad=True), Parameter containing:
# tensor(4.578e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.576e-08) tensor(2.917e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.2182450603859252e-09
# [Parameter containing:
# tensor(7.103e-01, requires_grad=True), Parameter containing:
# tensor(4.537e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.212e-08) tensor(7.527e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.2004005567334275e-09
# [Parameter containing:
# tensor(7.099e-01, requires_grad=True), Parameter containing:
# tensor(4.497e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.790e-08) tensor(3.963e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.332602333510181e-09
# [Parameter containing:
# tensor(7.095e-01, requires_grad=True), Parameter containing:
# tensor(4.459e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.136e-08) tensor(3.436e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.3300153745585703e-09
# [Parameter containing:
# tensor(7.092e-01, requires_grad=True), Parameter containing:
# tensor(4.426e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.033e-08) tensor(-1.799e-08, dtype=torch.float64)
# Epoch 1/8 at cost=9.869557393571426e-10
# [Parameter containing:
# tensor(7.089e-01, requires_grad=True), Parameter containing:
# tensor(4.400e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.014e-07) tensor(-8.122e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.0857195970336306e-09
# [Parameter containing:
# tensor(7.088e-01, requires_grad=True), Parameter containing:
# tensor(4.389e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.263e-07) tensor(-1.919e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.6029365329804932e-09
# [Parameter containing:
# tensor(7.086e-01, requires_grad=True), Parameter containing:
# tensor(4.379e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.478e-11) tensor(2.156e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.739467347938728e-09
# [Parameter containing:
# tensor(7.086e-01, requires_grad=True), Parameter containing:
# tensor(4.375e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.695e-08) tensor(-7.409e-08, dtype=torch.float64)
# Epoch 1/8 at cost=7.217155206795667e-10
# [Parameter containing:
# tensor(7.085e-01, requires_grad=True), Parameter containing:
# tensor(4.369e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.392e-08) tensor(2.892e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.221888533744277e-09
# [Parameter containing:
# tensor(7.084e-01, requires_grad=True), Parameter containing:
# tensor(4.364e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.166e-11) tensor(6.848e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.5610072123806162e-09
# [Parameter containing:
# tensor(7.085e-01, requires_grad=True), Parameter containing:
# tensor(4.369e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.022e-07) tensor(-1.641e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.1655096321969722e-09
# [Parameter containing:
# tensor(7.085e-01, requires_grad=True), Parameter containing:
# tensor(4.374e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.439e-09) tensor(1.309e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.5451345758421553e-09
# [Parameter containing:
# tensor(7.085e-01, requires_grad=True), Parameter containing:
# tensor(4.378e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.833e-11) tensor(-6.141e-11, dtype=torch.float64)
# Epoch 1/8 at cost=6.020984821830666e-10
# [Parameter containing:
# tensor(7.085e-01, requires_grad=True), Parameter containing:
# tensor(4.381e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.788e-08) tensor(1.483e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.679171634018985e-09
# [Parameter containing:
# tensor(7.086e-01, requires_grad=True), Parameter containing:
# tensor(4.395e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.081e-07) tensor(-1.683e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.4945092940976679e-09
# [Parameter containing:
# tensor(7.087e-01, requires_grad=True), Parameter containing:
# tensor(4.405e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.643e-08) tensor(3.091e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.0772403797053585e-09
# [Parameter containing:
# tensor(7.088e-01, requires_grad=True), Parameter containing:
# tensor(4.412e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.866e-08) tensor(2.427e-08, dtype=torch.float64)
# Epoch 1/8 at cost=5.148812043387352e-09
# [Parameter containing:
# tensor(7.089e-01, requires_grad=True), Parameter containing:
# tensor(4.422e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.526e-08) tensor(-3.825e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.715003777353786e-09
# [Parameter containing:
# tensor(7.089e-01, requires_grad=True), Parameter containing:
# tensor(4.430e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.335e-10) tensor(2.094e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.1331664495628502e-09
# [Parameter containing:
# tensor(7.091e-01, requires_grad=True), Parameter containing:
# tensor(4.442e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.697e-08) tensor(-7.662e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.7924215445219716e-09
# [Parameter containing:
# tensor(7.096e-01, requires_grad=True), Parameter containing:
# tensor(4.499e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.957e-07) tensor(-7.144e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.945860971299453e-09
# [Parameter containing:
# tensor(7.101e-01, requires_grad=True), Parameter containing:
# tensor(4.549e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.093e-10) tensor(-1.868e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.1237208941139443e-09
# [Parameter containing:
# tensor(7.105e-01, requires_grad=True), Parameter containing:
# tensor(4.595e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.550e-09) tensor(1.347e-09, dtype=torch.float64)
# Epoch 1/8 at cost=1.5805805553270602e-09
# [Parameter containing:
# tensor(7.109e-01, requires_grad=True), Parameter containing:
# tensor(4.637e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.334e-12) tensor(-2.484e-12, dtype=torch.float64)
# Epoch 1/8 at cost=3.2281519679600024e-09
# [Parameter containing:
# tensor(7.113e-01, requires_grad=True), Parameter containing:
# tensor(4.674e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.677e-10) tensor(-7.405e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.9136435486520895e-09
# [Parameter containing:
# tensor(7.117e-01, requires_grad=True), Parameter containing:
# tensor(4.717e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.680e-07) tensor(-1.345e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.0378575210932013e-09
# [Parameter containing:
# tensor(7.121e-01, requires_grad=True), Parameter containing:
# tensor(4.755e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.161e-11) tensor(6.038e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.2323707609951384e-09
# [Parameter containing:
# tensor(7.124e-01, requires_grad=True), Parameter containing:
# tensor(4.790e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.032e-09) tensor(2.531e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.449908331758621e-10
# [Parameter containing:
# tensor(7.125e-01, requires_grad=True), Parameter containing:
# tensor(4.799e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.503e-07) tensor(3.349e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.467047982042004e-09
# [Parameter containing:
# tensor(7.125e-01, requires_grad=True), Parameter containing:
# tensor(4.805e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.918e-08) tensor(3.840e-08, dtype=torch.float64)
# Epoch 1/8 at cost=7.254552070179443e-09
# [Parameter containing:
# tensor(7.125e-01, requires_grad=True), Parameter containing:
# tensor(4.810e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.579e-10) tensor(4.099e-10, dtype=torch.float64)
# Epoch 1/8 at cost=6.616922121338575e-09
# [Parameter containing:
# tensor(7.126e-01, requires_grad=True), Parameter containing:
# tensor(4.815e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.228e-10) tensor(5.435e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.4896859301671839e-09
# [Parameter containing:
# tensor(7.126e-01, requires_grad=True), Parameter containing:
# tensor(4.819e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.024e-11) tensor(2.597e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.0621180601688707e-09
# [Parameter containing:
# tensor(7.126e-01, requires_grad=True), Parameter containing:
# tensor(4.823e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.547e-11) tensor(-5.990e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.193837334019122e-09
# [Parameter containing:
# tensor(7.127e-01, requires_grad=True), Parameter containing:
# tensor(4.827e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.873e-10) tensor(8.351e-10, dtype=torch.float64)
# Epoch 1/8 at cost=2.5648434487379745e-09
# [Parameter containing:
# tensor(7.126e-01, requires_grad=True), Parameter containing:
# tensor(4.824e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.169e-07) tensor(8.633e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.592860732202439e-09
# [Parameter containing:
# tensor(7.121e-01, requires_grad=True), Parameter containing:
# tensor(4.775e-02, dtype=torch.float64, requires_grad=True)]
# tensor(9.544e-07) tensor(7.055e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.238581625097936e-09
# [Parameter containing:
# tensor(7.115e-01, requires_grad=True), Parameter containing:
# tensor(4.721e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.151e-07) tensor(1.604e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.068486075288092e-09
# [Parameter containing:
# tensor(7.110e-01, requires_grad=True), Parameter containing:
# tensor(4.672e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.245e-10) tensor(4.467e-10, dtype=torch.float64)
# Epoch 1/8 at cost=1.2814713734599081e-09
# [Parameter containing:
# tensor(7.105e-01, requires_grad=True), Parameter containing:
# tensor(4.625e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.636e-08) tensor(4.490e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.5053898955462728e-09
# [Parameter containing:
# tensor(7.100e-01, requires_grad=True), Parameter containing:
# tensor(4.582e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.523e-11) tensor(2.349e-11, dtype=torch.float64)
# Epoch 1/8 at cost=8.717109256650701e-10
# [Parameter containing:
# tensor(7.099e-01, requires_grad=True), Parameter containing:
# tensor(4.572e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.433e-07) tensor(-4.208e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.6661449997457112e-09
# [Parameter containing:
# tensor(7.099e-01, requires_grad=True), Parameter containing:
# tensor(4.572e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.903e-07) tensor(-1.477e-07, dtype=torch.float64)
# Epoch 1/8 at cost=5.918641132751645e-10
# [Parameter containing:
# tensor(7.100e-01, requires_grad=True), Parameter containing:
# tensor(4.583e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.027e-07) tensor(-1.658e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.457011121810183e-09
# [Parameter containing:
# tensor(7.101e-01, requires_grad=True), Parameter containing:
# tensor(4.593e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.596e-09) tensor(1.381e-09, dtype=torch.float64)
# Epoch 1/8 at cost=9.469875994483345e-10
# [Parameter containing:
# tensor(7.104e-01, requires_grad=True), Parameter containing:
# tensor(4.633e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.960e-07) tensor(-4.597e-07, dtype=torch.float64)
# Epoch 1/8 at cost=9.989085114625595e-10
# [Parameter containing:
# tensor(7.108e-01, requires_grad=True), Parameter containing:
# tensor(4.669e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.068e-10) tensor(1.812e-10, dtype=torch.float64)
# Epoch 1/8 at cost=7.080908082102155e-10
# [Parameter containing:
# tensor(7.111e-01, requires_grad=True), Parameter containing:
# tensor(4.698e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.058e-08) tensor(4.854e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.5843699402727793e-10
# [Parameter containing:
# tensor(7.113e-01, requires_grad=True), Parameter containing:
# tensor(4.724e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.028e-09) tensor(1.714e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.1237618330616215e-09
# [Parameter containing:
# tensor(7.115e-01, requires_grad=True), Parameter containing:
# tensor(4.747e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.525e-09) tensor(2.039e-09, dtype=torch.float64)
# Epoch 1/8 at cost=2.24933272008343e-09
# [Parameter containing:
# tensor(7.117e-01, requires_grad=True), Parameter containing:
# tensor(4.760e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.673e-07) tensor(1.268e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.2615545819680847e-09
# [Parameter containing:
# tensor(7.118e-01, requires_grad=True), Parameter containing:
# tensor(4.771e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.032e-09) tensor(-9.069e-10, dtype=torch.float64)
# Epoch 1/8 at cost=7.531255064030518e-10
# [Parameter containing:
# tensor(7.114e-01, requires_grad=True), Parameter containing:
# tensor(4.742e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.929e-07) tensor(5.920e-07, dtype=torch.float64)
# Epoch 1/8 at cost=6.862876933411144e-10
# [Parameter containing:
# tensor(7.107e-01, requires_grad=True), Parameter containing:
# tensor(4.676e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.964e-07) tensor(5.975e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.118440312059988e-09
# [Parameter containing:
# tensor(7.101e-01, requires_grad=True), Parameter containing:
# tensor(4.616e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.178e-11) tensor(-6.128e-11, dtype=torch.float64)
# Epoch 1/8 at cost=2.94009172563392e-09
# [Parameter containing:
# tensor(7.096e-01, requires_grad=True), Parameter containing:
# tensor(4.563e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.911e-12) tensor(-8.332e-12, dtype=torch.float64)
# Epoch 1/8 at cost=8.401390139134435e-10
# [Parameter containing:
# tensor(7.090e-01, requires_grad=True), Parameter containing:
# tensor(4.513e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.349e-08) tensor(1.920e-08, dtype=torch.float64)
# Epoch 1/8 at cost=2.0352921570321314e-09
# [Parameter containing:
# tensor(7.086e-01, requires_grad=True), Parameter containing:
# tensor(4.470e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.438e-08) tensor(-2.679e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.8061109274825071e-09
# [Parameter containing:
# tensor(7.086e-01, requires_grad=True), Parameter containing:
# tensor(4.476e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.310e-07) tensor(-6.581e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.6409665848371446e-09
# [Parameter containing:
# tensor(7.086e-01, requires_grad=True), Parameter containing:
# tensor(4.480e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.566e-11) tensor(-2.720e-11, dtype=torch.float64)
# Epoch 1/8 at cost=3.7188532253651374e-09
# [Parameter containing:
# tensor(7.086e-01, requires_grad=True), Parameter containing:
# tensor(4.477e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.416e-07) tensor(1.133e-07, dtype=torch.float64)
# Epoch 1/8 at cost=3.779284385441173e-10
# [Parameter containing:
# tensor(7.085e-01, requires_grad=True), Parameter containing:
# tensor(4.473e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.541e-08) tensor(2.133e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.5654165741452175e-09
# [Parameter containing:
# tensor(7.085e-01, requires_grad=True), Parameter containing:
# tensor(4.474e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.171e-08) tensor(-7.640e-08, dtype=torch.float64)
# Epoch 1/8 at cost=3.7269596298017404e-09
# [Parameter containing:
# tensor(7.085e-01, requires_grad=True), Parameter containing:
# tensor(4.475e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.692e-11) tensor(2.587e-11, dtype=torch.float64)
# Epoch 1/8 at cost=1.6203408614856585e-09
# [Parameter containing:
# tensor(7.087e-01, requires_grad=True), Parameter containing:
# tensor(4.500e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.450e-07) tensor(-3.524e-07, dtype=torch.float64)
# Epoch 1/8 at cost=9.455806804226086e-09
# [Parameter containing:
# tensor(7.090e-01, requires_grad=True), Parameter containing:
# tensor(4.530e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.423e-07) tensor(-1.179e-07, dtype=torch.float64)
# Epoch 1/8 at cost=1.5110038775745238e-09
# [Parameter containing:
# tensor(7.098e-01, requires_grad=True), Parameter containing:
# tensor(4.614e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.121e-06) tensor(-8.770e-07, dtype=torch.float64)
# Epoch 1/8 at cost=2.55995513676055e-09
# [Parameter containing:
# tensor(7.105e-01, requires_grad=True), Parameter containing:
# tensor(4.689e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-6.642e-10) tensor(-6.426e-10, dtype=torch.float64)
# Epoch 1/8 at cost=4.176031964675531e-09
# [Parameter containing:
# tensor(7.112e-01, requires_grad=True), Parameter containing:
# tensor(4.758e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.723e-12) tensor(-3.057e-12, dtype=torch.float64)
# Epoch 1/8 at cost=8.730650091770542e-10
# [Parameter containing:
# tensor(7.118e-01, requires_grad=True), Parameter containing:
# tensor(4.818e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.058e-08) tensor(3.192e-08, dtype=torch.float64)
# Epoch 1/8 at cost=7.0073120639335684e-09
# [Parameter containing:
# tensor(7.123e-01, requires_grad=True), Parameter containing:
# tensor(4.871e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.051e-12) tensor(-7.743e-12, dtype=torch.float64)
# Epoch 1/8 at cost=6.785726647251522e-09
# [Parameter containing:
# tensor(7.128e-01, requires_grad=True), Parameter containing:
# tensor(4.921e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.980e-08) tensor(-1.608e-08, dtype=torch.float64)
# Epoch 1/8 at cost=1.6881722686434841e-09
# [Parameter containing:
# tensor(7.132e-01, requires_grad=True), Parameter containing:
# tensor(4.966e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.781e-09) tensor(3.050e-09, dtype=torch.float64)
# Epoch 1/8 at cost=3.6689820626101266e-10
# [Parameter containing:
# tensor(7.136e-01, requires_grad=True), Parameter containing:
# tensor(5.003e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.159e-08) tensor(4.656e-08, dtype=torch.float64)
# Epoch 2/8 at cost=2.352342098888016e-09
# [Parameter containing:
# tensor(7.138e-01, requires_grad=True), Parameter containing:
# tensor(5.028e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.756e-07) tensor(1.264e-07, dtype=torch.float64)
# Epoch 2/8 at cost=4.295765076989255e-09
# [Parameter containing:
# tensor(7.136e-01, requires_grad=True), Parameter containing:
# tensor(5.016e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.225e-07) tensor(5.167e-07, dtype=torch.float64)
# Epoch 2/8 at cost=3.2756648504772556e-09
# [Parameter containing:
# tensor(7.135e-01, requires_grad=True), Parameter containing:
# tensor(5.004e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.654e-08) tensor(1.239e-08, dtype=torch.float64)
# Epoch 2/8 at cost=3.2184188647477185e-10
# [Parameter containing:
# tensor(7.133e-01, requires_grad=True), Parameter containing:
# tensor(4.994e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.777e-09) tensor(2.084e-09, dtype=torch.float64)
# Epoch 2/8 at cost=1.1705973967934824e-09
# [Parameter containing:
# tensor(7.132e-01, requires_grad=True), Parameter containing:
# tensor(4.981e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.029e-08) tensor(3.784e-08, dtype=torch.float64)
# Epoch 2/8 at cost=3.1366274022559537e-09
# [Parameter containing:
# tensor(7.130e-01, requires_grad=True), Parameter containing:
# tensor(4.968e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.505e-08) tensor(4.149e-08, dtype=torch.float64)
# Epoch 2/8 at cost=1.2481150557519527e-09
# [Parameter containing:
# tensor(7.128e-01, requires_grad=True), Parameter containing:
# tensor(4.948e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.515e-07) tensor(1.114e-07, dtype=torch.float64)
# Epoch 2/8 at cost=6.910698679973848e-10
# [Parameter containing:
# tensor(7.123e-01, requires_grad=True), Parameter containing:
# tensor(4.909e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.503e-07) tensor(3.089e-07, dtype=torch.float64)
# Epoch 2/8 at cost=5.2392765681474884e-09
# [Parameter containing:
# tensor(7.119e-01, requires_grad=True), Parameter containing:
# tensor(4.874e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.772e-11) tensor(2.624e-11, dtype=torch.float64)
# Epoch 2/8 at cost=3.464181386192422e-09
# [Parameter containing:
# tensor(7.116e-01, requires_grad=True), Parameter containing:
# tensor(4.842e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.141e-10) tensor(-6.207e-10, dtype=torch.float64)
# Epoch 2/8 at cost=7.142749502975221e-09
# [Parameter containing:
# tensor(7.113e-01, requires_grad=True), Parameter containing:
# tensor(4.815e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.863e-08) tensor(-2.216e-08, dtype=torch.float64)
# Epoch 2/8 at cost=2.056870229694141e-09
# [Parameter containing:
# tensor(7.108e-01, requires_grad=True), Parameter containing:
# tensor(4.777e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.683e-07) tensor(1.984e-07, dtype=torch.float64)
# Epoch 2/8 at cost=2.0848167636700055e-09
# [Parameter containing:
# tensor(7.104e-01, requires_grad=True), Parameter containing:
# tensor(4.742e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.676e-08) tensor(1.971e-08, dtype=torch.float64)
# Epoch 2/8 at cost=3.375305313024768e-10
# [Parameter containing:
# tensor(7.102e-01, requires_grad=True), Parameter containing:
# tensor(4.718e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.543e-07) tensor(-1.156e-07, dtype=torch.float64)
# Epoch 2/8 at cost=4.767966910179666e-09
# [Parameter containing:
# tensor(7.098e-01, requires_grad=True), Parameter containing:
# tensor(4.688e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.430e-07) tensor(1.133e-07, dtype=torch.float64)
# Epoch 2/8 at cost=3.6224754307312423e-09
# [Parameter containing:
# tensor(7.096e-01, requires_grad=True), Parameter containing:
# tensor(4.661e-02, dtype=torch.float64, requires_grad=True)]
# tensor(5.488e-09) tensor(4.371e-09, dtype=torch.float64)
# Epoch 2/8 at cost=5.335113462123786e-10
# [Parameter containing:
# tensor(7.094e-01, requires_grad=True), Parameter containing:
# tensor(4.644e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.236e-07) tensor(-9.905e-08, dtype=torch.float64)
# Epoch 2/8 at cost=1.7109855754426917e-09
# [Parameter containing:
# ...
# tensor(7.013e-01, requires_grad=True), Parameter containing:
# tensor(6.368e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.101e-11) tensor(6.566e-12, dtype=torch.float64)
# Epoch 8/8 at cost=6.643779970616492e-10
# [Parameter containing:
# tensor(7.006e-01, requires_grad=True), Parameter containing:
# tensor(6.309e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.418e-10) tensor(3.038e-10, dtype=torch.float64)
# Epoch 8/8 at cost=2.5801947245440715e-09
# [Parameter containing:
# tensor(6.995e-01, requires_grad=True), Parameter containing:
# tensor(6.217e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.960e-07) tensor(4.420e-07, dtype=torch.float64)
# Epoch 8/8 at cost=7.938124602091534e-10
# [Parameter containing:
# tensor(6.989e-01, requires_grad=True), Parameter containing:
# tensor(6.174e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.135e-07) tensor(-4.573e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.9099445075786434e-09
# [Parameter containing:
# tensor(6.985e-01, requires_grad=True), Parameter containing:
# tensor(6.135e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.101e-10) tensor(-2.085e-10, dtype=torch.float64)
# Epoch 8/8 at cost=1.5566632427521654e-09
# [Parameter containing:
# tensor(6.980e-01, requires_grad=True), Parameter containing:
# tensor(6.100e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.030e-09) tensor(1.816e-09, dtype=torch.float64)
# Epoch 8/8 at cost=6.04001126891518e-10
# [Parameter containing:
# tensor(6.976e-01, requires_grad=True), Parameter containing:
# tensor(6.064e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.986e-08) tensor(5.409e-08, dtype=torch.float64)
# Epoch 8/8 at cost=3.70610919731007e-09
# [Parameter containing:
# tensor(6.972e-01, requires_grad=True), Parameter containing:
# tensor(6.032e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.099e-08) tensor(-6.384e-09, dtype=torch.float64)
# Epoch 8/8 at cost=1.4386225544171793e-09
# [Parameter containing:
# tensor(6.969e-01, requires_grad=True), Parameter containing:
# tensor(6.003e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.911e-09) tensor(-1.299e-09, dtype=torch.float64)
# Epoch 8/8 at cost=2.078292649088098e-09
# [Parameter containing:
# tensor(6.967e-01, requires_grad=True), Parameter containing:
# tensor(5.995e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.366e-07) tensor(-1.947e-07, dtype=torch.float64)
# Epoch 8/8 at cost=5.237856370854388e-09
# [Parameter containing:
# tensor(6.967e-01, requires_grad=True), Parameter containing:
# tensor(5.991e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.249e-08) tensor(-5.045e-08, dtype=torch.float64)
# Epoch 8/8 at cost=2.7607129915452333e-09
# [Parameter containing:
# tensor(6.966e-01, requires_grad=True), Parameter containing:
# tensor(5.988e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.679e-10) tensor(5.005e-10, dtype=torch.float64)
# Epoch 8/8 at cost=1.1330344440452222e-09
# [Parameter containing:
# tensor(6.966e-01, requires_grad=True), Parameter containing:
# tensor(5.985e-02, dtype=torch.float64, requires_grad=True)]
# tensor(7.531e-09) tensor(4.476e-09, dtype=torch.float64)
# Epoch 8/8 at cost=2.407799515324882e-09
# [Parameter containing:
# tensor(6.965e-01, requires_grad=True), Parameter containing:
# tensor(5.982e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.933e-11) tensor(-1.418e-11, dtype=torch.float64)
# Epoch 8/8 at cost=5.328090857403822e-09
# [Parameter containing:
# tensor(6.968e-01, requires_grad=True), Parameter containing:
# tensor(6.007e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.467e-07) tensor(-3.183e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.164171508667323e-09
# [Parameter containing:
# tensor(6.970e-01, requires_grad=True), Parameter containing:
# tensor(6.030e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.698e-10) tensor(1.634e-10, dtype=torch.float64)
# Epoch 8/8 at cost=2.296074219643174e-09
# [Parameter containing:
# tensor(6.973e-01, requires_grad=True), Parameter containing:
# tensor(6.055e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-8.726e-08) tensor(-5.051e-08, dtype=torch.float64)
# Epoch 8/8 at cost=3.819164984264489e-09
# [Parameter containing:
# tensor(6.977e-01, requires_grad=True), Parameter containing:
# tensor(6.097e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.759e-07) tensor(-2.196e-07, dtype=torch.float64)
# Epoch 8/8 at cost=3.81629039480913e-09
# [Parameter containing:
# tensor(6.982e-01, requires_grad=True), Parameter containing:
# tensor(6.140e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.020e-07) tensor(-5.998e-08, dtype=torch.float64)
# Epoch 8/8 at cost=3.3397153931247203e-09
# [Parameter containing:
# tensor(6.986e-01, requires_grad=True), Parameter containing:
# tensor(6.179e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.065e-09) tensor(-3.166e-09, dtype=torch.float64)
# Epoch 8/8 at cost=3.9496875214872773e-10
# [Parameter containing:
# tensor(6.992e-01, requires_grad=True), Parameter containing:
# tensor(6.234e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.935e-07) tensor(-2.224e-07, dtype=torch.float64)
# Epoch 8/8 at cost=1.225814449945517e-09
# [Parameter containing:
# tensor(6.997e-01, requires_grad=True), Parameter containing:
# tensor(6.283e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.574e-11) tensor(1.838e-11, dtype=torch.float64)
# Epoch 8/8 at cost=3.2703315611115613e-09
# [Parameter containing:
# tensor(6.999e-01, requires_grad=True), Parameter containing:
# tensor(6.303e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.926e-07) tensor(2.748e-07, dtype=torch.float64)
# Epoch 8/8 at cost=6.689940157400542e-09
# [Parameter containing:
# tensor(7.001e-01, requires_grad=True), Parameter containing:
# tensor(6.321e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.422e-09) tensor(1.366e-09, dtype=torch.float64)
# Epoch 8/8 at cost=6.610240355087171e-09
# [Parameter containing:
# tensor(7.003e-01, requires_grad=True), Parameter containing:
# tensor(6.337e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.610e-08) tensor(9.410e-09, dtype=torch.float64)
# Epoch 8/8 at cost=1.4739129916563343e-09
# [Parameter containing:
# tensor(7.004e-01, requires_grad=True), Parameter containing:
# tensor(6.350e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.827e-12) tensor(1.242e-12, dtype=torch.float64)
# Epoch 8/8 at cost=1.0638940839413635e-09
# [Parameter containing:
# tensor(7.006e-01, requires_grad=True), Parameter containing:
# tensor(6.363e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.934e-10) tensor(1.744e-10, dtype=torch.float64)
# Epoch 8/8 at cost=3.261476366756e-10
# [Parameter containing:
# tensor(7.003e-01, requires_grad=True), Parameter containing:
# tensor(6.341e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.689e-07) tensor(3.701e-07, dtype=torch.float64)
# Epoch 8/8 at cost=1.0851048948268271e-09
# [Parameter containing:
# tensor(7.001e-01, requires_grad=True), Parameter containing:
# tensor(6.322e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.407e-10) tensor(1.494e-10, dtype=torch.float64)
# Epoch 8/8 at cost=1.579904096438156e-09
# [Parameter containing:
# tensor(6.995e-01, requires_grad=True), Parameter containing:
# tensor(6.272e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.592e-07) tensor(3.650e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.0157491231742597e-09
# [Parameter containing:
# tensor(6.989e-01, requires_grad=True), Parameter containing:
# tensor(6.228e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.244e-10) tensor(-3.358e-10, dtype=torch.float64)
# Epoch 8/8 at cost=5.390339730126925e-09
# [Parameter containing:
# tensor(6.985e-01, requires_grad=True), Parameter containing:
# tensor(6.187e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.714e-10) tensor(-6.684e-10, dtype=torch.float64)
# Epoch 8/8 at cost=2.0103676501292966e-09
# [Parameter containing:
# tensor(6.985e-01, requires_grad=True), Parameter containing:
# tensor(6.188e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.339e-07) tensor(-4.138e-07, dtype=torch.float64)
# Epoch 8/8 at cost=3.862133279852742e-09
# [Parameter containing:
# tensor(6.983e-01, requires_grad=True), Parameter containing:
# tensor(6.173e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.151e-07) tensor(1.778e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.3246181368730134e-10
# [Parameter containing:
# tensor(6.981e-01, requires_grad=True), Parameter containing:
# tensor(6.159e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.370e-09) tensor(8.768e-10, dtype=torch.float64)
# Epoch 8/8 at cost=2.0474026918293475e-09
# [Parameter containing:
# tensor(6.986e-01, requires_grad=True), Parameter containing:
# tensor(6.209e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.251e-06) tensor(-7.092e-07, dtype=torch.float64)
# Epoch 8/8 at cost=1.562859286430296e-09
# [Parameter containing:
# tensor(6.993e-01, requires_grad=True), Parameter containing:
# tensor(6.264e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.036e-07) tensor(-1.206e-07, dtype=torch.float64)
# Epoch 8/8 at cost=3.438851425840994e-09
# [Parameter containing:
# tensor(6.998e-01, requires_grad=True), Parameter containing:
# tensor(6.314e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.989e-10) tensor(4.283e-10, dtype=torch.float64)
# Epoch 8/8 at cost=9.484562024653087e-10
# [Parameter containing:
# tensor(7.004e-01, requires_grad=True), Parameter containing:
# tensor(6.369e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.983e-07) tensor(-1.099e-07, dtype=torch.float64)
# Epoch 8/8 at cost=6.228063065272238e-10
# [Parameter containing:
# tensor(7.010e-01, requires_grad=True), Parameter containing:
# tensor(6.418e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.952e-12) tensor(7.561e-12, dtype=torch.float64)
# Epoch 8/8 at cost=7.091459641728193e-10
# [Parameter containing:
# tensor(7.014e-01, requires_grad=True), Parameter containing:
# tensor(6.462e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.233e-09) tensor(-1.847e-09, dtype=torch.float64)
# Epoch 8/8 at cost=3.2267497007687496e-10
# [Parameter containing:
# tensor(7.014e-01, requires_grad=True), Parameter containing:
# tensor(6.463e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.116e-07) tensor(4.405e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.7335582686305315e-09
# [Parameter containing:
# tensor(7.013e-01, requires_grad=True), Parameter containing:
# tensor(6.455e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.827e-07) tensor(1.044e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.3916586489036717e-09
# [Parameter containing:
# tensor(7.008e-01, requires_grad=True), Parameter containing:
# tensor(6.415e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.830e-07) tensor(3.748e-07, dtype=torch.float64)
# Epoch 8/8 at cost=3.573787266120121e-09
# [Parameter containing:
# tensor(7.004e-01, requires_grad=True), Parameter containing:
# tensor(6.379e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.316e-13) tensor(6.809e-13, dtype=torch.float64)
# Epoch 8/8 at cost=7.524550982296319e-10
# [Parameter containing:
# tensor(6.999e-01, requires_grad=True), Parameter containing:
# tensor(6.338e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.692e-07) tensor(9.296e-08, dtype=torch.float64)
# Epoch 8/8 at cost=1.6176326944616903e-10
# [Parameter containing:
# tensor(6.990e-01, requires_grad=True), Parameter containing:
# tensor(6.262e-02, dtype=torch.float64, requires_grad=True)]
# tensor(8.184e-07) tensor(4.524e-07, dtype=torch.float64)
# Epoch 8/8 at cost=1.1162781810014621e-09
# [Parameter containing:
# tensor(6.982e-01, requires_grad=True), Parameter containing:
# tensor(6.193e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-9.651e-11) tensor(-7.575e-11, dtype=torch.float64)
# Epoch 8/8 at cost=2.9403794954419027e-09
# [Parameter containing:
# tensor(6.975e-01, requires_grad=True), Parameter containing:
# tensor(6.131e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.793e-11) tensor(-1.345e-11, dtype=torch.float64)
# Epoch 8/8 at cost=8.404171802922633e-10
# [Parameter containing:
# tensor(6.970e-01, requires_grad=True), Parameter containing:
# tensor(6.088e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-2.369e-07) tensor(-1.418e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.0654573607004068e-09
# [Parameter containing:
# tensor(6.969e-01, requires_grad=True), Parameter containing:
# tensor(6.085e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-7.118e-07) tensor(-4.074e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.3415833716455836e-09
# [Parameter containing:
# tensor(6.970e-01, requires_grad=True), Parameter containing:
# tensor(6.099e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-3.275e-07) tensor(-1.873e-07, dtype=torch.float64)
# Epoch 8/8 at cost=2.5186768226603817e-09
# [Parameter containing:
# tensor(6.971e-01, requires_grad=True), Parameter containing:
# tensor(6.111e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.795e-11) tensor(1.972e-11, dtype=torch.float64)
# Epoch 8/8 at cost=3.7198009117389574e-09
# [Parameter containing:
# tensor(6.972e-01, requires_grad=True), Parameter containing:
# tensor(6.122e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.016e-08) tensor(6.440e-09, dtype=torch.float64)
# Epoch 8/8 at cost=3.6709552064806417e-10
# [Parameter containing:
# tensor(6.973e-01, requires_grad=True), Parameter containing:
# tensor(6.131e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.997e-09) tensor(2.504e-09, dtype=torch.float64)
# Epoch 8/8 at cost=1.5704364475510602e-09
# [Parameter containing:
# tensor(6.974e-01, requires_grad=True), Parameter containing:
# tensor(6.139e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.320e-10) tensor(2.955e-10, dtype=torch.float64)
# Epoch 8/8 at cost=3.712495644236924e-09
# [Parameter containing:
# tensor(6.974e-01, requires_grad=True), Parameter containing:
# tensor(6.146e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.785e-09) tensor(1.128e-09, dtype=torch.float64)
# Epoch 8/8 at cost=1.6222703180801545e-09
# [Parameter containing:
# tensor(6.977e-01, requires_grad=True), Parameter containing:
# tensor(6.174e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-4.281e-07) tensor(-2.430e-07, dtype=torch.float64)
# Epoch 8/8 at cost=9.447309601284815e-09
# [Parameter containing:
# tensor(6.980e-01, requires_grad=True), Parameter containing:
# tensor(6.200e-02, dtype=torch.float64, requires_grad=True)]
# tensor(2.455e-10) tensor(1.653e-10, dtype=torch.float64)
# Epoch 8/8 at cost=1.4758425592731328e-09
# [Parameter containing:
# tensor(6.993e-01, requires_grad=True), Parameter containing:
# tensor(6.316e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-1.919e-06) tensor(-1.080e-06, dtype=torch.float64)
# Epoch 8/8 at cost=2.5293167560391794e-09
# [Parameter containing:
# tensor(7.004e-01, requires_grad=True), Parameter containing:
# tensor(6.420e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.649e-10) tensor(1.009e-10, dtype=torch.float64)
# Epoch 8/8 at cost=4.176571977154708e-09
# [Parameter containing:
# tensor(7.015e-01, requires_grad=True), Parameter containing:
# tensor(6.514e-02, dtype=torch.float64, requires_grad=True)]
# tensor(3.568e-11) tensor(2.410e-11, dtype=torch.float64)
# Epoch 8/8 at cost=8.729694744857852e-10
# [Parameter containing:
# tensor(7.024e-01, requires_grad=True), Parameter containing:
# tensor(6.597e-02, dtype=torch.float64, requires_grad=True)]
# tensor(4.065e-08) tensor(2.302e-08, dtype=torch.float64)
# Epoch 8/8 at cost=7.069337115694907e-09
# [Parameter containing:
# tensor(7.032e-01, requires_grad=True), Parameter containing:
# tensor(6.672e-02, dtype=torch.float64, requires_grad=True)]
# tensor(-5.276e-10) tensor(-3.309e-10, dtype=torch.float64)
# Epoch 8/8 at cost=6.794069307147765e-09
# [Parameter containing:
# tensor(7.040e-01, requires_grad=True), Parameter containing:
# tensor(6.736e-02, dtype=torch.float64, requires_grad=True)]
# tensor(6.935e-08) tensor(3.844e-08, dtype=torch.float64)
# Epoch 8/8 at cost=1.6742930375457377e-09
# [Parameter containing:
# tensor(7.046e-01, requires_grad=True), Parameter containing:
# tensor(6.792e-02, dtype=torch.float64, requires_grad=True)]
# tensor(1.840e-08) tensor(1.013e-08, dtype=torch.float64)
# Epoch 8/8 at cost=3.737984088925117e-10
# Finished Training

# %% [markdown]
# #### Evaluating unrolled network on train dataset

# %%
out_bftrain4, out_hat4 = get_net_outputs(net4, LearnedAAP(max_iter, d1, d2), r, train4)
out_accaltproj4 = []
for i, (L_true, S_true, M_true) in enumerate(train4):
    loss, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    out_accaltproj4.append((L0, S0))

# %%
metrics = get_metrics(train4, [x[:2] for x in train_est4], out_bftrain4, out_hat4)
fro_norm_L_old, mse_S_old, fro_norm_S_old, count_nonzeros_S_old, relative_err_old, \
    fro_norm_L_new, mse_S_new, fro_norm_S_new, count_nonzeros_S_new, relative_err_new, \
    fro_norm_L_bftrain, mse_S_bftrain, fro_norm_S_bftrain, count_nonzeros_S_bftrain, relative_err_bftrain \
        = metrics.values()
fro_norm_L_accaltproj, mse_S_accaltproj, fro_norm_S_accaltproj, count_nonzeros_S_accaltproj, relative_err_accaltproj \
    = list(get_metrics(train4, out_accaltproj4, out_bftrain4, out_hat4).values())[:5]

fig, ax = plt.subplots()
ax.boxplot([relative_err_old, \
    relative_err_new, relative_err_bftrain, relative_err_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["relative_err_old", \
    "relative_err_new", "relative_err_bftrain", "relative_err_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_L_old, fro_norm_L_new, fro_norm_L_bftrain, fro_norm_L_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["fro_norm_L_old", "fro_norm_L_new", "fro_norm_L_bfaftrain", "fro_norm_L_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([mse_S_old, mse_S_new, mse_S_bftrain, mse_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["mse_S_old", "mse_S_new", "mse_S_bfaftrain", "mse_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_S_old, fro_norm_S_new, fro_norm_S_bftrain, fro_norm_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["fro_norm_S_old", "fro_norm_S_new", "fro_norm_S_bfaftrain", "fro_norm_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([count_nonzeros_S_old, count_nonzeros_S_new, count_nonzeros_S_bftrain, count_nonzeros_S_accaltproj], notch = True, showfliers=False)
ax.set_xticklabels(["count_nonzeros_S_old", "count_nonzeros_S_new", "count_nonzeros_S_bfaftrain", "count_nonzeros_S_accaltproj"])
plt.show()
# Out:
# /Users/elitanzc/Github/FYP/helper.py:254: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat1 = (torch.tensor(mat1) == 0)
# /Users/elitanzc/Github/FYP/helper.py:255: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat2 = (torch.tensor(mat2) == 0)

# %%
print("P-values from test of mean with H1: _new < _old")
print("relative_err_new, relative_err_old: ", stats.ttest_rel(relative_err_new, relative_err_old, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_old, alternative='less').pvalue)
print("mse_S_new, mse_S_old: ", stats.ttest_rel(mse_S_new, mse_S_old, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_old, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_old, alternative='less').pvalue)
print()
print("P-values from test of mean with H1: _new < _accaltproj")
print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(relative_err_new, relative_err_accaltproj, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_accaltproj, alternative='less').pvalue)
print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(mse_S_new, mse_S_accaltproj, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_accaltproj, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_accaltproj, alternative='less').pvalue)
print()
print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(relative_err_new, relative_err_bftrain, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_bftrain, alternative='less').pvalue)
print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(mse_S_new, mse_S_bftrain, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_bftrain, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_bftrain, alternative='less').pvalue)

# print("*Note: values are log-transformed before deriving p-values")
# print()
# print("relative_err_new, relative_err_old: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_old), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_old), alternative='less').pvalue)
# print("mse_S_new, mse_S_old: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_old), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_old), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_old), alternative='less').pvalue)
# print()
# print("P-values from test of mean with H1: _new < _accaltproj")
# print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_accaltproj), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_accaltproj), alternative='less').pvalue)
# print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_accaltproj), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_accaltproj), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_accaltproj), alternative='less').pvalue)
# print()
# print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_bftrain), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_bftrain), alternative='less').pvalue)
# print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_bftrain), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_bftrain), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_bftrain), alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new < _old
# relative_err_new, relative_err_old:  1.159658372851787e-14
# fro_norm_L_new, fro_norm_L_old:  0.004016282411196734
# mse_S_new, mse_S_old:  5.37706942422456e-07
# fro_norm_S_new, fro_norm_S_old:  8.482811918146755e-15
# count_nonzeros_S_new, count_nonzeros_S_old:  0.9999999966039328
#
# P-values from test of mean with H1: _new < _accaltproj
# relative_err_new, relative_err_accaltproj:  3.250031155782045e-30
# fro_norm_L_new, fro_norm_L_accaltproj:  4.1522986867270055e-23
# mse_S_new, mse_S_accaltproj:  1.5107300136007257e-09
# fro_norm_S_new, fro_norm_S_accaltproj:  2.749717991619777e-16
# count_nonzeros_S_new, count_nonzeros_S_accaltproj:  0.9999999984378337
#
# relative_err_new, relative_err_bftrain:  1.0
# fro_norm_L_new, fro_norm_L_bftrain:  8.295514495846353e-35
# mse_S_new, mse_S_bftrain:  1.0862202857707863e-16
# fro_norm_S_new, fro_norm_S_bftrain:  5.037031031605137e-44
# count_nonzeros_S_new, count_nonzeros_S_bftrain:  1.0086527751392034e-123

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_old[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_old[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_old[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_old[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2174885101.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2174885101.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# relative_err: 3/120 outliers
# fro_norm_L: 6/120 outliers
# mse_S: 18/120 outliers
# fro_norm_S: 6/120 outliers
# count_nonzeros_S: 0/120 outliers
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
print("P-values from test of mean with H1: _new/_old < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_old < 1
# relative_err:  2.0418254612197056e-29
# fro_norm_L:  0.647243778522453
# mse_S:  0.020811127191885957
# fro_norm_S:  1.18061254209597e-16
# count_nonzeros_S:  nan

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_accaltproj[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_accaltproj[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_accaltproj[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_accaltproj[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2948823882.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2948823882.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# relative_err: 4/120 outliers
# fro_norm_L: 4/120 outliers
# mse_S: 12/120 outliers
# fro_norm_S: 7/120 outliers
# count_nonzeros_S: 0/120 outliers
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/function_base.py:4486: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
print("P-values from test of mean with H1: _new/_accaltproj < 1")
#print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_accaltproj < 1
# relative_err:  4.56642453154426e-54
# fro_norm_L:  2.792217706972972e-38
# mse_S:  1.1446117476289494e-16
# fro_norm_S:  6.136132273239063e-29
# count_nonzeros_S:  nan

# %%
print(np.median(count_nonzeros_S_new), np.mean(count_nonzeros_S_new), np.max(count_nonzeros_S_new))
print(np.median(count_nonzeros_S_accaltproj), np.mean(count_nonzeros_S_accaltproj), np.max(count_nonzeros_S_accaltproj))
print(np.median(count_nonzeros_S_old), np.mean(count_nonzeros_S_old), np.max(count_nonzeros_S_old))
# Out:
# 0.000128 0.0005784 0.005024
# 0.0 5.4666666e-06 4.8e-05
# 1.6e-05 1.9600002e-05 6.4e-05

# %% [markdown]
# #### Evaluating unrolled network on test dataset

# %%
out_bftrain_ontest4, out_hat_ontest4 = get_net_outputs(net4, LearnedAAP(max_iter, d1, d2), r, test4)
out_accaltproj_ontest4 = []
out_ircur_ontest4 = []
for (L_true, S_true, M_true) in test4:
    loss0, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    out_accaltproj_ontest4.append((L0, S0))
    loss0, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    out_ircur_ontest4.append((L0, S0))

# %%
metrics = get_metrics(test4, out_ircur_ontest4, out_bftrain_ontest4, out_hat_ontest4)
fro_norm_L_old, mse_S_old, fro_norm_S_old, count_nonzeros_S_old, relative_err_old, \
    fro_norm_L_new, mse_S_new, fro_norm_S_new, count_nonzeros_S_new, relative_err_new, \
    fro_norm_L_bftrain, mse_S_bftrain, fro_norm_S_bftrain, count_nonzeros_S_bftrain, relative_err_bftrain \
        = metrics.values()
fro_norm_L_accaltproj, mse_S_accaltproj, fro_norm_S_accaltproj, count_nonzeros_S_accaltproj, relative_err_accaltproj \
    = list(get_metrics(test4, out_accaltproj_ontest4, out_bftrain_ontest4, out_hat_ontest4).values())[:5]

fig, ax = plt.subplots()
ax.boxplot([relative_err_old, relative_err_new, relative_err_bftrain, relative_err_accaltproj], notch = True)
ax.set_xticklabels(["relative_err_old", "relative_err_new", "relative_err_bftrain", "relative_err_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_L_old, fro_norm_L_new, fro_norm_L_bftrain, fro_norm_L_accaltproj], notch = True)
ax.set_xticklabels(["fro_norm_L_old", "fro_norm_L_new", "fro_norm_L_bfaftrain", "fro_norm_L_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([mse_S_old, mse_S_new, mse_S_bftrain, mse_S_accaltproj], notch = True)
ax.set_xticklabels(["mse_S_old", "mse_S_new", "mse_S_bfaftrain", "mse_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([fro_norm_S_old, fro_norm_S_new, fro_norm_S_bftrain, fro_norm_S_accaltproj], notch = True)
ax.set_xticklabels(["fro_norm_S_old", "fro_norm_S_new", "fro_norm_S_bfaftrain", "fro_norm_S_accaltproj"])
plt.show()

fig, ax = plt.subplots()
ax.boxplot([count_nonzeros_S_old, count_nonzeros_S_new, count_nonzeros_S_bftrain, count_nonzeros_S_accaltproj], notch = True)
ax.set_xticklabels(["count_nonzeros_S_old", "count_nonzeros_S_new", "count_nonzeros_S_bfaftrain", "count_nonzeros_S_accaltproj"])
plt.show()
# Out:
# /Users/elitanzc/Github/FYP/helper.py:254: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat1 = (torch.tensor(mat1) == 0)
# /Users/elitanzc/Github/FYP/helper.py:255: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   mat2 = (torch.tensor(mat2) == 0)

# %%
print("P-values from test of mean with H1: _new < _old")
print("relative_err_new, relative_err_old: ", stats.ttest_rel(relative_err_new, relative_err_old, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_old, alternative='less').pvalue)
print("mse_S_new, mse_S_old: ", stats.ttest_rel(mse_S_new, mse_S_old, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_old, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_old, alternative='less').pvalue)
print()
print("P-values from test of mean with H1: _new < _accaltproj")
print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(relative_err_new, relative_err_accaltproj, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_accaltproj, alternative='less').pvalue)
print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(mse_S_new, mse_S_accaltproj, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_accaltproj, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_accaltproj, alternative='less').pvalue)
print()
print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(relative_err_new, relative_err_bftrain, alternative='less').pvalue)
print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(fro_norm_L_new, fro_norm_L_bftrain, alternative='less').pvalue)
print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(mse_S_new, mse_S_bftrain, alternative='less').pvalue)
print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(fro_norm_S_new, fro_norm_S_bftrain, alternative='less').pvalue)
print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(count_nonzeros_S_new, count_nonzeros_S_bftrain, alternative='less').pvalue)

# print("*Note: values are log-transformed before deriving p-values")
# print()
# print("relative_err_new, relative_err_old: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_old), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_old: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_old), alternative='less').pvalue)
# print("mse_S_new, mse_S_old: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_old), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_old: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_old), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_old: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_old), alternative='less').pvalue)
# print()
# print("P-values from test of mean with H1: _new < _accaltproj")
# print("relative_err_new, relative_err_accaltproj: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_accaltproj), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_accaltproj: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_accaltproj), alternative='less').pvalue)
# print("mse_S_new, mse_S_accaltproj: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_accaltproj), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_accaltproj: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_accaltproj), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_accaltproj: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_accaltproj), alternative='less').pvalue)
# print()
# print("relative_err_new, relative_err_bftrain: ", stats.ttest_rel(np.log(relative_err_new), np.log(relative_err_bftrain), alternative='less').pvalue)
# print("fro_norm_L_new, fro_norm_L_bftrain: ", stats.ttest_rel(np.log(fro_norm_L_new), np.log(fro_norm_L_bftrain), alternative='less').pvalue)
# print("mse_S_new, mse_S_bftrain: ", stats.ttest_rel(np.log(mse_S_new), np.log(mse_S_bftrain), alternative='less').pvalue)
# print("fro_norm_S_new, fro_norm_S_bftrain: ", stats.ttest_rel(np.log(fro_norm_S_new), np.log(fro_norm_S_bftrain), alternative='less').pvalue)
# print("count_nonzeros_S_new, count_nonzeros_S_bftrain: ", stats.ttest_rel(np.log(count_nonzeros_S_new), np.log(count_nonzeros_S_bftrain), alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new < _old
# relative_err_new, relative_err_old:  4.245684245124085e-12
# fro_norm_L_new, fro_norm_L_old:  1.9103453623402072e-05
# mse_S_new, mse_S_old:  9.266371257935711e-05
# fro_norm_S_new, fro_norm_S_old:  2.374321231518678e-12
# count_nonzeros_S_new, count_nonzeros_S_old:  0.8842316379368482
#
# P-values from test of mean with H1: _new < _accaltproj
# relative_err_new, relative_err_accaltproj:  3.173370652455835e-29
# fro_norm_L_new, fro_norm_L_accaltproj:  6.604578527122348e-23
# mse_S_new, mse_S_accaltproj:  1.1190974406726196e-09
# fro_norm_S_new, fro_norm_S_accaltproj:  6.010098835546886e-17
# count_nonzeros_S_new, count_nonzeros_S_accaltproj:  0.9815020369299345
#
# relative_err_new, relative_err_bftrain:  1.0
# fro_norm_L_new, fro_norm_L_bftrain:  6.481843415537724e-35
# mse_S_new, mse_S_bftrain:  7.680854188553864e-17
# fro_norm_S_new, fro_norm_S_bftrain:  2.0924719470889573e-45
# count_nonzeros_S_new, count_nonzeros_S_bftrain:  8.576250766061587e-124

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_old[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_old[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_old[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_old[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_old without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2174885101.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2174885101.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_old[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 2/120 outliers
# fro_norm_L: 2/120 outliers
# mse_S: 11/120 outliers
# fro_norm_S: 1/120 outliers
# count_nonzeros_S: 0/120 outliers

# %%
print("P-values from test of mean with H1: _new/_old < 1")
# print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_old < 1
# relative_err:  6.648496910173569e-31
# fro_norm_L:  0.13087574427045237
# mse_S:  4.161704068729844e-10
# fro_norm_S:  2.4693223554903504e-28
# count_nonzeros_S:  nan

# %%
relative_err = np.array([relative_err_new[i]/ relative_err_accaltproj[i] for i in range(len(relative_err_new))])
fro_norm_L = np.array([fro_norm_L_new[i]/ fro_norm_L_accaltproj[i] for i in range(len(fro_norm_L_new))])
mse_S = np.array([mse_S_new[i]/ mse_S_accaltproj[i] for i in range(len(mse_S_new))])
fro_norm_S = np.array([fro_norm_S_new[i]/ fro_norm_S_accaltproj[i] for i in range(len(fro_norm_S_new))])
count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
d = {"relative_err": relative_err \
    , "fro_norm_L": fro_norm_L \
    , "mse_S": mse_S \
    , "fro_norm_S": fro_norm_S \
    , "count_nonzeros_S": count_nonzeros_S
    }

fig, ax = plt.subplots()
ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj")
plt.show()

fig, ax = plt.subplots()
ax.boxplot(d.values(), showfliers=False)
ax.set_xticklabels(d.keys())
ax.set_title("Plot of {metric}_new over {metric}_accaltproj without outliers")
plt.show()

for key, val in d.items():
    print(f"{key}: {count_outliers(d[key])}/{len(relative_err)} outliers")
# Out:
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2948823882.py:5: RuntimeWarning: invalid value encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
# /var/folders/st/_q3p7lz50mncs1x1m22w92gc0000gn/T/ipykernel_61504/2948823882.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   count_nonzeros_S = np.array([count_nonzeros_S_new[i]/ count_nonzeros_S_accaltproj[i] for i in range(len(count_nonzeros_S_new))])
# relative_err: 3/120 outliers
# fro_norm_L: 2/120 outliers
# mse_S: 9/120 outliers
# fro_norm_S: 4/120 outliers
# count_nonzeros_S: 0/120 outliers

# %%
print("P-values from test of mean with H1: _new/_accaltproj < 1")
#print("*Note: values are log-transformed before deriving p-values \n")
for key, val in d.items():
    print(f'{key}: ', stats.ttest_1samp(val, 1, alternative='less').pvalue)
# Out:
# P-values from test of mean with H1: _new/_accaltproj < 1
# relative_err:  5.881271640311224e-48
# fro_norm_L:  3.5509471165109845e-38
# mse_S:  8.719626413412173e-19
# fro_norm_S:  1.9258435525798967e-34
# count_nonzeros_S:  nan

# %%
print(np.median(count_nonzeros_S_new), np.mean(count_nonzeros_S_new), np.max(count_nonzeros_S_new))
print(np.median(count_nonzeros_S_accaltproj), np.mean(count_nonzeros_S_accaltproj), np.max(count_nonzeros_S_accaltproj))
print(np.median(count_nonzeros_S_old), np.mean(count_nonzeros_S_old), np.max(count_nonzeros_S_old))
# Out:
# 0.0 3.7066664e-05 0.001296
# 0.0 5.4666666e-06 4.8e-05
# 1.6e-05 1.88e-05 8e-05
