# %% [markdown]
# # Test on real world data

# %%
from helper import *
import torch
import torchvision
import torchvision.transforms as transforms
import os

# %%
from torchvision.io import read_image, ImageReadMode

# %%
dir = "data_pngs"
subjects = {}
for subject in os.listdir(dir):
    for pic in os.listdir(os.path.join(dir, subject)):
        f = os.path.join(dir, subject, pic)
        img = read_image(f, ImageReadMode.GRAY)
        img = torchvision.transforms.ConvertImageDtype(torch.float64)(img)
        img = torch.flatten(img.squeeze().T)
        if subjects.get(subject) == None:
            subjects[subject] = img
        else:
            subjects[subject] = torch.column_stack((subjects[subject], img))

# %% [markdown]
# ## New functions

# %%
def thres(inputs, t, hard=True, old=True):
    if not hard:
        out = torch.sign(inputs) * torch.max(torch.abs(inputs)- t, torch.zeros(inputs.shape))
    else:
        if old:
            out = inputs * (torch.abs(inputs) > t)
        else:
            # out = torch.sign(inputs) * torch.max(\
            #                                     torch.abs(inputs) - torch.nan_to_num(torch.div(torch.pow(t, 6), torch.pow(torch.abs(inputs), 5))) \
            #                                     , torch.zeros(inputs.shape))
            # out = torch.sign(inputs) * torch.max(torch.abs(inputs) \
            #                                     - torch.div(t, torch.exp(3 * torch.div(torch.abs(inputs) - t, t))) \
            #                                     , torch.zeros(inputs.shape))
            # out = inputs * torch.max(1 - torch.div(torch.pow(t, 2), torch.pow(inputs, 2)), torch.zeros(inputs.shape))
            # out = torch.div(1,  1 + torch.exp(-100 * (torch.sign(inputs) * torch.max(torch.abs(inputs)- t, torch.zeros(inputs.shape))))) \
            #         + torch.sign(inputs) * torch.max(torch.abs(inputs)- t, torch.zeros(inputs.shape)) \
            #         - t
            # mu = 1.0005 * t
            # out = inputs * (torch.abs(inputs) >= mu) \
            #         + torch.sign(inputs) * (mu/(mu-t))*(torch.abs(inputs) - t) * (mu > torch.abs(inputs)) * (torch.abs(inputs) >= t)
            gamma, beta = 0.95, 1
            out = inputs * (torch.abs(inputs) > torch.sqrt(gamma * beta * t**2)) * (beta <= gamma) \
                    + torch.sign(inputs) * torch.min(beta/(beta - gamma) * torch.max(torch.abs(inputs) - (t * gamma), torch.zeros(inputs.shape)), torch.abs(inputs)) * (beta > gamma)
    return out

# %%
## ======================== Learned AccAltProj model ========================
## recover low-rank matrix L from M = L + S

class InitStage(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, M0, r):
        m, n = M0.shape
        norm_of_M0 = torch.linalg.norm(M0)
        beta = 1/(2 * np.power(m * n, 1/4))
        beta_init = 4 * beta
        zeta = beta_init * torch.linalg.norm(M0, 2)
        S = thres(M0, zeta, hard=True, old=False)
        U, Sigma, V = torch.linalg.svd(M0 - S, full_matrices=False)
        U, Sigma, V = U[:,:r], Sigma[:r], V.t()[:, :r]
        L = U @ torch.diag(Sigma) @ V.t()
        zeta = beta * Sigma[0]
        S = M0 - L
        S = thres(S, zeta, hard=True, old=False)
        return S, L, U, V, beta, norm_of_M0

class ProjStage(nn.Module):
    def __init__(self, gamma, lay):
        super().__init__()
        self.gamma = gamma
        self.lay = lay
    def forward(self, M0, S, U, V, r, beta):
        ## Update L
        Z = M0 - S
        Q1, R1 = torch.linalg.qr(Z.t() @ U - V @ ((Z @ V).t() @ U)) ## reduced QR
        Q2, R2 = torch.linalg.qr(Z @ V - U @ (U.t() @ Z @ V)) ## reduced QR
        A = torch.cat((torch.cat((U.t() @ Z @ V, R1.t()), 1), 
                        torch.cat((R2, torch.zeros(R2.shape)), 1)), 0) ## A is 2r x 2r matrix
        Um, Sm, Vm = torch.linalg.svd(A, full_matrices=False)
        U = torch.cat((U, Q2), 1) @ Um[:,:r]
        V = torch.cat((V, Q1), 1) @ Vm.t()[:,:r]
        L = U @ torch.diag(Sm[:r]) @ V.t()
        ## Update S
        zeta = beta * (Sm[r] + torch.pow(self.gamma, self.lay) * Sm[0])
        S = M0 - L
        S = thres(S, zeta, hard=True, old=False)
        return S, L, U, V

class LearnedAAP(nn.Module):
    def __init__(self, max_iter):
        super().__init__()
        self.max_iter = max_iter
        self.gamma = nn.Parameter(torch.tensor(0.7))
        #self.gamma = torch.tensor(0.7)
        self.beta = nn.Parameter(torch.tensor(0.03))
        # self.coef = nn.Parameter(torch.tensor(1.0))

        ## Stack layers
        self.layer = [InitStage()]
        for t in range(max_iter):
            #self.layer.append(ProjStage(gamma = nn.Parameter(torch.pow(self.gamma.clone().detach(), t + 1).requires_grad_(True))))
            #self.layer.append(ProjStage(gamma = nn.Parameter(self.gamma.clone().detach().requires_grad_(True))))
            self.layer.append(ProjStage(self.gamma, t+1))
        self.layers = nn.Sequential(*self.layer)
        ## Track loss
        self.err = np.zeros(max_iter + 1)

    def forward(self, M0, r):
        lay_init = self.layers[0]
        S, L, U, V, beta, norm_of_M0 = lay_init(M0, r)
        for t in range(1, self.max_iter + 1):
            lay = self.layers[t]
            S, L, U, V = lay(M0, S, U, V, r, self.beta)
            self.err[t] = torch.linalg.norm(M0 - L - S)/ norm_of_M0
        return L, S

# %%
def train_nn(net, r, lr, weight_decay, nepochs, dataset):
    torch.autograd.set_detect_anomaly(False)
    params_bftrain = [x.clone().detach().numpy() for x in list(net.parameters())]
    optimizer = Adam(net.parameters(), lr=lr, weight_decay=weight_decay)
    l0_norm_of_S_Shat = []
    for epoch in range(nepochs):
        for i in range(len(dataset)):
            L0, S0, M0 = dataset[i]
            optimizer.zero_grad()
            L_hat, S_hat = net(M0, r)
            print(net.err[-1])
            loss = torch.pow(torch.linalg.norm(L0 - L_hat), 2)/ torch.pow(torch.linalg.norm(L0), 2) \
                    + torch.pow(torch.linalg.norm(S0 - S_hat), 2)/ torch.pow(torch.linalg.norm(S0), 2) \
                    #+ torch.pow(torch.linalg.norm(M0 - L_hat - S_hat), 2)
            # loss = torch.linalg.norm(L0 - L_hat)/ torch.linalg.norm(L0) \
            #         + torch.linalg.norm(S0 - S_hat)/ torch.linalg.norm(S0)
            loss.backward()
            optimizer.step()
            l0_norm_of_S_Shat.append(torch.count_nonzero(S0 - S_hat))
            print(list(net.parameters()))
            print(net.gamma.grad, net.beta.grad)
            print('Epoch ' + str(epoch+1) +'/' + str(nepochs) +' at cost=' + str(loss.item()))
    print('Finished Training')
    params_aftrain = [x.clone().detach().numpy() for x in list(net.parameters())]
    return net, params_bftrain, params_aftrain, l0_norm_of_S_Shat

# %%
def get_net_outputs(net_trained, net_bftrain, r, dataset):
    out_bftrain = []
    out_hat = []
    for i in range(len(dataset)):
        M_true = dataset[i]
        L_bftrain, S_bftrain = net_bftrain(M_true, r)
        print(net_bftrain.err[-1])
        out_bftrain.append((L_bftrain.detach().numpy(), S_bftrain.detach().numpy()))
        L_hat, S_hat = net_trained(M_true, r)
        print(net_trained.err[-1])
        out_hat.append((L_hat.detach().numpy(), S_hat.detach().numpy()))
    out_bftrain = np.asarray(out_bftrain)
    out_hat = np.asarray(out_hat)
    return out_bftrain, out_hat

# %%
def plot_true_vs_est_matrices(L_hat, L_true, S_hat, S_true):
    combined = np.concatenate((L_hat, L_true, S_hat, S_true))
    fig, [ax1, ax2] = plt.subplots(1,2)
    im1 = ax1.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    ax1.set_title("L_hat")
    plt.colorbar(im1, ax=ax1)
    im2 = ax2.imshow(L_true, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    ax2.set_title("L_true")
    plt.colorbar(im2, ax=ax2)
    plt.show()
    fig, [ax3, ax4] = plt.subplots(1,2)
    im3 = ax3.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    ax3.set_title("S_hat")
    plt.colorbar(im3, ax=ax3)
    im4 = ax4.imshow(S_true, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    ax4.set_title("S_true")
    plt.colorbar(im4, ax=ax4)
    plt.show()

# %% [markdown]
# ## Training

# %%
r = 1
max_iter = 50

# %%
print("original beta =", 1/(2 * np.power(243 * 320 * 11, 1/4)))
# Out:
# original beta = 0.01644117189829903

# %%
train = [subjects[x] for x in ['subject01', 'subject02', 'subject03', 'subject04', 'subject05', 'subject06', 'subject07']]
test = [subjects[x] for x in ['subject08', 'subject09', 'subject10', 'subject11', 'subject12', 'subject13', 'subject14', 'subject15']]
train_est = []
for i, M_true in enumerate(train):
    loss, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    train_est.append((L0, S0, M_true))
    print(loss[-1])
# Out:
# tensor(4.8264e-10, dtype=torch.float64)
# tensor(1.4858e-09, dtype=torch.float64)
# tensor(9.3135e-10, dtype=torch.float64)
# tensor(1.0266e-09, dtype=torch.float64)
# tensor(9.3461e-10, dtype=torch.float64)
# tensor(1.7012e-09, dtype=torch.float64)
# tensor(9.1149e-10, dtype=torch.float64)

# %%
net, params_bftrain, params_aftrain, l0_norm_of_S_Shat = train_nn(LearnedAAP(max_iter), r \
                                                                    , lr=2e-03, weight_decay=0 \
                                                                    , nepochs=5, dataset=train_est)
# Out:
# 2.0612961117521244e-08
# [Parameter containing:
# tensor(0.7200, requires_grad=True), Parameter containing:
# tensor(0.0500, requires_grad=True)]
# tensor(-0.1395) tensor(-0.3793)
# Epoch 1/5 at cost=0.030185111642100138
# 2.7396298735093934e-07
# [Parameter containing:
# tensor(0.7103, requires_grad=True), Parameter containing:
# tensor(0.0497, requires_grad=True)]
# tensor(0.4060) tensor(0.3501)
# Epoch 1/5 at cost=0.055088654085035486
# 9.12960498167034e-08
# [Parameter containing:
# tensor(0.6957, requires_grad=True), Parameter containing:
# tensor(0.0411, requires_grad=True)]
# tensor(0.5024) tensor(0.4572)
# Epoch 1/5 at cost=0.4811818339134786
# 3.299739289385053e-08
# [Parameter containing:
# tensor(0.6882, requires_grad=True), Parameter containing:
# tensor(0.0424, requires_grad=True)]
# tensor(-0.2280) tensor(-0.5108)
# Epoch 1/5 at cost=0.06415765771100593
# 1.1278724043547412e-08
# [Parameter containing:
# tensor(0.6776, requires_grad=True), Parameter containing:
# tensor(0.0397, requires_grad=True)]
# tensor(0.3474) tensor(0.3103)
# Epoch 1/5 at cost=0.27217406397703114
# 5.265650526193603e-09
# [Parameter containing:
# tensor(0.6873, requires_grad=True), Parameter containing:
# tensor(0.0500, requires_grad=True)]
# tensor(-9.8988) tensor(-18.1250)
# Epoch 1/5 at cost=0.2201494899581325
# 1.0253224168757924e-08
# [Parameter containing:
# tensor(0.6954, requires_grad=True), Parameter containing:
# tensor(0.0587, requires_grad=True)]
# tensor(0.3788) tensor(0.4279)
# Epoch 1/5 at cost=0.14878209829404734
# 2.275662758060784e-08
# [Parameter containing:
# tensor(0.7019, requires_grad=True), Parameter containing:
# tensor(0.0662, requires_grad=True)]
# tensor(0.5948) tensor(0.5176)
# Epoch 2/5 at cost=0.03147451588448755
# 1.0357656629927723e-07
# [Parameter containing:
# tensor(0.7075, requires_grad=True), Parameter containing:
# tensor(0.0727, requires_grad=True)]
# tensor(0.2016) tensor(0.0878)
# Epoch 2/5 at cost=0.054013444253213985
# 1.0921521067001378e-07
# [Parameter containing:
# tensor(0.7109, requires_grad=True), Parameter containing:
# tensor(0.0781, requires_grad=True)]
# tensor(1.5672) tensor(0.8597)
# Epoch 2/5 at cost=0.47780524045850664
# 1.984714448206887e-07
# [Parameter containing:
# tensor(0.7144, requires_grad=True), Parameter containing:
# tensor(0.0831, requires_grad=True)]
# tensor(-0.4480) tensor(-0.3406)
# Epoch 2/5 at cost=0.06814304263219251
# 1.878270062550825e-07
# [Parameter containing:
# tensor(0.7164, requires_grad=True), Parameter containing:
# tensor(0.0874, requires_grad=True)]
# tensor(1.1745) tensor(0.3583)
# Epoch 2/5 at cost=0.27511550141591207
# 3.0661199614586596e-07
# [Parameter containing:
# tensor(0.7165, requires_grad=True), Parameter containing:
# tensor(0.0909, requires_grad=True)]
# tensor(1.7859) tensor(0.7245)
# Epoch 2/5 at cost=0.22726175190417092
# 2.969940007053131e-07
# [Parameter containing:
# tensor(0.7141, requires_grad=True), Parameter containing:
# tensor(0.0933, requires_grad=True)]
# tensor(2.7180) tensor(1.4850)
# Epoch 2/5 at cost=0.15554829968701117
# 1.4472076072599948e-07
# [Parameter containing:
# tensor(0.7123, requires_grad=True), Parameter containing:
# tensor(0.0955, requires_grad=True)]
# tensor(-0.3885) tensor(-0.1851)
# Epoch 3/5 at cost=0.03214187612822789
# 3.547052137947055e-07
# [Parameter containing:
# tensor(0.7107, requires_grad=True), Parameter containing:
# tensor(0.0976, requires_grad=True)]
# tensor(-0.0696) tensor(-0.1088)
# Epoch 3/5 at cost=0.05466114757919579
# 1.904133074870742e-07
# [Parameter containing:
# tensor(0.7111, requires_grad=True), Parameter containing:
# tensor(0.1004, requires_grad=True)]
# tensor(-2.0022) tensor(-1.7116)
# Epoch 3/5 at cost=0.4689366138732114
# 2.4869725620395536e-07
# [Parameter containing:
# tensor(0.7091, requires_grad=True), Parameter containing:
# tensor(0.1023, requires_grad=True)]
# tensor(2.6573) tensor(1.2593)
# Epoch 3/5 at cost=0.06852592036900733
# 1.681818461723783e-07
# [Parameter containing:
# tensor(0.7068, requires_grad=True), Parameter containing:
# tensor(0.1039, requires_grad=True)]
# tensor(0.5872) tensor(0.0944)
# Epoch 3/5 at cost=0.274332718360104
# 2.261585055809112e-07
# [Parameter containing:
# tensor(0.7038, requires_grad=True), Parameter containing:
# tensor(0.1052, requires_grad=True)]
# tensor(0.9165) tensor(0.2955)
# Epoch 3/5 at cost=0.22073401474361407
# 1.1477228576520327e-07
# [Parameter containing:
# tensor(0.7016, requires_grad=True), Parameter containing:
# tensor(0.1068, requires_grad=True)]
# tensor(-0.4689) tensor(-0.5488)
# Epoch 3/5 at cost=0.044464685173317225
# 8.286147657253416e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.1079, requires_grad=True)]
# tensor(0.9175) tensor(0.4293)
# Epoch 4/5 at cost=0.0319950302343778
# 1.2728330543604037e-07
# [Parameter containing:
# tensor(0.6961, requires_grad=True), Parameter containing:
# tensor(0.1089, requires_grad=True)]
# tensor(-0.0952) tensor(-0.0420)
# Epoch 4/5 at cost=0.05360199269381921
# 6.828753985906421e-08
# [Parameter containing:
# tensor(0.6944, requires_grad=True), Parameter containing:
# tensor(0.1100, requires_grad=True)]
# tensor(-0.6132) tensor(-0.1981)
# Epoch 4/5 at cost=0.12828952691093415
# 7.131088068370743e-08
# [Parameter containing:
# tensor(0.6933, requires_grad=True), Parameter containing:
# tensor(0.1112, requires_grad=True)]
# tensor(-0.5014) tensor(-0.3099)
# Epoch 4/5 at cost=0.06630634838182452
# 5.260061279769565e-08
# [Parameter containing:
# tensor(0.6929, requires_grad=True), Parameter containing:
# tensor(0.1124, requires_grad=True)]
# tensor(-0.6786) tensor(-0.2333)
# Epoch 4/5 at cost=0.2721410360145265
# 6.679008591923377e-08
# [Parameter containing:
# tensor(0.6882, requires_grad=True), Parameter containing:
# tensor(0.1123, requires_grad=True)]
# tensor(5.0425) tensor(1.9034)
# Epoch 4/5 at cost=0.23440841977126006
# 3.0175049043671844e-08
# [Parameter containing:
# tensor(0.6813, requires_grad=True), Parameter containing:
# tensor(0.1116, requires_grad=True)]
# tensor(2.9572) tensor(1.1417)
# Epoch 4/5 at cost=0.04599959821516678
# 1.295541223934707e-08
# [Parameter containing:
# tensor(0.6748, requires_grad=True), Parameter containing:
# tensor(0.1108, requires_grad=True)]
# tensor(0.3791) tensor(0.1792)
# Epoch 5/5 at cost=0.03221884756367581
# 1.3465652538797912e-08
# [Parameter containing:
# tensor(0.6687, requires_grad=True), Parameter containing:
# tensor(0.1101, requires_grad=True)]
# tensor(0.1075) tensor(0.0461)
# Epoch 5/5 at cost=0.05272326420192537
# 4.183925840981517e-09
# [Parameter containing:
# tensor(0.6775, requires_grad=True), Parameter containing:
# tensor(0.1182, requires_grad=True)]
# tensor(-33.8165) tensor(-20.4847)
# Epoch 5/5 at cost=0.24610430684191945
# 1.4951036988928063e-08
# [Parameter containing:
# tensor(0.6855, requires_grad=True), Parameter containing:
# tensor(0.1255, requires_grad=True)]
# tensor(0.3703) tensor(0.1226)
# Epoch 5/5 at cost=0.06339823176069503
# 3.275114276621668e-08
# [Parameter containing:
# tensor(0.6927, requires_grad=True), Parameter containing:
# tensor(0.1322, requires_grad=True)]
# tensor(-0.0847) tensor(-0.0500)
# Epoch 5/5 at cost=0.2702462210425435
# 8.338948366899858e-08
# [Parameter containing:
# tensor(0.6997, requires_grad=True), Parameter containing:
# tensor(0.1386, requires_grad=True)]
# tensor(-1.3573) tensor(-0.6790)
# Epoch 5/5 at cost=0.21483958734350336
# 9.157336116936385e-08
# [Parameter containing:
# tensor(0.7051, requires_grad=True), Parameter containing:
# tensor(0.1442, requires_grad=True)]
# tensor(3.2453) tensor(0.6503)
# Epoch 5/5 at cost=0.15822092592365672
# Finished Training

# %% [markdown]
# ## on train data

# %%
out_bftrain, out_hat = get_net_outputs(net, LearnedAAP(max_iter), r, train)
# Out:
# 2.0612961117521244e-08
# 1.3231484413810533e-07
# 3.174769997691283e-08
# 2.8463061368101256e-07
# 3.379746744357647e-08
# 2.2331439608252652e-07
# 3.6524603524654775e-08
# 2.8552352086143954e-07
# 3.0071229460727176e-08
# 1.9779970473348339e-07
# 3.472429212269612e-08
# 2.7873816978203804e-07
# 1.9357718041596934e-08
# 1.926559494868308e-07

# %%
out_hat[0][0].shape
# Out:
# (77760, 11)

# %%
subject1_train_est = train_est[0]
subject1_out_hat = out_hat[0]
subject1_out_bftrain = out_bftrain[0]
lowrank_train_est = subject1_train_est[0]
lowrank_out_hat = subject1_out_hat[0]
lowrank_out_bftrain = subject1_out_bftrain[0]
sparse_train_est = subject1_train_est[1]
sparse_out_hat = subject1_out_hat[1]
sparse_out_bftrain = subject1_out_bftrain[1]
for i in range(11):
    plot_true_vs_est_matrices((lowrank_out_hat[:,i].reshape(320, 243).T) \
                            , (lowrank_train_est[:,i].reshape(320, 243).T) \
                            , (sparse_out_hat[:,i].reshape(320, 243).T) \
                            , (sparse_train_est[:,i].reshape(320, 243).T))

# %% [markdown]
# ## on test data

# %%
out_accaltproj_ontest = []
out_ircur_ontest = []
for i, M_true in enumerate(test):
    loss, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    print(loss[-1])
    out_accaltproj_ontest.append((L0, S0, M_true))
    loss, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    out_ircur_ontest.append((L0, S0, M_true))
# Out:
# tensor(8.0928e-09, dtype=torch.float64)
# tensor(9.8949e-09, dtype=torch.float64)
# tensor(8.9720e-09, dtype=torch.float64)
# tensor(6.2974e-09, dtype=torch.float64)
# tensor(6.0862e-09, dtype=torch.float64)
# tensor(7.5678e-09, dtype=torch.float64)
# tensor(1.1220e-08, dtype=torch.float64)
# tensor(9.8406e-09, dtype=torch.float64)

# %%
out_bftrain_ontest, out_hat_ontest = get_net_outputs(net, LearnedAAP(max_iter), r, test)
# Out:
# 1.3923348010659632e-08
# 1.1446975568076541e-07
# 1.6037300960640718e-08
# 1.4494323212725672e-07
# 1.9690897359248287e-08
# 1.4024326946539573e-07
# 1.5613406550966546e-08
# 1.147099400019028e-07
# 1.2744056298733032e-08
# 1.0298301744561186e-07
# 1.2140990917347729e-08
# 1.099590512933523e-07
# 1.9430904061779102e-08
# 1.6010042765651758e-07
# 1.4969132778947998e-08
# 1.3818069726368016e-07

# %%
subject1_accaltproj_ontest = out_accaltproj_ontest[3]
subject1_ircur_ontest = out_ircur_ontest[3]
subject1_out_hat_ontest = out_hat_ontest[3]
subject1_out_bftrain_ontest = out_bftrain_ontest[3]
lowrank_accaltproj_ontest = subject1_accaltproj_ontest[0]
lowrank_ircur_ontest = subject1_ircur_ontest[0]
lowrank_out_hat_ontest = subject1_out_hat_ontest[0]
lowrank_out_bftrain_ontest = subject1_out_bftrain_ontest[0]
sparse_accaltproj_ontest = subject1_accaltproj_ontest[1]
sparse_ircur_ontest = subject1_ircur_ontest[1]
sparse_out_hat_ontest = subject1_out_hat_ontest[1]
sparse_out_bftrain_ontest = subject1_out_bftrain_ontest[1]
for i in range(11):
    plot_true_vs_est_matrices((lowrank_out_hat_ontest[:,i].reshape(320, 243).T * 255) \
                            , (lowrank_ircur_ontest[:,i].reshape(320, 243).T * 255) \
                            , (sparse_out_hat_ontest[:,i].reshape(320, 243).T * 255) \
                            , (sparse_ircur_ontest[:,i].reshape(320, 243).T * 255))
